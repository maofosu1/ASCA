# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols, mixedlm
from statsmodels.stats.anova import anova_lm
import random
from scipy.linalg import svd
import warnings
warnings.filterwarnings('ignore')

# Load the synthetic data
df = pd.read_csv('synthetic_multivariate_data.csv')

# Extract feature columns
feature_cols = [col for col in df.columns if 'feature' in col]
X = df[feature_cols].values

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create a data matrix for easier handling
X_matrix = pd.DataFrame(X_scaled, columns=feature_cols)
X_matrix['subject_id'] = df['subject_id']
X_matrix['treatment'] = df['treatment']
X_matrix['timepoint'] = df['timepoint']

print("Data prepared for analysis.")
print("Number of samples:", X_matrix.shape[0])
print("Number of features:", len(feature_cols))
print("Factors: treatment, timepoint, subject_id")

# ============ ASCA: ANOVA-Simultaneous Component Analysis ============

def asca(data, formula, design_cols, feature_cols):
    """
    Implement ASCA (ANOVA-Simultaneous Component Analysis)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features

    Returns:
    --------
    Dictionary containing:
    - effect_matrices: matrices for each effect
    - pca_results: PCA results for each effect
    - explained_var: explained variance for each effect
    - total_variance: total variance of the data
    """
    print("\n=== ASCA Analysis ===")

    # Extract design and data matrices
    X = data[feature_cols].values
    n_samples, n_features = X.shape

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Fit the ANOVA model for each feature
    effect_matrices = {}
    anova_summaries = []

    # ANOVA decomposition
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model
        model = ols(feature_formula, data=data).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        # Store ANOVA summary for this feature
        if feature_idx == 0:  # Only store once
            anova_summaries.append(anova_table)

    # Extract effects from ANOVA model
    # Create empty matrices for each effect
    effects = ['C(treatment)', 'C(timepoint)', 'C(treatment):C(timepoint)', 'Residual']
    effect_matrices = {effect: np.zeros((n_samples, n_features)) for effect in effects}

    # Fill effect matrices feature by feature
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model for this feature
        model = ols(feature_formula, data=data).fit()

        # Get predicted values for each effect
        # Treatment effect
        treatment_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            param_name = f"C(treatment)[T.{treatment}]"
            if param_name in model.params:
                treatment_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment)'][:, feature_idx] = treatment_effect

        # Timepoint effect
        timepoint_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            timepoint = row['timepoint']
            param_name = f"C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                timepoint_effect[idx] = model.params[param_name]
        effect_matrices['C(timepoint)'][:, feature_idx] = timepoint_effect

        # Interaction effect
        interaction_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            timepoint = row['timepoint']
            param_name = f"C(treatment)[T.{treatment}]:C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                interaction_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment):C(timepoint)'][:, feature_idx] = interaction_effect

        # Residual effect
        effect_matrices['Residual'][:, feature_idx] = model.resid

    # Apply PCA to each effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in effect_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            print(f"{effect} - Sum of Squares: {effect_ss:.4f}")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Calculate total variance
    total_variance = np.sum(X_centered**2)

    return {
        'effect_matrices': effect_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'total_variance': total_variance,
        'anova_summaries': anova_summaries
    }

# ============ ASCA+ (ASCA with Significance Testing) ============

def asca_plus(data, formula, design_cols, feature_cols, n_permutations=999):
    """
    Implement ASCA+ (ASCA with permutation testing)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing

    Returns:
    --------
    Dictionary containing ASCA results plus permutation test results
    """
    print("\n=== ASCA+ Analysis (ASCA with Permutation Testing) ===")

    # Run standard ASCA
    asca_results = asca(data, formula, design_cols, feature_cols)

    # Get effect matrices and calculate sum of squares for each effect
    effect_matrices = asca_results['effect_matrices']
    observed_ss = {effect: np.sum(matrix**2) for effect, matrix in effect_matrices.items()
                 if effect != 'Residual'}

    # Permutation testing
    permuted_ss = {effect: [] for effect in observed_ss.keys()}

    print(f"\nRunning permutation tests with {n_permutations} permutations...")

    for perm in range(n_permutations):
        if perm % 100 == 0 and perm > 0:
            print(f"  Completed {perm} permutations")

        # Create permuted data
        perm_data = data.copy()

        # Permute each factor separately
        for effect in observed_ss.keys():
            if effect == 'C(treatment)':
                # Permute treatment labels
                perm_data['treatment'] = np.random.permutation(perm_data['treatment'].values)
            elif effect == 'C(timepoint)':
                # Permute timepoint labels
                perm_data['timepoint'] = np.random.permutation(perm_data['timepoint'].values)
            elif effect == 'C(treatment):C(timepoint)':
                # Permute interaction by shuffling combinations
                combinations = perm_data[['treatment', 'timepoint']].values
                np.random.shuffle(combinations)
                perm_data['treatment'] = combinations[:, 0]
                perm_data['timepoint'] = combinations[:, 1]

        # Run ASCA on permuted data
        perm_asca = asca(perm_data, formula, design_cols, feature_cols)
        perm_effect_matrices = perm_asca['effect_matrices']

        # Calculate sum of squares for each permuted effect
        for effect in observed_ss.keys():
            perm_ss = np.sum(perm_effect_matrices[effect]**2)
            permuted_ss[effect].append(perm_ss)

    # Calculate p-values
    p_values = {}
    for effect in observed_ss.keys():
        # Count how many permuted SS are >= observed SS
        p_values[effect] = (np.sum(np.array(permuted_ss[effect]) >= observed_ss[effect]) + 1) / (n_permutations + 1)

    print("\nPermutation Test Results:")
    for effect, p_value in p_values.items():
        significance = "significant" if p_value < 0.05 else "not significant"
        print(f"{effect}: p-value = {p_value:.4f} ({significance})")

    # Add results to ASCA results
    asca_results['p_values'] = p_values
    asca_results['permuted_ss'] = permuted_ss

    return asca_results

# ============ PE-ASCA (Permutation-Enhanced ASCA) ============

def pe_asca(data, formula, design_cols, feature_cols, n_permutations=999, alpha=0.05):
    """
    Implement PE-ASCA (Permutation-Enhanced ASCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing
    alpha: float
        Significance level

    Returns:
    --------
    Dictionary containing PE-ASCA results
    """
    print("\n=== PE-ASCA Analysis (Permutation-Enhanced ASCA) ===")

    # First, run ASCA+ to get permutation test results
    asca_plus_results = asca_plus(data, formula, design_cols, feature_cols, n_permutations)

    # Extract relevant information
    effect_matrices = asca_plus_results['effect_matrices']
    p_values = asca_plus_results['p_values']

    # Enhanced decomposition: only keep significant effects
    enhanced_matrices = {}
    for effect, p_value in p_values.items():
        if p_value <= alpha:
            enhanced_matrices[effect] = effect_matrices[effect]
            print(f"Effect {effect} is significant (p={p_value:.4f}) and included in enhanced model")
        else:
            # Add non-significant effects to residuals
            if 'Residual' not in enhanced_matrices:
                enhanced_matrices['Residual'] = effect_matrices[effect].copy()
            else:
                enhanced_matrices['Residual'] += effect_matrices[effect]
            print(f"Effect {effect} is not significant (p={p_value:.4f}) and added to residuals")

    # Add original residuals if not already included
    if 'Residual' not in enhanced_matrices:
        enhanced_matrices['Residual'] = effect_matrices['Residual']
    else:
        enhanced_matrices['Residual'] += effect_matrices['Residual']

    # Apply PCA to each significant effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in enhanced_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            total_ss = np.sum([np.sum(m**2) for m in enhanced_matrices.values()])
            print(f"{effect} - Sum of Squares: {effect_ss:.4f} ({effect_ss/total_ss*100:.2f}% of total)")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Create result structure
    pe_asca_results = {
        'effect_matrices': enhanced_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'p_values': p_values,
        'total_variance': asca_plus_results['total_variance']
    }

    return pe_asca_results

# ============ LiMM-PCA (Linear Mixed Models with PCA) ============

def limm_pca(data, feature_cols, verbose=True):
    """
    Implement LiMM-PCA (Linear Mixed Models with PCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing LiMM-PCA results
    """
    if verbose:
        print("\n=== LiMM-PCA Analysis (Linear Mixed Models with PCA) ===")

    # Extract data matrix
    X = data[feature_cols].values

    # Standardize the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Initialize containers for results
    fixed_effects = {}
    random_effects = {}
    residuals = {}
    pvalues = {}

    # Apply mixed model to each feature
    for i, feature in enumerate(feature_cols):
        if verbose and i % 3 == 0:
            print(f"Processing feature {i+1}/{len(feature_cols)}...")

        # Create mixed model formula
        formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit mixed effects model
        try:
            model = mixedlm(formula, data, groups=data['subject_id'])
            result = model.fit(reml=True)

            # Extract fixed effects
            fe_design = pd.get_dummies(data[['treatment', 'timepoint']], drop_first=False)
            fixed_pred = result.predict(exog=fe_design)
            fixed_effects[feature] = fixed_pred

            # Extract random effects (subject)
            rand_pred = result.random_effects
            subject_effect = np.zeros(len(data))
            for subject, effect in rand_pred.items():
                subject_idx = data['subject_id'] == subject
                subject_effect[subject_idx] = effect[0]
            random_effects[feature] = subject_effect

            # Extract residuals
            residuals[feature] = result.resid

            # Store p-values for fixed effects
            pvalues[feature] = result.pvalues

        except Exception as e:
            if verbose:
                print(f"Error fitting model for {feature}: {e}")
            # Use simpler approach if model fails
            fixed_effects[feature] = np.zeros(len(data))
            random_effects[feature] = np.zeros(len(data))
            residuals[feature] = X_scaled[:, i]

    # Convert to matrices
    fixed_matrix = np.column_stack([fixed_effects[feature] for feature in feature_cols])
    random_matrix = np.column_stack([random_effects[feature] for feature in feature_cols])
    resid_matrix = np.column_stack([residuals[feature] for feature in feature_cols])

    # Calculate variance explained
    total_var = np.sum(X_scaled**2)
    fixed_var = np.sum(fixed_matrix**2)
    random_var = np.sum(random_matrix**2)
    resid_var = np.sum(resid_matrix**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Fixed Effects: {fixed_var/total_var*100:.2f}%")
        print(f"Random Effects: {random_var/total_var*100:.2f}%")
        print(f"Residuals: {resid_var/total_var*100:.2f}%")

    # Apply PCA to fixed effects matrix
    pca_fixed = PCA()
    pca_fixed.fit(fixed_matrix)

    if verbose:
        print("\nPCA on Fixed Effects:")
        print(f"PC1 explained variance: {pca_fixed.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_fixed.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_fixed.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'fixed_matrix': fixed_matrix,
        'random_matrix': random_matrix,
        'resid_matrix': resid_matrix,
        'pca_fixed': pca_fixed,
        'fixed_scores': pca_fixed.transform(fixed_matrix),
        'total_var': total_var,
        'fixed_var': fixed_var,
        'random_var': random_var,
        'resid_var': resid_var
    }

    return results

# ============ MSCA (Multilevel Simultaneous Component Analysis) ============

def msca(data, feature_cols, verbose=True):
    """
    Implement MSCA (Multilevel Simultaneous Component Analysis)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing MSCA results
    """
    if verbose:
        print("\n=== MSCA Analysis (Multilevel Simultaneous Component Analysis) ===")

    # Extract data
    X = data[feature_cols].values
    subjects = data['subject_id'].unique()
    n_subjects = len(subjects)

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Split data into between-subject and within-subject parts
    X_between = np.zeros_like(X)
    X_within = np.zeros_like(X)

    # Calculate between-subject variation (level 2)
    for subject in subjects:
        subject_indices = data['subject_id'] == subject
        subject_mean = np.mean(X[subject_indices], axis=0)
        X_between[subject_indices] = subject_mean

    # Calculate within-subject variation (level 1)
    X_within = X - X_between

    # Calculate variance explained by each level
    total_var = np.sum(X_centered**2)
    between_var = np.sum(X_between**2)
    within_var = np.sum(X_within**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Between-subject: {between_var/total_var*100:.2f}%")
        print(f"Within-subject: {within_var/total_var*100:.2f}%")

    # Apply PCA to between-subject variation
    pca_between = PCA()
    between_scores = pca_between.fit_transform(X_between)

    # Apply PCA to within-subject variation
    pca_within = PCA()
    within_scores = pca_within.fit_transform(X_within)

    if verbose:
        print("\nPCA on Between-subject Variation:")
        print(f"PC1 explained variance: {pca_between.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_between.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_between.explained_variance_ratio_[1]*100:.2f}%")

        print("\nPCA on Within-subject Variation:")
        print(f"PC1 explained variance: {pca_within.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_within.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_within.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'X_between': X_between,
        'X_within': X_within,
        'pca_between': pca_between,
        'pca_within': pca_within,
        'between_scores': between_scores,
        'within_scores': within_scores,
        'total_var': total_var,
        'between_var': between_var,
        'within_var': within_var
    }

    return results

# Run all methods on the synthetic data

print("\n==== RUNNING ALL METHODS ON THE SYNTHETIC DATASET ====")

# Prepare formula and design columns for ASCA methods
formula = "~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"
design_cols = ['treatment', 'timepoint', 'subject_id']

# Run each method
print("\n===== METHOD 1: ASCA =====")
asca_results = asca(X_matrix, formula, design_cols, feature_cols)

print("\n===== METHOD 2: ASCA+ =====")
asca_plus_results = asca_plus(X_matrix, formula, design_cols, feature_cols, n_permutations=99)  # Reduced for computation

print("\n===== METHOD 3: PE-ASCA =====")
pe_asca_results = pe_asca(X_matrix, formula, design_cols, feature_cols, n_permutations=99, alpha=0.05)  # Reduced for computation

print("\n===== METHOD 4: LiMM-PCA =====")
limm_pca_results = limm_pca(X_matrix, feature_cols)

print("\n===== METHOD 5: MSCA =====")
msca_results = msca(X_matrix, feature_cols)
# Out:
# Data prepared for analysis.
# Number of samples: 90
# Number of features: 10
# Factors: treatment, timepoint, subject_id
#
# ==== RUNNING ALL METHODS ON THE SYNTHETIC DATASET ====
#
# ===== METHOD 1: ASCA =====
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# ===== METHOD 2: ASCA+ =====
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 93.5400
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 96.5207
#   PC1 explained variance: 76.73%
#   PC2 explained variance: 23.27%
# C(treatment):C(timepoint) - Sum of Squares: 82.5380
#   PC1 explained variance: 92.53%
#   PC2 explained variance: 7.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2851
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.3140
#   PC1 explained variance: 79.42%
#   PC2 explained variance: 20.58%
# C(treatment):C(timepoint) - Sum of Squares: 130.5723
#   PC1 explained variance: 91.47%
#   PC2 explained variance: 8.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.1554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 64.0552
#   PC1 explained variance: 76.88%
#   PC2 explained variance: 23.12%
# C(treatment):C(timepoint) - Sum of Squares: 90.4537
#   PC1 explained variance: 87.18%
#   PC2 explained variance: 12.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.8071
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.7020
#   PC1 explained variance: 70.36%
#   PC2 explained variance: 29.64%
# C(treatment):C(timepoint) - Sum of Squares: 62.3506
#   PC1 explained variance: 60.63%
#   PC2 explained variance: 39.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.0950
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.2996
#   PC1 explained variance: 61.92%
#   PC2 explained variance: 38.08%
# C(treatment):C(timepoint) - Sum of Squares: 54.3761
#   PC1 explained variance: 61.31%
#   PC2 explained variance: 38.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0112
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.0225
#   PC1 explained variance: 78.27%
#   PC2 explained variance: 21.73%
# C(treatment):C(timepoint) - Sum of Squares: 144.6457
#   PC1 explained variance: 94.79%
#   PC2 explained variance: 5.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.4633
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.6746
#   PC1 explained variance: 69.23%
#   PC2 explained variance: 30.77%
# C(treatment):C(timepoint) - Sum of Squares: 61.8270
#   PC1 explained variance: 72.24%
#   PC2 explained variance: 27.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.9151
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.5919
#   PC1 explained variance: 70.76%
#   PC2 explained variance: 29.24%
# C(treatment):C(timepoint) - Sum of Squares: 75.5881
#   PC1 explained variance: 75.78%
#   PC2 explained variance: 24.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.5258
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.2187
#   PC1 explained variance: 65.27%
#   PC2 explained variance: 34.73%
# C(treatment):C(timepoint) - Sum of Squares: 100.4018
#   PC1 explained variance: 68.80%
#   PC2 explained variance: 31.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.6102
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 34.7627
#   PC1 explained variance: 81.59%
#   PC2 explained variance: 18.41%
# C(treatment):C(timepoint) - Sum of Squares: 61.9159
#   PC1 explained variance: 74.27%
#   PC2 explained variance: 25.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.0804
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.4985
#   PC1 explained variance: 62.42%
#   PC2 explained variance: 37.58%
# C(treatment):C(timepoint) - Sum of Squares: 69.7323
#   PC1 explained variance: 82.19%
#   PC2 explained variance: 17.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.0806
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.1339
#   PC1 explained variance: 60.47%
#   PC2 explained variance: 39.53%
# C(treatment):C(timepoint) - Sum of Squares: 86.1851
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.4656
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 128.2963
#   PC1 explained variance: 88.88%
#   PC2 explained variance: 11.12%
# C(treatment):C(timepoint) - Sum of Squares: 77.9805
#   PC1 explained variance: 91.59%
#   PC2 explained variance: 8.41%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 88.1323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.5339
#   PC1 explained variance: 78.68%
#   PC2 explained variance: 21.32%
# C(treatment):C(timepoint) - Sum of Squares: 109.2450
#   PC1 explained variance: 87.08%
#   PC2 explained variance: 12.92%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.8497
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.5703
#   PC1 explained variance: 68.90%
#   PC2 explained variance: 31.10%
# C(treatment):C(timepoint) - Sum of Squares: 41.4442
#   PC1 explained variance: 70.54%
#   PC2 explained variance: 29.46%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 150.9762
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.2468
#   PC1 explained variance: 81.94%
#   PC2 explained variance: 18.06%
# C(treatment):C(timepoint) - Sum of Squares: 203.2224
#   PC1 explained variance: 80.03%
#   PC2 explained variance: 19.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.5539
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 105.1444
#   PC1 explained variance: 60.34%
#   PC2 explained variance: 39.66%
# C(treatment):C(timepoint) - Sum of Squares: 61.4169
#   PC1 explained variance: 75.03%
#   PC2 explained variance: 24.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.6092
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 82.1656
#   PC1 explained variance: 67.65%
#   PC2 explained variance: 32.35%
# C(treatment):C(timepoint) - Sum of Squares: 92.6206
#   PC1 explained variance: 57.93%
#   PC2 explained variance: 42.07%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 96.3889
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 194.9687
#   PC1 explained variance: 69.51%
#   PC2 explained variance: 30.49%
# C(treatment):C(timepoint) - Sum of Squares: 80.4608
#   PC1 explained variance: 70.57%
#   PC2 explained variance: 29.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 106.0029
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.0969
#   PC1 explained variance: 79.67%
#   PC2 explained variance: 20.33%
# C(treatment):C(timepoint) - Sum of Squares: 120.1617
#   PC1 explained variance: 90.43%
#   PC2 explained variance: 9.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.9269
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.7287
#   PC1 explained variance: 89.48%
#   PC2 explained variance: 10.52%
# C(treatment):C(timepoint) - Sum of Squares: 31.3438
#   PC1 explained variance: 71.63%
#   PC2 explained variance: 28.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.1983
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.0953
#   PC1 explained variance: 80.80%
#   PC2 explained variance: 19.20%
# C(treatment):C(timepoint) - Sum of Squares: 36.2068
#   PC1 explained variance: 91.62%
#   PC2 explained variance: 8.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.0944
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.6501
#   PC1 explained variance: 77.30%
#   PC2 explained variance: 22.70%
# C(treatment):C(timepoint) - Sum of Squares: 68.6838
#   PC1 explained variance: 72.91%
#   PC2 explained variance: 27.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.7903
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.9533
#   PC1 explained variance: 97.41%
#   PC2 explained variance: 2.59%
# C(treatment):C(timepoint) - Sum of Squares: 72.6324
#   PC1 explained variance: 94.05%
#   PC2 explained variance: 5.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.6203
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.2152
#   PC1 explained variance: 89.43%
#   PC2 explained variance: 10.57%
# C(treatment):C(timepoint) - Sum of Squares: 61.1255
#   PC1 explained variance: 79.38%
#   PC2 explained variance: 20.62%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 129.4940
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 118.9843
#   PC1 explained variance: 51.20%
#   PC2 explained variance: 48.80%
# C(treatment):C(timepoint) - Sum of Squares: 101.1683
#   PC1 explained variance: 69.65%
#   PC2 explained variance: 30.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.0976
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.6821
#   PC1 explained variance: 74.51%
#   PC2 explained variance: 25.49%
# C(treatment):C(timepoint) - Sum of Squares: 71.3826
#   PC1 explained variance: 89.74%
#   PC2 explained variance: 10.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.1381
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 80.8763
#   PC1 explained variance: 73.17%
#   PC2 explained variance: 26.83%
# C(treatment):C(timepoint) - Sum of Squares: 95.5416
#   PC1 explained variance: 88.18%
#   PC2 explained variance: 11.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.8415
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 137.1565
#   PC1 explained variance: 69.95%
#   PC2 explained variance: 30.05%
# C(treatment):C(timepoint) - Sum of Squares: 63.1305
#   PC1 explained variance: 78.60%
#   PC2 explained variance: 21.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0848
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.0256
#   PC1 explained variance: 67.54%
#   PC2 explained variance: 32.46%
# C(treatment):C(timepoint) - Sum of Squares: 61.8478
#   PC1 explained variance: 73.13%
#   PC2 explained variance: 26.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.0923
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 110.0554
#   PC1 explained variance: 86.80%
#   PC2 explained variance: 13.20%
# C(treatment):C(timepoint) - Sum of Squares: 75.0035
#   PC1 explained variance: 93.76%
#   PC2 explained variance: 6.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.9729
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 36.5159
#   PC1 explained variance: 58.43%
#   PC2 explained variance: 41.57%
# C(treatment):C(timepoint) - Sum of Squares: 32.8670
#   PC1 explained variance: 71.24%
#   PC2 explained variance: 28.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.6695
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 28.0609
#   PC1 explained variance: 60.97%
#   PC2 explained variance: 39.03%
# C(treatment):C(timepoint) - Sum of Squares: 44.9596
#   PC1 explained variance: 59.78%
#   PC2 explained variance: 40.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.8023
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.4681
#   PC1 explained variance: 61.51%
#   PC2 explained variance: 38.49%
# C(treatment):C(timepoint) - Sum of Squares: 53.7541
#   PC1 explained variance: 74.16%
#   PC2 explained variance: 25.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.5095
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 258.2013
#   PC1 explained variance: 90.51%
#   PC2 explained variance: 9.49%
# C(treatment):C(timepoint) - Sum of Squares: 155.7456
#   PC1 explained variance: 77.12%
#   PC2 explained variance: 22.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.5777
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.0168
#   PC1 explained variance: 65.91%
#   PC2 explained variance: 34.09%
# C(treatment):C(timepoint) - Sum of Squares: 88.8284
#   PC1 explained variance: 88.32%
#   PC2 explained variance: 11.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.2282
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.4503
#   PC1 explained variance: 68.75%
#   PC2 explained variance: 31.25%
# C(treatment):C(timepoint) - Sum of Squares: 80.1619
#   PC1 explained variance: 87.88%
#   PC2 explained variance: 12.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 98.8811
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 83.2326
#   PC1 explained variance: 83.83%
#   PC2 explained variance: 16.17%
# C(treatment):C(timepoint) - Sum of Squares: 88.8374
#   PC1 explained variance: 66.53%
#   PC2 explained variance: 33.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 133.3942
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 107.2813
#   PC1 explained variance: 53.60%
#   PC2 explained variance: 46.40%
# C(treatment):C(timepoint) - Sum of Squares: 82.5099
#   PC1 explained variance: 86.44%
#   PC2 explained variance: 13.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.1643
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.9890
#   PC1 explained variance: 60.34%
#   PC2 explained variance: 39.66%
# C(treatment):C(timepoint) - Sum of Squares: 52.0364
#   PC1 explained variance: 66.11%
#   PC2 explained variance: 33.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.6014
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 122.6156
#   PC1 explained variance: 77.89%
#   PC2 explained variance: 22.11%
# C(treatment):C(timepoint) - Sum of Squares: 146.4008
#   PC1 explained variance: 76.43%
#   PC2 explained variance: 23.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 11.1502
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.5562
#   PC1 explained variance: 73.95%
#   PC2 explained variance: 26.05%
# C(treatment):C(timepoint) - Sum of Squares: 104.2733
#   PC1 explained variance: 69.23%
#   PC2 explained variance: 30.77%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 59.1691
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.1928
#   PC1 explained variance: 56.77%
#   PC2 explained variance: 43.23%
# C(treatment):C(timepoint) - Sum of Squares: 118.4736
#   PC1 explained variance: 88.86%
#   PC2 explained variance: 11.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 83.3409
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.9356
#   PC1 explained variance: 90.80%
#   PC2 explained variance: 9.20%
# C(treatment):C(timepoint) - Sum of Squares: 147.1410
#   PC1 explained variance: 79.43%
#   PC2 explained variance: 20.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 72.1827
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.3797
#   PC1 explained variance: 63.36%
#   PC2 explained variance: 36.64%
# C(treatment):C(timepoint) - Sum of Squares: 167.9569
#   PC1 explained variance: 66.19%
#   PC2 explained variance: 33.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.7733
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.6793
#   PC1 explained variance: 66.44%
#   PC2 explained variance: 33.56%
# C(treatment):C(timepoint) - Sum of Squares: 80.1525
#   PC1 explained variance: 74.30%
#   PC2 explained variance: 25.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.1051
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.2113
#   PC1 explained variance: 64.66%
#   PC2 explained variance: 35.34%
# C(treatment):C(timepoint) - Sum of Squares: 120.9629
#   PC1 explained variance: 80.21%
#   PC2 explained variance: 19.79%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.6980
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.5284
#   PC1 explained variance: 70.65%
#   PC2 explained variance: 29.35%
# C(treatment):C(timepoint) - Sum of Squares: 54.0949
#   PC1 explained variance: 74.68%
#   PC2 explained variance: 25.32%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.0692
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.9364
#   PC1 explained variance: 80.52%
#   PC2 explained variance: 19.48%
# C(treatment):C(timepoint) - Sum of Squares: 47.2228
#   PC1 explained variance: 95.31%
#   PC2 explained variance: 4.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.5874
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.7022
#   PC1 explained variance: 88.64%
#   PC2 explained variance: 11.36%
# C(treatment):C(timepoint) - Sum of Squares: 109.1821
#   PC1 explained variance: 90.20%
#   PC2 explained variance: 9.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.9056
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.5472
#   PC1 explained variance: 80.72%
#   PC2 explained variance: 19.28%
# C(treatment):C(timepoint) - Sum of Squares: 66.1365
#   PC1 explained variance: 69.09%
#   PC2 explained variance: 30.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.3856
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.4939
#   PC1 explained variance: 63.62%
#   PC2 explained variance: 36.38%
# C(treatment):C(timepoint) - Sum of Squares: 107.7522
#   PC1 explained variance: 83.46%
#   PC2 explained variance: 16.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.8883
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.7716
#   PC1 explained variance: 90.36%
#   PC2 explained variance: 9.64%
# C(treatment):C(timepoint) - Sum of Squares: 66.8466
#   PC1 explained variance: 82.26%
#   PC2 explained variance: 17.74%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.5969
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.7536
#   PC1 explained variance: 80.74%
#   PC2 explained variance: 19.26%
# C(treatment):C(timepoint) - Sum of Squares: 92.5669
#   PC1 explained variance: 87.98%
#   PC2 explained variance: 12.02%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.3168
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.0332
#   PC1 explained variance: 74.51%
#   PC2 explained variance: 25.49%
# C(treatment):C(timepoint) - Sum of Squares: 64.0935
#   PC1 explained variance: 85.34%
#   PC2 explained variance: 14.66%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.8790
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.3961
#   PC1 explained variance: 55.91%
#   PC2 explained variance: 44.09%
# C(treatment):C(timepoint) - Sum of Squares: 47.0185
#   PC1 explained variance: 83.32%
#   PC2 explained variance: 16.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.4887
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.8698
#   PC1 explained variance: 72.76%
#   PC2 explained variance: 27.24%
# C(treatment):C(timepoint) - Sum of Squares: 54.0652
#   PC1 explained variance: 73.04%
#   PC2 explained variance: 26.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.5641
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 52.1758
#   PC1 explained variance: 78.39%
#   PC2 explained variance: 21.61%
# C(treatment):C(timepoint) - Sum of Squares: 85.6186
#   PC1 explained variance: 69.17%
#   PC2 explained variance: 30.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.2135
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.7153
#   PC1 explained variance: 71.44%
#   PC2 explained variance: 28.56%
# C(treatment):C(timepoint) - Sum of Squares: 87.0360
#   PC1 explained variance: 77.46%
#   PC2 explained variance: 22.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.9115
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.1116
#   PC1 explained variance: 71.61%
#   PC2 explained variance: 28.39%
# C(treatment):C(timepoint) - Sum of Squares: 34.3068
#   PC1 explained variance: 57.65%
#   PC2 explained variance: 42.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.6722
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.8897
#   PC1 explained variance: 67.50%
#   PC2 explained variance: 32.50%
# C(treatment):C(timepoint) - Sum of Squares: 43.0181
#   PC1 explained variance: 72.78%
#   PC2 explained variance: 27.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.4168
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.5863
#   PC1 explained variance: 71.31%
#   PC2 explained variance: 28.69%
# C(treatment):C(timepoint) - Sum of Squares: 47.7428
#   PC1 explained variance: 80.85%
#   PC2 explained variance: 19.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.1139
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 19.4607
#   PC1 explained variance: 73.55%
#   PC2 explained variance: 26.45%
# C(treatment):C(timepoint) - Sum of Squares: 39.4761
#   PC1 explained variance: 61.10%
#   PC2 explained variance: 38.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.0236
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.3325
#   PC1 explained variance: 61.09%
#   PC2 explained variance: 38.91%
# C(treatment):C(timepoint) - Sum of Squares: 90.5732
#   PC1 explained variance: 59.09%
#   PC2 explained variance: 40.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.7110
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 79.6146
#   PC1 explained variance: 87.50%
#   PC2 explained variance: 12.50%
# C(treatment):C(timepoint) - Sum of Squares: 45.0781
#   PC1 explained variance: 82.47%
#   PC2 explained variance: 17.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.1345
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 24.6737
#   PC1 explained variance: 85.63%
#   PC2 explained variance: 14.37%
# C(treatment):C(timepoint) - Sum of Squares: 23.1230
#   PC1 explained variance: 77.52%
#   PC2 explained variance: 22.48%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 76.1873
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8768
#   PC1 explained variance: 59.26%
#   PC2 explained variance: 40.74%
# C(treatment):C(timepoint) - Sum of Squares: 97.3391
#   PC1 explained variance: 91.20%
#   PC2 explained variance: 8.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.0879
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.9164
#   PC1 explained variance: 81.88%
#   PC2 explained variance: 18.12%
# C(treatment):C(timepoint) - Sum of Squares: 44.8200
#   PC1 explained variance: 70.04%
#   PC2 explained variance: 29.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 82.6659
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.4200
#   PC1 explained variance: 84.89%
#   PC2 explained variance: 15.11%
# C(treatment):C(timepoint) - Sum of Squares: 116.9591
#   PC1 explained variance: 75.73%
#   PC2 explained variance: 24.27%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2961
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.6037
#   PC1 explained variance: 79.71%
#   PC2 explained variance: 20.29%
# C(treatment):C(timepoint) - Sum of Squares: 57.4077
#   PC1 explained variance: 66.17%
#   PC2 explained variance: 33.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.0463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.8388
#   PC1 explained variance: 78.24%
#   PC2 explained variance: 21.76%
# C(treatment):C(timepoint) - Sum of Squares: 50.8574
#   PC1 explained variance: 53.06%
#   PC2 explained variance: 46.94%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.7463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.7902
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 52.8370
#   PC1 explained variance: 70.95%
#   PC2 explained variance: 29.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 75.1025
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.4943
#   PC1 explained variance: 68.76%
#   PC2 explained variance: 31.24%
# C(treatment):C(timepoint) - Sum of Squares: 31.9683
#   PC1 explained variance: 63.74%
#   PC2 explained variance: 36.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.8244
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.7738
#   PC1 explained variance: 57.76%
#   PC2 explained variance: 42.24%
# C(treatment):C(timepoint) - Sum of Squares: 46.0627
#   PC1 explained variance: 87.11%
#   PC2 explained variance: 12.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.9643
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 87.2915
#   PC1 explained variance: 69.03%
#   PC2 explained variance: 30.97%
# C(treatment):C(timepoint) - Sum of Squares: 81.1964
#   PC1 explained variance: 86.42%
#   PC2 explained variance: 13.58%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 100.0165
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 20.2013
#   PC1 explained variance: 75.09%
#   PC2 explained variance: 24.91%
# C(treatment):C(timepoint) - Sum of Squares: 91.0284
#   PC1 explained variance: 85.82%
#   PC2 explained variance: 14.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.5674
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.6836
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
# C(treatment):C(timepoint) - Sum of Squares: 67.1162
#   PC1 explained variance: 65.17%
#   PC2 explained variance: 34.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.0037
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 88.7425
#   PC1 explained variance: 64.04%
#   PC2 explained variance: 35.96%
# C(treatment):C(timepoint) - Sum of Squares: 96.4032
#   PC1 explained variance: 59.67%
#   PC2 explained variance: 40.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.3477
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 172.3101
#   PC1 explained variance: 85.24%
#   PC2 explained variance: 14.76%
# C(treatment):C(timepoint) - Sum of Squares: 90.5997
#   PC1 explained variance: 91.28%
#   PC2 explained variance: 8.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.4772
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.3400
#   PC1 explained variance: 81.86%
#   PC2 explained variance: 18.14%
# C(treatment):C(timepoint) - Sum of Squares: 67.0503
#   PC1 explained variance: 72.08%
#   PC2 explained variance: 27.92%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.3279
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.3083
#   PC1 explained variance: 60.24%
#   PC2 explained variance: 39.76%
# C(treatment):C(timepoint) - Sum of Squares: 68.1674
#   PC1 explained variance: 68.98%
#   PC2 explained variance: 31.02%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 115.9950
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.3651
#   PC1 explained variance: 59.88%
#   PC2 explained variance: 40.12%
# C(treatment):C(timepoint) - Sum of Squares: 125.7500
#   PC1 explained variance: 74.19%
#   PC2 explained variance: 25.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 121.5654
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.1756
#   PC1 explained variance: 66.54%
#   PC2 explained variance: 33.46%
# C(treatment):C(timepoint) - Sum of Squares: 145.0826
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.0745
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.4451
#   PC1 explained variance: 74.59%
#   PC2 explained variance: 25.41%
# C(treatment):C(timepoint) - Sum of Squares: 57.5403
#   PC1 explained variance: 67.64%
#   PC2 explained variance: 32.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 161.5636
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.4645
#   PC1 explained variance: 64.49%
#   PC2 explained variance: 35.51%
# C(treatment):C(timepoint) - Sum of Squares: 159.6772
#   PC1 explained variance: 94.84%
#   PC2 explained variance: 5.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.9730
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 116.7388
#   PC1 explained variance: 65.27%
#   PC2 explained variance: 34.73%
# C(treatment):C(timepoint) - Sum of Squares: 89.0334
#   PC1 explained variance: 74.91%
#   PC2 explained variance: 25.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.8126
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.0615
#   PC1 explained variance: 59.19%
#   PC2 explained variance: 40.81%
# C(treatment):C(timepoint) - Sum of Squares: 49.5193
#   PC1 explained variance: 70.04%
#   PC2 explained variance: 29.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.8843
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 82.3132
#   PC1 explained variance: 70.80%
#   PC2 explained variance: 29.20%
# C(treatment):C(timepoint) - Sum of Squares: 67.4278
#   PC1 explained variance: 83.57%
#   PC2 explained variance: 16.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 154.7291
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 259.5835
#   PC1 explained variance: 90.19%
#   PC2 explained variance: 9.81%
# C(treatment):C(timepoint) - Sum of Squares: 261.9607
#   PC1 explained variance: 93.56%
#   PC2 explained variance: 6.44%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.0679
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 113.3129
#   PC1 explained variance: 81.70%
#   PC2 explained variance: 18.30%
# C(treatment):C(timepoint) - Sum of Squares: 57.2653
#   PC1 explained variance: 77.50%
#   PC2 explained variance: 22.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.1429
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.5064
#   PC1 explained variance: 81.12%
#   PC2 explained variance: 18.88%
# C(treatment):C(timepoint) - Sum of Squares: 119.7950
#   PC1 explained variance: 92.90%
#   PC2 explained variance: 7.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.9001
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.7434
#   PC1 explained variance: 76.67%
#   PC2 explained variance: 23.33%
# C(treatment):C(timepoint) - Sum of Squares: 55.2513
#   PC1 explained variance: 93.30%
#   PC2 explained variance: 6.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.7737
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.2581
#   PC1 explained variance: 90.70%
#   PC2 explained variance: 9.30%
# C(treatment):C(timepoint) - Sum of Squares: 132.4805
#   PC1 explained variance: 83.13%
#   PC2 explained variance: 16.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 77.7771
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.9942
#   PC1 explained variance: 79.85%
#   PC2 explained variance: 20.15%
# C(treatment):C(timepoint) - Sum of Squares: 70.6955
#   PC1 explained variance: 62.92%
#   PC2 explained variance: 37.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 56.2701
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.9836
#   PC1 explained variance: 82.68%
#   PC2 explained variance: 17.32%
# C(treatment):C(timepoint) - Sum of Squares: 33.6657
#   PC1 explained variance: 84.36%
#   PC2 explained variance: 15.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.4394
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.4072
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
# C(treatment):C(timepoint) - Sum of Squares: 83.4620
#   PC1 explained variance: 63.95%
#   PC2 explained variance: 36.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.9036
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 43.1588
#   PC1 explained variance: 67.38%
#   PC2 explained variance: 32.62%
# C(treatment):C(timepoint) - Sum of Squares: 54.7247
#   PC1 explained variance: 52.50%
#   PC2 explained variance: 47.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.3547
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.9884
#   PC1 explained variance: 57.75%
#   PC2 explained variance: 42.25%
# C(treatment):C(timepoint) - Sum of Squares: 102.1661
#   PC1 explained variance: 78.90%
#   PC2 explained variance: 21.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.4475
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.3868
#   PC1 explained variance: 91.05%
#   PC2 explained variance: 8.95%
# C(treatment):C(timepoint) - Sum of Squares: 79.6215
#   PC1 explained variance: 78.77%
#   PC2 explained variance: 21.23%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0600 (not significant)
#
# ===== METHOD 3: PE-ASCA =====
#
# === PE-ASCA Analysis (Permutation-Enhanced ASCA) ===
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.2545
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 27.3329
#   PC1 explained variance: 78.49%
#   PC2 explained variance: 21.51%
# C(treatment):C(timepoint) - Sum of Squares: 29.4738
#   PC1 explained variance: 83.97%
#   PC2 explained variance: 16.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.7013
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.1399
#   PC1 explained variance: 74.90%
#   PC2 explained variance: 25.10%
# C(treatment):C(timepoint) - Sum of Squares: 111.8756
#   PC1 explained variance: 81.36%
#   PC2 explained variance: 18.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.1361
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.7540
#   PC1 explained variance: 62.81%
#   PC2 explained variance: 37.19%
# C(treatment):C(timepoint) - Sum of Squares: 48.1752
#   PC1 explained variance: 82.64%
#   PC2 explained variance: 17.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.9011
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.5508
#   PC1 explained variance: 64.13%
#   PC2 explained variance: 35.87%
# C(treatment):C(timepoint) - Sum of Squares: 17.5364
#   PC1 explained variance: 69.16%
#   PC2 explained variance: 30.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 66.1348
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.6486
#   PC1 explained variance: 85.99%
#   PC2 explained variance: 14.01%
# C(treatment):C(timepoint) - Sum of Squares: 50.9172
#   PC1 explained variance: 74.25%
#   PC2 explained variance: 25.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.1784
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 172.8445
#   PC1 explained variance: 59.52%
#   PC2 explained variance: 40.48%
# C(treatment):C(timepoint) - Sum of Squares: 126.7074
#   PC1 explained variance: 94.72%
#   PC2 explained variance: 5.28%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.7101
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.1722
#   PC1 explained variance: 63.71%
#   PC2 explained variance: 36.29%
# C(treatment):C(timepoint) - Sum of Squares: 37.0255
#   PC1 explained variance: 54.58%
#   PC2 explained variance: 45.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 172.2891
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 145.9829
#   PC1 explained variance: 92.95%
#   PC2 explained variance: 7.05%
# C(treatment):C(timepoint) - Sum of Squares: 108.9758
#   PC1 explained variance: 89.92%
#   PC2 explained variance: 10.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.4650
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.9447
#   PC1 explained variance: 70.25%
#   PC2 explained variance: 29.75%
# C(treatment):C(timepoint) - Sum of Squares: 53.3156
#   PC1 explained variance: 55.77%
#   PC2 explained variance: 44.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.0620
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8393
#   PC1 explained variance: 78.12%
#   PC2 explained variance: 21.88%
# C(treatment):C(timepoint) - Sum of Squares: 119.6388
#   PC1 explained variance: 78.86%
#   PC2 explained variance: 21.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.3314
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 30.8562
#   PC1 explained variance: 91.02%
#   PC2 explained variance: 8.98%
# C(treatment):C(timepoint) - Sum of Squares: 57.7767
#   PC1 explained variance: 55.04%
#   PC2 explained variance: 44.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.2414
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.8524
#   PC1 explained variance: 90.01%
#   PC2 explained variance: 9.99%
# C(treatment):C(timepoint) - Sum of Squares: 110.3825
#   PC1 explained variance: 93.76%
#   PC2 explained variance: 6.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.4075
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.9352
#   PC1 explained variance: 73.77%
#   PC2 explained variance: 26.23%
# C(treatment):C(timepoint) - Sum of Squares: 47.1571
#   PC1 explained variance: 91.51%
#   PC2 explained variance: 8.49%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.8346
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.4181
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
# C(treatment):C(timepoint) - Sum of Squares: 33.9097
#   PC1 explained variance: 57.71%
#   PC2 explained variance: 42.29%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 97.4321
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.3464
#   PC1 explained variance: 63.43%
#   PC2 explained variance: 36.57%
# C(treatment):C(timepoint) - Sum of Squares: 130.0520
#   PC1 explained variance: 83.87%
#   PC2 explained variance: 16.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.9729
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.6007
#   PC1 explained variance: 91.02%
#   PC2 explained variance: 8.98%
# C(treatment):C(timepoint) - Sum of Squares: 64.2794
#   PC1 explained variance: 58.87%
#   PC2 explained variance: 41.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 138.9466
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 102.7825
#   PC1 explained variance: 90.47%
#   PC2 explained variance: 9.53%
# C(treatment):C(timepoint) - Sum of Squares: 124.1681
#   PC1 explained variance: 86.05%
#   PC2 explained variance: 13.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.7009
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 107.5537
#   PC1 explained variance: 65.70%
#   PC2 explained variance: 34.30%
# C(treatment):C(timepoint) - Sum of Squares: 52.8664
#   PC1 explained variance: 66.19%
#   PC2 explained variance: 33.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.6536
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.3649
#   PC1 explained variance: 63.73%
#   PC2 explained variance: 36.27%
# C(treatment):C(timepoint) - Sum of Squares: 110.5032
#   PC1 explained variance: 84.89%
#   PC2 explained variance: 15.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.6185
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 87.3657
#   PC1 explained variance: 69.15%
#   PC2 explained variance: 30.85%
# C(treatment):C(timepoint) - Sum of Squares: 104.8970
#   PC1 explained variance: 62.88%
#   PC2 explained variance: 37.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.6099
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 52.8385
#   PC1 explained variance: 69.85%
#   PC2 explained variance: 30.15%
# C(treatment):C(timepoint) - Sum of Squares: 109.3501
#   PC1 explained variance: 71.22%
#   PC2 explained variance: 28.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.3221
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.5187
#   PC1 explained variance: 54.20%
#   PC2 explained variance: 45.80%
# C(treatment):C(timepoint) - Sum of Squares: 61.2196
#   PC1 explained variance: 66.32%
#   PC2 explained variance: 33.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.4296
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 108.5456
#   PC1 explained variance: 78.22%
#   PC2 explained variance: 21.78%
# C(treatment):C(timepoint) - Sum of Squares: 92.0795
#   PC1 explained variance: 69.47%
#   PC2 explained variance: 30.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.1214
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.3653
#   PC1 explained variance: 76.30%
#   PC2 explained variance: 23.70%
# C(treatment):C(timepoint) - Sum of Squares: 61.7190
#   PC1 explained variance: 83.11%
#   PC2 explained variance: 16.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.4795
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.0259
#   PC1 explained variance: 80.46%
#   PC2 explained variance: 19.54%
# C(treatment):C(timepoint) - Sum of Squares: 116.8375
#   PC1 explained variance: 68.16%
#   PC2 explained variance: 31.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.5356
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.3898
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 69.8600
#   PC1 explained variance: 61.30%
#   PC2 explained variance: 38.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.9924
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.6166
#   PC1 explained variance: 82.73%
#   PC2 explained variance: 17.27%
# C(treatment):C(timepoint) - Sum of Squares: 62.0948
#   PC1 explained variance: 64.14%
#   PC2 explained variance: 35.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.9945
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.1001
#   PC1 explained variance: 61.14%
#   PC2 explained variance: 38.86%
# C(treatment):C(timepoint) - Sum of Squares: 64.4625
#   PC1 explained variance: 72.00%
#   PC2 explained variance: 28.00%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.2137
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.6902
#   PC1 explained variance: 80.22%
#   PC2 explained variance: 19.78%
# C(treatment):C(timepoint) - Sum of Squares: 76.4132
#   PC1 explained variance: 87.92%
#   PC2 explained variance: 12.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 16.0991
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.3942
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
# C(treatment):C(timepoint) - Sum of Squares: 39.7173
#   PC1 explained variance: 86.61%
#   PC2 explained variance: 13.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.6300
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 131.5219
#   PC1 explained variance: 79.77%
#   PC2 explained variance: 20.23%
# C(treatment):C(timepoint) - Sum of Squares: 79.3282
#   PC1 explained variance: 75.14%
#   PC2 explained variance: 24.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 123.8235
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 189.9530
#   PC1 explained variance: 81.02%
#   PC2 explained variance: 18.98%
# C(treatment):C(timepoint) - Sum of Squares: 174.2882
#   PC1 explained variance: 80.03%
#   PC2 explained variance: 19.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.4799
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 106.3065
#   PC1 explained variance: 88.89%
# ...
#   PC1 explained variance: 74.72%
#   PC2 explained variance: 25.28%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.4385
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.3685
#   PC1 explained variance: 70.85%
#   PC2 explained variance: 29.15%
# C(treatment):C(timepoint) - Sum of Squares: 62.9679
#   PC1 explained variance: 59.80%
#   PC2 explained variance: 40.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.8172
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.9868
#   PC1 explained variance: 65.05%
#   PC2 explained variance: 34.95%
# C(treatment):C(timepoint) - Sum of Squares: 77.5605
#   PC1 explained variance: 88.84%
#   PC2 explained variance: 11.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6198
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 44.9746
#   PC1 explained variance: 67.23%
#   PC2 explained variance: 32.77%
# C(treatment):C(timepoint) - Sum of Squares: 73.3071
#   PC1 explained variance: 90.12%
#   PC2 explained variance: 9.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 112.1787
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.2843
#   PC1 explained variance: 88.73%
#   PC2 explained variance: 11.27%
# C(treatment):C(timepoint) - Sum of Squares: 145.7468
#   PC1 explained variance: 84.83%
#   PC2 explained variance: 15.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 92.7923
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8309
#   PC1 explained variance: 68.40%
#   PC2 explained variance: 31.60%
# C(treatment):C(timepoint) - Sum of Squares: 54.1722
#   PC1 explained variance: 75.47%
#   PC2 explained variance: 24.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.8420
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.4897
#   PC1 explained variance: 60.04%
#   PC2 explained variance: 39.96%
# C(treatment):C(timepoint) - Sum of Squares: 64.2805
#   PC1 explained variance: 54.18%
#   PC2 explained variance: 45.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.9798
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.8588
#   PC1 explained variance: 71.36%
#   PC2 explained variance: 28.64%
# C(treatment):C(timepoint) - Sum of Squares: 136.3190
#   PC1 explained variance: 57.61%
#   PC2 explained variance: 42.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.7355
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.3260
#   PC1 explained variance: 88.75%
#   PC2 explained variance: 11.25%
# C(treatment):C(timepoint) - Sum of Squares: 87.5063
#   PC1 explained variance: 94.97%
#   PC2 explained variance: 5.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.7606
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.3878
#   PC1 explained variance: 67.27%
#   PC2 explained variance: 32.73%
# C(treatment):C(timepoint) - Sum of Squares: 46.7964
#   PC1 explained variance: 55.16%
#   PC2 explained variance: 44.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.4731
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.5275
#   PC1 explained variance: 60.81%
#   PC2 explained variance: 39.19%
# C(treatment):C(timepoint) - Sum of Squares: 40.2915
#   PC1 explained variance: 83.53%
#   PC2 explained variance: 16.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.5775
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.0589
#   PC1 explained variance: 81.41%
#   PC2 explained variance: 18.59%
# C(treatment):C(timepoint) - Sum of Squares: 89.0888
#   PC1 explained variance: 95.05%
#   PC2 explained variance: 4.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.4983
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.0859
#   PC1 explained variance: 67.05%
#   PC2 explained variance: 32.95%
# C(treatment):C(timepoint) - Sum of Squares: 126.2874
#   PC1 explained variance: 90.09%
#   PC2 explained variance: 9.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.1746
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.1026
#   PC1 explained variance: 83.49%
#   PC2 explained variance: 16.51%
# C(treatment):C(timepoint) - Sum of Squares: 42.1619
#   PC1 explained variance: 78.87%
#   PC2 explained variance: 21.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.2323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.3496
#   PC1 explained variance: 92.92%
#   PC2 explained variance: 7.08%
# C(treatment):C(timepoint) - Sum of Squares: 73.4514
#   PC1 explained variance: 75.10%
#   PC2 explained variance: 24.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.8108
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.4396
#   PC1 explained variance: 57.89%
#   PC2 explained variance: 42.11%
# C(treatment):C(timepoint) - Sum of Squares: 82.9862
#   PC1 explained variance: 72.33%
#   PC2 explained variance: 27.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.7679
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 98.9390
#   PC1 explained variance: 79.47%
#   PC2 explained variance: 20.53%
# C(treatment):C(timepoint) - Sum of Squares: 102.2909
#   PC1 explained variance: 75.53%
#   PC2 explained variance: 24.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.5054
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 39.9591
#   PC1 explained variance: 67.87%
#   PC2 explained variance: 32.13%
# C(treatment):C(timepoint) - Sum of Squares: 77.7079
#   PC1 explained variance: 74.83%
#   PC2 explained variance: 25.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.8095
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.7352
#   PC1 explained variance: 58.17%
#   PC2 explained variance: 41.83%
# C(treatment):C(timepoint) - Sum of Squares: 58.6922
#   PC1 explained variance: 67.60%
#   PC2 explained variance: 32.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 207.6415
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.5652
#   PC1 explained variance: 74.97%
#   PC2 explained variance: 25.03%
# C(treatment):C(timepoint) - Sum of Squares: 164.7368
#   PC1 explained variance: 91.18%
#   PC2 explained variance: 8.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 138.5167
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.6042
#   PC1 explained variance: 78.59%
#   PC2 explained variance: 21.41%
# C(treatment):C(timepoint) - Sum of Squares: 105.0695
#   PC1 explained variance: 91.13%
#   PC2 explained variance: 8.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.2061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.0477
#   PC1 explained variance: 56.43%
#   PC2 explained variance: 43.57%
# C(treatment):C(timepoint) - Sum of Squares: 52.2624
#   PC1 explained variance: 78.95%
#   PC2 explained variance: 21.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.2227
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.8702
#   PC1 explained variance: 72.77%
#   PC2 explained variance: 27.23%
# C(treatment):C(timepoint) - Sum of Squares: 66.1411
#   PC1 explained variance: 87.84%
#   PC2 explained variance: 12.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6855
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 111.5940
#   PC1 explained variance: 89.99%
#   PC2 explained variance: 10.01%
# C(treatment):C(timepoint) - Sum of Squares: 81.2256
#   PC1 explained variance: 77.78%
#   PC2 explained variance: 22.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.5325
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 118.7682
#   PC1 explained variance: 87.20%
#   PC2 explained variance: 12.80%
# C(treatment):C(timepoint) - Sum of Squares: 42.0798
#   PC1 explained variance: 73.57%
#   PC2 explained variance: 26.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.2930
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.6663
#   PC1 explained variance: 75.66%
#   PC2 explained variance: 24.34%
# C(treatment):C(timepoint) - Sum of Squares: 93.5337
#   PC1 explained variance: 68.82%
#   PC2 explained variance: 31.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.2881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 88.6973
#   PC1 explained variance: 71.00%
#   PC2 explained variance: 29.00%
# C(treatment):C(timepoint) - Sum of Squares: 82.1089
#   PC1 explained variance: 82.92%
#   PC2 explained variance: 17.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 128.7708
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 121.5047
#   PC1 explained variance: 80.21%
#   PC2 explained variance: 19.79%
# C(treatment):C(timepoint) - Sum of Squares: 228.6359
#   PC1 explained variance: 92.29%
#   PC2 explained variance: 7.71%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.8738
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 38.5953
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 55.6615
#   PC1 explained variance: 62.30%
#   PC2 explained variance: 37.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.7559
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 109.8221
#   PC1 explained variance: 90.07%
#   PC2 explained variance: 9.93%
# C(treatment):C(timepoint) - Sum of Squares: 131.8791
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.1000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.4753
#   PC1 explained variance: 79.63%
#   PC2 explained variance: 20.37%
# C(treatment):C(timepoint) - Sum of Squares: 55.2224
#   PC1 explained variance: 74.39%
#   PC2 explained variance: 25.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.8653
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.3050
#   PC1 explained variance: 58.18%
#   PC2 explained variance: 41.82%
# C(treatment):C(timepoint) - Sum of Squares: 116.5312
#   PC1 explained variance: 75.17%
#   PC2 explained variance: 24.83%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0700 (not significant)
# Effect C(treatment) is significant (p=0.0100) and included in enhanced model
# Effect C(timepoint) is significant (p=0.0100) and included in enhanced model
# Effect C(treatment):C(timepoint) is not significant (p=0.0700) and added to residuals
# C(treatment) - Sum of Squares: 592.6881 (35.97% of total)
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804 (35.93% of total)
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
#
# ===== METHOD 4: LiMM-PCA =====
#
# === LiMM-PCA Analysis (Linear Mixed Models with PCA) ===
# Processing feature 1/10...
# Error fitting model for feature_1: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_1 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_2: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_2 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_3: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_3 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Processing feature 4/10...
# Error fitting model for feature_4: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_4 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_5: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_5 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_6: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_6 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Processing feature 7/10...
# Error fitting model for feature_7: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_7 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_8: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_8 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Error fitting model for feature_9: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_9 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                 ^^^^^^^^^^^^
# Processing feature 10/10...
# Error fitting model for feature_10: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'treatment' is not defined
#     feature_10 ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)
#                  ^^^^^^^^^^^^
#
# Variance Partition:
# Fixed Effects: 0.00%
# Random Effects: 0.00%
# Residuals: 100.00%
#
# PCA on Fixed Effects:
# PC1 explained variance: nan%
# PC2 explained variance: nan%
#
# ===== METHOD 5: MSCA =====
#
# === MSCA Analysis (Multilevel Simultaneous Component Analysis) ===
#
# Variance Partition:
# Between-subject: 51.77%
# Within-subject: 48.23%
#
# PCA on Between-subject Variation:
# PC1 explained variance: 53.02%
# PC2 explained variance: 13.09%
#
# PCA on Within-subject Variation:
# PC1 explained variance: 52.73%
# PC2 explained variance: 23.16%

# %% [markdown]
# New

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols, mixedlm
from statsmodels.stats.anova import anova_lm
import random
from scipy.linalg import svd
import warnings
warnings.filterwarnings('ignore')

# Load the synthetic data
df = pd.read_csv('synthetic_multivariate_data.csv')

# Extract feature columns
feature_cols = [col for col in df.columns if 'feature' in col]
X = df[feature_cols].values

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create a data matrix for easier handling
X_matrix = pd.DataFrame(X_scaled, columns=feature_cols)
X_matrix['subject_id'] = df['subject_id']
X_matrix['treatment'] = df['treatment']
X_matrix['timepoint'] = df['timepoint']

print("Data prepared for analysis.")
print("Number of samples:", X_matrix.shape[0])
print("Number of features:", len(feature_cols))
print("Factors: treatment, timepoint, subject_id")

# ============ ASCA: ANOVA-Simultaneous Component Analysis ============

def asca(data, formula, design_cols, feature_cols):
    """
    Implement ASCA (ANOVA-Simultaneous Component Analysis)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features

    Returns:
    --------
    Dictionary containing:
    - effect_matrices: matrices for each effect
    - pca_results: PCA results for each effect
    - explained_var: explained variance for each effect
    - total_variance: total variance of the data
    """
    print("\n=== ASCA Analysis ===")

    # Extract design and data matrices
    X = data[feature_cols].values
    n_samples, n_features = X.shape

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Fit the ANOVA model for each feature
    effect_matrices = {}
    anova_summaries = []

    # ANOVA decomposition
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model
        model = ols(feature_formula, data=data).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        # Store ANOVA summary for this feature
        if feature_idx == 0:  # Only store once
            anova_summaries.append(anova_table)

    # Extract effects from ANOVA model
    # Create empty matrices for each effect
    effects = ['C(treatment)', 'C(timepoint)', 'C(treatment):C(timepoint)', 'Residual']
    effect_matrices = {effect: np.zeros((n_samples, n_features)) for effect in effects}

    # Fill effect matrices feature by feature
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model for this feature
        model = ols(feature_formula, data=data).fit()

        # Get predicted values for each effect
        # Treatment effect
        treatment_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            param_name = f"C(treatment)[T.{treatment}]"
            if param_name in model.params:
                treatment_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment)'][:, feature_idx] = treatment_effect

        # Timepoint effect
        timepoint_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            timepoint = row['timepoint']
            param_name = f"C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                timepoint_effect[idx] = model.params[param_name]
        effect_matrices['C(timepoint)'][:, feature_idx] = timepoint_effect

        # Interaction effect
        interaction_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            timepoint = row['timepoint']
            param_name = f"C(treatment)[T.{treatment}]:C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                interaction_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment):C(timepoint)'][:, feature_idx] = interaction_effect

        # Residual effect
        effect_matrices['Residual'][:, feature_idx] = model.resid

    # Apply PCA to each effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in effect_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            print(f"{effect} - Sum of Squares: {effect_ss:.4f}")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Calculate total variance
    total_variance = np.sum(X_centered**2)

    return {
        'effect_matrices': effect_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'total_variance': total_variance,
        'anova_summaries': anova_summaries
    }

# ============ ASCA+ (ASCA with Significance Testing) ============

def asca_plus(data, formula, design_cols, feature_cols, n_permutations=999):
    """
    Implement ASCA+ (ASCA with permutation testing)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing

    Returns:
    --------
    Dictionary containing ASCA results plus permutation test results
    """
    print("\n=== ASCA+ Analysis (ASCA with Permutation Testing) ===")

    # Run standard ASCA
    asca_results = asca(data, formula, design_cols, feature_cols)

    # Get effect matrices and calculate sum of squares for each effect
    effect_matrices = asca_results['effect_matrices']
    observed_ss = {effect: np.sum(matrix**2) for effect, matrix in effect_matrices.items()
                 if effect != 'Residual'}

    # Permutation testing
    permuted_ss = {effect: [] for effect in observed_ss.keys()}

    print(f"\nRunning permutation tests with {n_permutations} permutations...")

    for perm in range(n_permutations):
        if perm % 100 == 0 and perm > 0:
            print(f"  Completed {perm} permutations")

        # Create permuted data
        perm_data = data.copy()

        # Permute each factor separately
        for effect in observed_ss.keys():
            if effect == 'C(treatment)':
                # Permute treatment labels
                perm_data['treatment'] = np.random.permutation(perm_data['treatment'].values)
            elif effect == 'C(timepoint)':
                # Permute timepoint labels
                perm_data['timepoint'] = np.random.permutation(perm_data['timepoint'].values)
            elif effect == 'C(treatment):C(timepoint)':
                # Permute interaction by shuffling combinations
                combinations = perm_data[['treatment', 'timepoint']].values
                np.random.shuffle(combinations)
                perm_data['treatment'] = combinations[:, 0]
                perm_data['timepoint'] = combinations[:, 1]

        # Run ASCA on permuted data
        perm_asca = asca(perm_data, formula, design_cols, feature_cols)
        perm_effect_matrices = perm_asca['effect_matrices']

        # Calculate sum of squares for each permuted effect
        for effect in observed_ss.keys():
            perm_ss = np.sum(perm_effect_matrices[effect]**2)
            permuted_ss[effect].append(perm_ss)

    # Calculate p-values
    p_values = {}
    for effect in observed_ss.keys():
        # Count how many permuted SS are >= observed SS
        p_values[effect] = (np.sum(np.array(permuted_ss[effect]) >= observed_ss[effect]) + 1) / (n_permutations + 1)

    print("\nPermutation Test Results:")
    for effect, p_value in p_values.items():
        significance = "significant" if p_value < 0.05 else "not significant"
        print(f"{effect}: p-value = {p_value:.4f} ({significance})")

    # Add results to ASCA results
    asca_results['p_values'] = p_values
    asca_results['permuted_ss'] = permuted_ss

    return asca_results

# ============ PE-ASCA (Permutation-Enhanced ASCA) ============

def pe_asca(data, formula, design_cols, feature_cols, n_permutations=999, alpha=0.05):
    """
    Implement PE-ASCA (Permutation-Enhanced ASCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing
    alpha: float
        Significance level

    Returns:
    --------
    Dictionary containing PE-ASCA results
    """
    print("\n=== PE-ASCA Analysis (Permutation-Enhanced ASCA) ===")

    # First, run ASCA+ to get permutation test results
    asca_plus_results = asca_plus(data, formula, design_cols, feature_cols, n_permutations)

    # Extract relevant information
    effect_matrices = asca_plus_results['effect_matrices']
    p_values = asca_plus_results['p_values']

    # Enhanced decomposition: only keep significant effects
    enhanced_matrices = {}
    for effect, p_value in p_values.items():
        if p_value <= alpha:
            enhanced_matrices[effect] = effect_matrices[effect]
            print(f"Effect {effect} is significant (p={p_value:.4f}) and included in enhanced model")
        else:
            # Add non-significant effects to residuals
            if 'Residual' not in enhanced_matrices:
                enhanced_matrices['Residual'] = effect_matrices[effect].copy()
            else:
                enhanced_matrices['Residual'] += effect_matrices[effect]
            print(f"Effect {effect} is not significant (p={p_value:.4f}) and added to residuals")

    # Add original residuals if not already included
    if 'Residual' not in enhanced_matrices:
        enhanced_matrices['Residual'] = effect_matrices['Residual']
    else:
        enhanced_matrices['Residual'] += effect_matrices['Residual']

    # Apply PCA to each significant effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in enhanced_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            total_ss = np.sum([np.sum(m**2) for m in enhanced_matrices.values()])
            print(f"{effect} - Sum of Squares: {effect_ss:.4f} ({effect_ss/total_ss*100:.2f}% of total)")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Create result structure
    pe_asca_results = {
        'effect_matrices': enhanced_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'p_values': p_values,
        'total_variance': asca_plus_results['total_variance']
    }

    return pe_asca_results

# ============ LiMM-PCA (Linear Mixed Models with PCA) ============

def limm_pca(data, feature_cols, verbose=True):
    """
    Implement LiMM-PCA (Linear Mixed Models with PCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing LiMM-PCA results
    """
    if verbose:
        print("\n=== LiMM-PCA Analysis (Linear Mixed Models with PCA) ===")

    # Extract data matrix
    X = data[feature_cols].values

    # Standardize the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Initialize containers for results
    fixed_effects = {}
    random_effects = {}
    residuals = {}
    pvalues = {}

    # Apply mixed model to each feature
    for i, feature in enumerate(feature_cols):
        if verbose and i % 3 == 0:
            print(f"Processing feature {i+1}/{len(feature_cols)}...")

        # Create mixed model formula
        formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit mixed effects model
        try:
            # Convert categorical variables to string to ensure proper handling
            data_copy = data.copy()
            if isinstance(data_copy['treatment'].iloc[0], str) == False:
                data_copy['treatment'] = data_copy['treatment'].astype(str)
            if isinstance(data_copy['timepoint'].iloc[0], str) == False:
                data_copy['timepoint'] = data_copy['timepoint'].astype(str)
            if isinstance(data_copy['subject_id'].iloc[0], str) == False:
                data_copy['subject_id'] = data_copy['subject_id'].astype(str)

            model = mixedlm(formula, data_copy, groups=data_copy['subject_id'])
            result = model.fit(reml=True)

            # Extract fixed effects
            fixed_pred = result.fittedvalues - result.random_effects[data_copy['subject_id'].values].flatten()
            fixed_effects[feature] = fixed_pred

            # Extract random effects (subject)
            subject_effect = np.zeros(len(data_copy))
            for idx, subj in enumerate(data_copy['subject_id']):
                subject_effect[idx] = result.random_effects[subj][0]
            random_effects[feature] = subject_effect

            # Extract residuals
            residuals[feature] = result.resid

            # Store p-values for fixed effects
            pvalues[feature] = result.pvalues

        except Exception as e:
            if verbose:
                print(f"Error fitting model for {feature}: {e}")
            # Use simpler approach if model fails
            fixed_effects[feature] = np.zeros(len(data))
            random_effects[feature] = np.zeros(len(data))
            residuals[feature] = X_scaled[:, i]

    # Convert to matrices
    fixed_matrix = np.column_stack([fixed_effects[feature] for feature in feature_cols])
    random_matrix = np.column_stack([random_effects[feature] for feature in feature_cols])
    resid_matrix = np.column_stack([residuals[feature] for feature in feature_cols])

    # Calculate variance explained
    total_var = np.sum(X_scaled**2)
    fixed_var = np.sum(fixed_matrix**2)
    random_var = np.sum(random_matrix**2)
    resid_var = np.sum(resid_matrix**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Fixed Effects: {fixed_var/total_var*100:.2f}%")
        print(f"Random Effects: {random_var/total_var*100:.2f}%")
        print(f"Residuals: {resid_var/total_var*100:.2f}%")

    # Apply PCA to fixed effects matrix
    pca_fixed = PCA()
    pca_fixed.fit(fixed_matrix)

    if verbose:
        print("\nPCA on Fixed Effects:")
        print(f"PC1 explained variance: {pca_fixed.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_fixed.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_fixed.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'fixed_matrix': fixed_matrix,
        'random_matrix': random_matrix,
        'resid_matrix': resid_matrix,
        'pca_fixed': pca_fixed,
        'fixed_scores': pca_fixed.transform(fixed_matrix),
        'total_var': total_var,
        'fixed_var': fixed_var,
        'random_var': random_var,
        'resid_var': resid_var
    }

    return results

# ============ MSCA (Multilevel Simultaneous Component Analysis) ============

def msca(data, feature_cols, verbose=True):
    """
    Implement MSCA (Multilevel Simultaneous Component Analysis)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing MSCA results
    """
    if verbose:
        print("\n=== MSCA Analysis (Multilevel Simultaneous Component Analysis) ===")

    # Extract data
    X = data[feature_cols].values
    subjects = data['subject_id'].unique()
    n_subjects = len(subjects)

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Split data into between-subject and within-subject parts
    X_between = np.zeros_like(X)
    X_within = np.zeros_like(X)

    # Calculate between-subject variation (level 2)
    for subject in subjects:
        subject_indices = data['subject_id'] == subject
        subject_mean = np.mean(X[subject_indices], axis=0)
        X_between[subject_indices] = subject_mean

    # Calculate within-subject variation (level 1)
    X_within = X - X_between

    # Calculate variance explained by each level
    total_var = np.sum(X_centered**2)
    between_var = np.sum(X_between**2)
    within_var = np.sum(X_within**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Between-subject: {between_var/total_var*100:.2f}%")
        print(f"Within-subject: {within_var/total_var*100:.2f}%")

    # Apply PCA to between-subject variation
    pca_between = PCA()
    between_scores = pca_between.fit_transform(X_between)

    # Apply PCA to within-subject variation
    pca_within = PCA()
    within_scores = pca_within.fit_transform(X_within)

    if verbose:
        print("\nPCA on Between-subject Variation:")
        print(f"PC1 explained variance: {pca_between.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_between.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_between.explained_variance_ratio_[1]*100:.2f}%")

        print("\nPCA on Within-subject Variation:")
        print(f"PC1 explained variance: {pca_within.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_within.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_within.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'X_between': X_between,
        'X_within': X_within,
        'pca_between': pca_between,
        'pca_within': pca_within,
        'between_scores': between_scores,
        'within_scores': within_scores,
        'total_var': total_var,
        'between_var': between_var,
        'within_var': within_var
    }

    return results

# Run all methods on the synthetic data

print("\n==== RUNNING ALL METHODS ON THE SYNTHETIC DATASET ====")

# Prepare formula and design columns for ASCA methods
formula = "~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"
design_cols = ['treatment', 'timepoint', 'subject_id']

# Run each method
print("\n===== METHOD 1: ASCA =====")
asca_results = asca(X_matrix, formula, design_cols, feature_cols)

print("\n===== METHOD 2: ASCA+ =====")
asca_plus_results = asca_plus(X_matrix, formula, design_cols, feature_cols, n_permutations=99)  # Reduced for computation

print("\n===== METHOD 3: PE-ASCA =====")
pe_asca_results = pe_asca(X_matrix, formula, design_cols, feature_cols, n_permutations=99, alpha=0.05)  # Reduced for computation

print("\n===== METHOD 4: LiMM-PCA =====")
limm_pca_results = limm_pca(X_matrix, feature_cols)

print("\n===== METHOD 5: MSCA =====")
msca_results = msca(X_matrix, feature_cols)
# Out:
# Data prepared for analysis.
# Number of samples: 90
# Number of features: 10
# Factors: treatment, timepoint, subject_id
#
# ==== RUNNING ALL METHODS ON THE SYNTHETIC DATASET ====
#
# ===== METHOD 1: ASCA =====
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# ===== METHOD 2: ASCA+ =====
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.2406
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.7752
#   PC1 explained variance: 82.00%
#   PC2 explained variance: 18.00%
# C(treatment):C(timepoint) - Sum of Squares: 82.1474
#   PC1 explained variance: 89.69%
#   PC2 explained variance: 10.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.1216
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 119.3476
#   PC1 explained variance: 76.02%
#   PC2 explained variance: 23.98%
# C(treatment):C(timepoint) - Sum of Squares: 80.7992
#   PC1 explained variance: 69.62%
#   PC2 explained variance: 30.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.0026
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.1658
#   PC1 explained variance: 53.71%
#   PC2 explained variance: 46.29%
# C(treatment):C(timepoint) - Sum of Squares: 54.2212
#   PC1 explained variance: 57.09%
#   PC2 explained variance: 42.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.8492
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 95.3448
#   PC1 explained variance: 59.35%
#   PC2 explained variance: 40.65%
# C(treatment):C(timepoint) - Sum of Squares: 72.8433
#   PC1 explained variance: 68.60%
#   PC2 explained variance: 31.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.3246
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.8694
#   PC1 explained variance: 85.86%
#   PC2 explained variance: 14.14%
# C(treatment):C(timepoint) - Sum of Squares: 69.5646
#   PC1 explained variance: 79.49%
#   PC2 explained variance: 20.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.4828
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.9309
#   PC1 explained variance: 78.37%
#   PC2 explained variance: 21.63%
# C(treatment):C(timepoint) - Sum of Squares: 49.5714
#   PC1 explained variance: 79.30%
#   PC2 explained variance: 20.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.8096
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.1998
#   PC1 explained variance: 73.38%
#   PC2 explained variance: 26.62%
# C(treatment):C(timepoint) - Sum of Squares: 57.8525
#   PC1 explained variance: 70.15%
#   PC2 explained variance: 29.85%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 9.9100
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.7486
#   PC1 explained variance: 90.61%
#   PC2 explained variance: 9.39%
# C(treatment):C(timepoint) - Sum of Squares: 60.7831
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.1752
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.4800
#   PC1 explained variance: 78.84%
#   PC2 explained variance: 21.16%
# C(treatment):C(timepoint) - Sum of Squares: 135.9940
#   PC1 explained variance: 63.16%
#   PC2 explained variance: 36.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.2192
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.5029
#   PC1 explained variance: 81.80%
#   PC2 explained variance: 18.20%
# C(treatment):C(timepoint) - Sum of Squares: 63.0739
#   PC1 explained variance: 76.94%
#   PC2 explained variance: 23.06%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 166.4390
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 161.5291
#   PC1 explained variance: 71.04%
#   PC2 explained variance: 28.96%
# C(treatment):C(timepoint) - Sum of Squares: 181.2184
#   PC1 explained variance: 92.49%
#   PC2 explained variance: 7.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.6083
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.9458
#   PC1 explained variance: 70.21%
#   PC2 explained variance: 29.79%
# C(treatment):C(timepoint) - Sum of Squares: 41.2522
#   PC1 explained variance: 79.44%
#   PC2 explained variance: 20.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 175.6346
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.2532
#   PC1 explained variance: 82.40%
#   PC2 explained variance: 17.60%
# C(treatment):C(timepoint) - Sum of Squares: 272.8960
#   PC1 explained variance: 94.03%
#   PC2 explained variance: 5.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.4468
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.5610
#   PC1 explained variance: 65.22%
#   PC2 explained variance: 34.78%
# C(treatment):C(timepoint) - Sum of Squares: 92.5868
#   PC1 explained variance: 66.58%
#   PC2 explained variance: 33.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 25.5869
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.6274
#   PC1 explained variance: 81.71%
#   PC2 explained variance: 18.29%
# C(treatment):C(timepoint) - Sum of Squares: 82.2202
#   PC1 explained variance: 75.79%
#   PC2 explained variance: 24.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.8918
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.3935
#   PC1 explained variance: 74.77%
#   PC2 explained variance: 25.23%
# C(treatment):C(timepoint) - Sum of Squares: 58.4307
#   PC1 explained variance: 82.97%
#   PC2 explained variance: 17.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.1659
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.8450
#   PC1 explained variance: 79.91%
#   PC2 explained variance: 20.09%
# C(treatment):C(timepoint) - Sum of Squares: 67.5709
#   PC1 explained variance: 57.41%
#   PC2 explained variance: 42.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.5256
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 141.0589
#   PC1 explained variance: 84.53%
#   PC2 explained variance: 15.47%
# C(treatment):C(timepoint) - Sum of Squares: 58.2580
#   PC1 explained variance: 83.20%
#   PC2 explained variance: 16.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.7323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 112.2728
#   PC1 explained variance: 72.21%
#   PC2 explained variance: 27.79%
# C(treatment):C(timepoint) - Sum of Squares: 109.0906
#   PC1 explained variance: 69.08%
#   PC2 explained variance: 30.92%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.7012
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.0870
#   PC1 explained variance: 59.57%
#   PC2 explained variance: 40.43%
# C(treatment):C(timepoint) - Sum of Squares: 40.3273
#   PC1 explained variance: 63.80%
#   PC2 explained variance: 36.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.9430
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 75.0060
#   PC1 explained variance: 67.18%
#   PC2 explained variance: 32.82%
# C(treatment):C(timepoint) - Sum of Squares: 108.2753
#   PC1 explained variance: 75.35%
#   PC2 explained variance: 24.65%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.9530
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 19.7540
#   PC1 explained variance: 83.31%
#   PC2 explained variance: 16.69%
# C(treatment):C(timepoint) - Sum of Squares: 96.2376
#   PC1 explained variance: 80.76%
#   PC2 explained variance: 19.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.6651
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 116.8437
#   PC1 explained variance: 71.46%
#   PC2 explained variance: 28.54%
# C(treatment):C(timepoint) - Sum of Squares: 72.0598
#   PC1 explained variance: 86.95%
#   PC2 explained variance: 13.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.9276
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.3673
#   PC1 explained variance: 72.67%
#   PC2 explained variance: 27.33%
# C(treatment):C(timepoint) - Sum of Squares: 35.3981
#   PC1 explained variance: 85.81%
#   PC2 explained variance: 14.19%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 116.6810
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 123.2656
#   PC1 explained variance: 86.81%
#   PC2 explained variance: 13.19%
# C(treatment):C(timepoint) - Sum of Squares: 103.3679
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 109.7912
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.6118
#   PC1 explained variance: 57.44%
#   PC2 explained variance: 42.56%
# C(treatment):C(timepoint) - Sum of Squares: 172.6227
#   PC1 explained variance: 72.20%
#   PC2 explained variance: 27.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.5111
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 173.8670
#   PC1 explained variance: 78.25%
#   PC2 explained variance: 21.75%
# C(treatment):C(timepoint) - Sum of Squares: 69.1889
#   PC1 explained variance: 69.58%
#   PC2 explained variance: 30.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2070
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.5124
#   PC1 explained variance: 84.93%
#   PC2 explained variance: 15.07%
# C(treatment):C(timepoint) - Sum of Squares: 55.6828
#   PC1 explained variance: 74.83%
#   PC2 explained variance: 25.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.0588
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 154.8941
#   PC1 explained variance: 86.77%
#   PC2 explained variance: 13.23%
# C(treatment):C(timepoint) - Sum of Squares: 105.1223
#   PC1 explained variance: 95.56%
#   PC2 explained variance: 4.44%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.3968
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 79.6579
#   PC1 explained variance: 71.57%
#   PC2 explained variance: 28.43%
# C(treatment):C(timepoint) - Sum of Squares: 58.1766
#   PC1 explained variance: 85.19%
#   PC2 explained variance: 14.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.7066
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.0574
#   PC1 explained variance: 80.56%
#   PC2 explained variance: 19.44%
# C(treatment):C(timepoint) - Sum of Squares: 50.2784
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.9512
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.8427
#   PC1 explained variance: 75.84%
#   PC2 explained variance: 24.16%
# C(treatment):C(timepoint) - Sum of Squares: 52.2038
#   PC1 explained variance: 79.25%
#   PC2 explained variance: 20.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 184.2065
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.6361
#   PC1 explained variance: 84.35%
#   PC2 explained variance: 15.65%
# C(treatment):C(timepoint) - Sum of Squares: 168.4762
#   PC1 explained variance: 93.57%
#   PC2 explained variance: 6.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 105.4030
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.3991
#   PC1 explained variance: 70.46%
#   PC2 explained variance: 29.54%
# C(treatment):C(timepoint) - Sum of Squares: 108.9449
#   PC1 explained variance: 93.32%
#   PC2 explained variance: 6.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.9670
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 108.5947
#   PC1 explained variance: 88.07%
#   PC2 explained variance: 11.93%
# C(treatment):C(timepoint) - Sum of Squares: 131.3705
#   PC1 explained variance: 85.00%
#   PC2 explained variance: 15.00%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.4555
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.6671
#   PC1 explained variance: 92.78%
#   PC2 explained variance: 7.22%
# C(treatment):C(timepoint) - Sum of Squares: 89.6421
#   PC1 explained variance: 76.83%
#   PC2 explained variance: 23.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.7892
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 163.8768
#   PC1 explained variance: 79.92%
#   PC2 explained variance: 20.08%
# C(treatment):C(timepoint) - Sum of Squares: 107.8400
#   PC1 explained variance: 85.50%
#   PC2 explained variance: 14.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.4357
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 40.4407
#   PC1 explained variance: 73.77%
#   PC2 explained variance: 26.23%
# C(treatment):C(timepoint) - Sum of Squares: 56.4461
#   PC1 explained variance: 58.20%
#   PC2 explained variance: 41.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.4680
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.9426
#   PC1 explained variance: 68.33%
#   PC2 explained variance: 31.67%
# C(treatment):C(timepoint) - Sum of Squares: 90.9603
#   PC1 explained variance: 61.10%
#   PC2 explained variance: 38.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.2793
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.6794
#   PC1 explained variance: 67.35%
#   PC2 explained variance: 32.65%
# C(treatment):C(timepoint) - Sum of Squares: 40.8106
#   PC1 explained variance: 89.28%
#   PC2 explained variance: 10.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.9238
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.7943
#   PC1 explained variance: 67.20%
#   PC2 explained variance: 32.80%
# C(treatment):C(timepoint) - Sum of Squares: 33.5440
#   PC1 explained variance: 58.79%
#   PC2 explained variance: 41.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.0046
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 122.5340
#   PC1 explained variance: 59.83%
#   PC2 explained variance: 40.17%
# C(treatment):C(timepoint) - Sum of Squares: 118.7886
#   PC1 explained variance: 92.07%
#   PC2 explained variance: 7.93%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 5.7345
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.0115
#   PC1 explained variance: 86.71%
#   PC2 explained variance: 13.29%
# C(treatment):C(timepoint) - Sum of Squares: 60.0838
#   PC1 explained variance: 90.52%
#   PC2 explained variance: 9.48%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.3082
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8690
#   PC1 explained variance: 75.11%
#   PC2 explained variance: 24.89%
# C(treatment):C(timepoint) - Sum of Squares: 69.6241
#   PC1 explained variance: 82.31%
#   PC2 explained variance: 17.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.9323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.0022
#   PC1 explained variance: 78.22%
#   PC2 explained variance: 21.78%
# C(treatment):C(timepoint) - Sum of Squares: 65.8509
#   PC1 explained variance: 56.14%
#   PC2 explained variance: 43.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.8514
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.7031
#   PC1 explained variance: 71.21%
#   PC2 explained variance: 28.79%
# C(treatment):C(timepoint) - Sum of Squares: 78.6381
#   PC1 explained variance: 69.90%
#   PC2 explained variance: 30.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.3182
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.4558
#   PC1 explained variance: 70.76%
#   PC2 explained variance: 29.24%
# C(treatment):C(timepoint) - Sum of Squares: 55.2327
#   PC1 explained variance: 77.45%
#   PC2 explained variance: 22.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 92.5148
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.2117
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
# C(treatment):C(timepoint) - Sum of Squares: 114.8594
#   PC1 explained variance: 89.70%
#   PC2 explained variance: 10.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.4000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.4675
#   PC1 explained variance: 79.56%
#   PC2 explained variance: 20.44%
# C(treatment):C(timepoint) - Sum of Squares: 144.6204
#   PC1 explained variance: 82.78%
#   PC2 explained variance: 17.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.8105
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.5721
#   PC1 explained variance: 73.11%
#   PC2 explained variance: 26.89%
# C(treatment):C(timepoint) - Sum of Squares: 64.5267
#   PC1 explained variance: 83.36%
#   PC2 explained variance: 16.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.6693
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.6785
#   PC1 explained variance: 89.00%
#   PC2 explained variance: 11.00%
# C(treatment):C(timepoint) - Sum of Squares: 150.1809
#   PC1 explained variance: 91.37%
#   PC2 explained variance: 8.63%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 107.7567
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 114.5357
#   PC1 explained variance: 63.08%
#   PC2 explained variance: 36.92%
# C(treatment):C(timepoint) - Sum of Squares: 203.0186
#   PC1 explained variance: 72.07%
#   PC2 explained variance: 27.93%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.9058
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 44.5217
#   PC1 explained variance: 66.05%
#   PC2 explained variance: 33.95%
# C(treatment):C(timepoint) - Sum of Squares: 39.7067
#   PC1 explained variance: 61.88%
#   PC2 explained variance: 38.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.8872
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 185.1426
#   PC1 explained variance: 88.19%
#   PC2 explained variance: 11.81%
# C(treatment):C(timepoint) - Sum of Squares: 254.9074
#   PC1 explained variance: 94.91%
#   PC2 explained variance: 5.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.7287
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.9797
#   PC1 explained variance: 76.71%
#   PC2 explained variance: 23.29%
# C(treatment):C(timepoint) - Sum of Squares: 33.9515
#   PC1 explained variance: 53.69%
#   PC2 explained variance: 46.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 192.6848
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 170.9497
#   PC1 explained variance: 82.08%
#   PC2 explained variance: 17.92%
# C(treatment):C(timepoint) - Sum of Squares: 175.0752
#   PC1 explained variance: 82.88%
#   PC2 explained variance: 17.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.7342
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.9406
#   PC1 explained variance: 67.91%
#   PC2 explained variance: 32.09%
# C(treatment):C(timepoint) - Sum of Squares: 87.2268
#   PC1 explained variance: 63.01%
#   PC2 explained variance: 36.99%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0143
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.9813
#   PC1 explained variance: 59.58%
#   PC2 explained variance: 40.42%
# C(treatment):C(timepoint) - Sum of Squares: 56.4085
#   PC1 explained variance: 85.03%
#   PC2 explained variance: 14.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.5567
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.7754
#   PC1 explained variance: 78.31%
#   PC2 explained variance: 21.69%
# C(treatment):C(timepoint) - Sum of Squares: 83.1012
#   PC1 explained variance: 86.41%
#   PC2 explained variance: 13.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.6632
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 100.2729
#   PC1 explained variance: 81.60%
#   PC2 explained variance: 18.40%
# C(treatment):C(timepoint) - Sum of Squares: 93.2210
#   PC1 explained variance: 84.58%
#   PC2 explained variance: 15.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.7683
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 38.0568
#   PC1 explained variance: 65.98%
#   PC2 explained variance: 34.02%
# C(treatment):C(timepoint) - Sum of Squares: 70.5775
#   PC1 explained variance: 80.27%
#   PC2 explained variance: 19.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.4762
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.3809
#   PC1 explained variance: 72.41%
#   PC2 explained variance: 27.59%
# C(treatment):C(timepoint) - Sum of Squares: 96.4162
#   PC1 explained variance: 96.57%
#   PC2 explained variance: 3.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.3851
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 35.3250
#   PC1 explained variance: 61.89%
#   PC2 explained variance: 38.11%
# C(treatment):C(timepoint) - Sum of Squares: 36.9236
#   PC1 explained variance: 70.55%
#   PC2 explained variance: 29.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.3062
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.3488
#   PC1 explained variance: 87.39%
#   PC2 explained variance: 12.61%
# C(treatment):C(timepoint) - Sum of Squares: 80.4566
#   PC1 explained variance: 84.49%
#   PC2 explained variance: 15.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.2922
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.3893
#   PC1 explained variance: 74.82%
#   PC2 explained variance: 25.18%
# C(treatment):C(timepoint) - Sum of Squares: 85.3232
#   PC1 explained variance: 54.16%
#   PC2 explained variance: 45.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.6488
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.6103
#   PC1 explained variance: 69.61%
#   PC2 explained variance: 30.39%
# C(treatment):C(timepoint) - Sum of Squares: 79.4090
#   PC1 explained variance: 75.06%
#   PC2 explained variance: 24.94%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.2094
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 138.8943
#   PC1 explained variance: 57.20%
#   PC2 explained variance: 42.80%
# C(treatment):C(timepoint) - Sum of Squares: 145.5113
#   PC1 explained variance: 76.44%
#   PC2 explained variance: 23.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.7023
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.3081
#   PC1 explained variance: 71.12%
#   PC2 explained variance: 28.88%
# C(treatment):C(timepoint) - Sum of Squares: 164.7540
#   PC1 explained variance: 93.91%
#   PC2 explained variance: 6.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.9061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 64.0057
#   PC1 explained variance: 80.07%
#   PC2 explained variance: 19.93%
# C(treatment):C(timepoint) - Sum of Squares: 36.4484
#   PC1 explained variance: 87.89%
#   PC2 explained variance: 12.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 49.9245
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.6083
#   PC1 explained variance: 84.85%
#   PC2 explained variance: 15.15%
# C(treatment):C(timepoint) - Sum of Squares: 52.4485
#   PC1 explained variance: 73.02%
#   PC2 explained variance: 26.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.3538
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.8536
#   PC1 explained variance: 81.79%
#   PC2 explained variance: 18.21%
# C(treatment):C(timepoint) - Sum of Squares: 35.3170
#   PC1 explained variance: 68.66%
#   PC2 explained variance: 31.34%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 94.0596
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.0056
#   PC1 explained variance: 57.42%
#   PC2 explained variance: 42.58%
# C(treatment):C(timepoint) - Sum of Squares: 91.9101
#   PC1 explained variance: 86.16%
#   PC2 explained variance: 13.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 10.0145
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.5832
#   PC1 explained variance: 87.73%
#   PC2 explained variance: 12.27%
# C(treatment):C(timepoint) - Sum of Squares: 37.9410
#   PC1 explained variance: 81.85%
#   PC2 explained variance: 18.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6416
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.2199
#   PC1 explained variance: 74.98%
#   PC2 explained variance: 25.02%
# C(treatment):C(timepoint) - Sum of Squares: 63.7353
#   PC1 explained variance: 78.50%
#   PC2 explained variance: 21.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.2402
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.0284
#   PC1 explained variance: 60.33%
#   PC2 explained variance: 39.67%
# C(treatment):C(timepoint) - Sum of Squares: 75.9066
#   PC1 explained variance: 69.66%
#   PC2 explained variance: 30.34%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.9160
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.9625
#   PC1 explained variance: 74.76%
#   PC2 explained variance: 25.24%
# C(treatment):C(timepoint) - Sum of Squares: 105.6830
#   PC1 explained variance: 78.27%
#   PC2 explained variance: 21.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.0030
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.7798
#   PC1 explained variance: 62.39%
#   PC2 explained variance: 37.61%
# C(treatment):C(timepoint) - Sum of Squares: 132.9635
#   PC1 explained variance: 81.70%
#   PC2 explained variance: 18.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.4467
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.2838
#   PC1 explained variance: 73.75%
#   PC2 explained variance: 26.25%
# C(treatment):C(timepoint) - Sum of Squares: 85.3961
#   PC1 explained variance: 83.69%
#   PC2 explained variance: 16.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 36.1530
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 84.4957
#   PC1 explained variance: 76.54%
#   PC2 explained variance: 23.46%
# C(treatment):C(timepoint) - Sum of Squares: 55.5767
#   PC1 explained variance: 71.31%
#   PC2 explained variance: 28.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 72.9467
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.2745
#   PC1 explained variance: 75.36%
#   PC2 explained variance: 24.64%
# C(treatment):C(timepoint) - Sum of Squares: 71.6495
#   PC1 explained variance: 78.10%
#   PC2 explained variance: 21.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.0871
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 168.3153
#   PC1 explained variance: 94.61%
#   PC2 explained variance: 5.39%
# C(treatment):C(timepoint) - Sum of Squares: 84.4454
#   PC1 explained variance: 86.22%
#   PC2 explained variance: 13.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.1703
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.8168
#   PC1 explained variance: 72.29%
#   PC2 explained variance: 27.71%
# C(treatment):C(timepoint) - Sum of Squares: 56.9122
#   PC1 explained variance: 75.34%
#   PC2 explained variance: 24.66%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 25.1927
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.1611
#   PC1 explained variance: 66.47%
#   PC2 explained variance: 33.53%
# C(treatment):C(timepoint) - Sum of Squares: 44.0158
#   PC1 explained variance: 61.02%
#   PC2 explained variance: 38.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.4053
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 250.3561
#   PC1 explained variance: 82.28%
#   PC2 explained variance: 17.72%
# C(treatment):C(timepoint) - Sum of Squares: 86.1859
#   PC1 explained variance: 68.26%
#   PC2 explained variance: 31.74%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.5002
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.0789
#   PC1 explained variance: 67.16%
#   PC2 explained variance: 32.84%
# C(treatment):C(timepoint) - Sum of Squares: 44.9918
#   PC1 explained variance: 84.17%
#   PC2 explained variance: 15.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.8895
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.7758
#   PC1 explained variance: 87.50%
#   PC2 explained variance: 12.50%
# C(treatment):C(timepoint) - Sum of Squares: 68.2090
#   PC1 explained variance: 64.15%
#   PC2 explained variance: 35.85%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 66.2017
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 36.1451
#   PC1 explained variance: 76.36%
#   PC2 explained variance: 23.64%
# C(treatment):C(timepoint) - Sum of Squares: 56.5073
#   PC1 explained variance: 70.64%
#   PC2 explained variance: 29.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.1320
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.2681
#   PC1 explained variance: 67.55%
#   PC2 explained variance: 32.45%
# C(treatment):C(timepoint) - Sum of Squares: 40.2181
#   PC1 explained variance: 80.40%
#   PC2 explained variance: 19.60%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.2590
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.1288
#   PC1 explained variance: 75.28%
#   PC2 explained variance: 24.72%
# C(treatment):C(timepoint) - Sum of Squares: 145.1008
#   PC1 explained variance: 91.55%
#   PC2 explained variance: 8.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 18.2269
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 145.9336
#   PC1 explained variance: 69.30%
#   PC2 explained variance: 30.70%
# C(treatment):C(timepoint) - Sum of Squares: 35.6192
#   PC1 explained variance: 75.14%
#   PC2 explained variance: 24.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.7463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.7320
#   PC1 explained variance: 68.92%
#   PC2 explained variance: 31.08%
# C(treatment):C(timepoint) - Sum of Squares: 34.3647
#   PC1 explained variance: 75.68%
#   PC2 explained variance: 24.32%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.6688
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.5957
#   PC1 explained variance: 57.38%
#   PC2 explained variance: 42.62%
# C(treatment):C(timepoint) - Sum of Squares: 85.6425
#   PC1 explained variance: 81.13%
#   PC2 explained variance: 18.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.9668
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.2716
#   PC1 explained variance: 69.60%
#   PC2 explained variance: 30.40%
# C(treatment):C(timepoint) - Sum of Squares: 32.1763
#   PC1 explained variance: 67.25%
#   PC2 explained variance: 32.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 12.7014
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 100.6886
#   PC1 explained variance: 78.94%
#   PC2 explained variance: 21.06%
# C(treatment):C(timepoint) - Sum of Squares: 48.8603
#   PC1 explained variance: 89.22%
#   PC2 explained variance: 10.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.6955
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.5567
#   PC1 explained variance: 89.99%
#   PC2 explained variance: 10.01%
# C(treatment):C(timepoint) - Sum of Squares: 78.5186
#   PC1 explained variance: 83.11%
#   PC2 explained variance: 16.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.9663
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 96.6414
#   PC1 explained variance: 74.03%
#   PC2 explained variance: 25.97%
# C(treatment):C(timepoint) - Sum of Squares: 88.0031
#   PC1 explained variance: 66.14%
#   PC2 explained variance: 33.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 118.5173
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.1647
#   PC1 explained variance: 79.28%
#   PC2 explained variance: 20.72%
# C(treatment):C(timepoint) - Sum of Squares: 68.7249
#   PC1 explained variance: 78.89%
#   PC2 explained variance: 21.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.0634
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.3267
#   PC1 explained variance: 67.39%
#   PC2 explained variance: 32.61%
# C(treatment):C(timepoint) - Sum of Squares: 122.6578
#   PC1 explained variance: 60.45%
#   PC2 explained variance: 39.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.0578
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.0832
#   PC1 explained variance: 67.44%
#   PC2 explained variance: 32.56%
# C(treatment):C(timepoint) - Sum of Squares: 64.6168
#   PC1 explained variance: 64.49%
#   PC2 explained variance: 35.51%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.1000 (not significant)
#
# ===== METHOD 3: PE-ASCA =====
#
# === PE-ASCA Analysis (Permutation-Enhanced ASCA) ===
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 49.2947
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7215
#   PC1 explained variance: 61.77%
#   PC2 explained variance: 38.23%
# C(treatment):C(timepoint) - Sum of Squares: 79.9093
#   PC1 explained variance: 64.47%
#   PC2 explained variance: 35.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 104.5620
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 102.3960
#   PC1 explained variance: 67.39%
#   PC2 explained variance: 32.61%
# C(treatment):C(timepoint) - Sum of Squares: 98.2144
#   PC1 explained variance: 80.32%
#   PC2 explained variance: 19.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.3569
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.7327
#   PC1 explained variance: 61.67%
#   PC2 explained variance: 38.33%
# C(treatment):C(timepoint) - Sum of Squares: 40.8871
#   PC1 explained variance: 61.92%
#   PC2 explained variance: 38.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.6031
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.1464
#   PC1 explained variance: 81.29%
#   PC2 explained variance: 18.71%
# C(treatment):C(timepoint) - Sum of Squares: 46.6305
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.1229
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.4551
#   PC1 explained variance: 83.74%
#   PC2 explained variance: 16.26%
# C(treatment):C(timepoint) - Sum of Squares: 96.9734
#   PC1 explained variance: 90.55%
#   PC2 explained variance: 9.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 123.1694
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.2184
#   PC1 explained variance: 79.00%
#   PC2 explained variance: 21.00%
# C(treatment):C(timepoint) - Sum of Squares: 137.9866
#   PC1 explained variance: 78.45%
#   PC2 explained variance: 21.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 115.7939
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.8034
#   PC1 explained variance: 63.50%
#   PC2 explained variance: 36.50%
# C(treatment):C(timepoint) - Sum of Squares: 72.7242
#   PC1 explained variance: 80.16%
#   PC2 explained variance: 19.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.6196
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.6583
#   PC1 explained variance: 52.73%
#   PC2 explained variance: 47.27%
# C(treatment):C(timepoint) - Sum of Squares: 53.4075
#   PC1 explained variance: 82.05%
#   PC2 explained variance: 17.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.4662
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.7651
#   PC1 explained variance: 74.54%
#   PC2 explained variance: 25.46%
# C(treatment):C(timepoint) - Sum of Squares: 69.3219
#   PC1 explained variance: 85.67%
#   PC2 explained variance: 14.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 9.5544
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.7727
#   PC1 explained variance: 78.02%
#   PC2 explained variance: 21.98%
# C(treatment):C(timepoint) - Sum of Squares: 69.1643
#   PC1 explained variance: 62.13%
#   PC2 explained variance: 37.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.3531
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.0991
#   PC1 explained variance: 70.57%
#   PC2 explained variance: 29.43%
# C(treatment):C(timepoint) - Sum of Squares: 60.7556
#   PC1 explained variance: 81.47%
#   PC2 explained variance: 18.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 100.5456
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7985
#   PC1 explained variance: 50.79%
#   PC2 explained variance: 49.21%
# C(treatment):C(timepoint) - Sum of Squares: 124.6717
#   PC1 explained variance: 70.70%
#   PC2 explained variance: 29.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.5738
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 80.8509
#   PC1 explained variance: 61.59%
#   PC2 explained variance: 38.41%
# C(treatment):C(timepoint) - Sum of Squares: 51.8927
#   PC1 explained variance: 76.19%
#   PC2 explained variance: 23.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.5933
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.8780
#   PC1 explained variance: 87.70%
#   PC2 explained variance: 12.30%
# C(treatment):C(timepoint) - Sum of Squares: 40.8761
#   PC1 explained variance: 62.90%
#   PC2 explained variance: 37.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.1089
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.2473
#   PC1 explained variance: 79.44%
#   PC2 explained variance: 20.56%
# C(treatment):C(timepoint) - Sum of Squares: 52.7229
#   PC1 explained variance: 86.12%
#   PC2 explained variance: 13.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.9980
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.3284
#   PC1 explained variance: 67.99%
#   PC2 explained variance: 32.01%
# C(treatment):C(timepoint) - Sum of Squares: 28.2435
#   PC1 explained variance: 68.95%
#   PC2 explained variance: 31.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.3037
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.4803
#   PC1 explained variance: 78.57%
#   PC2 explained variance: 21.43%
# C(treatment):C(timepoint) - Sum of Squares: 54.9183
#   PC1 explained variance: 78.23%
#   PC2 explained variance: 21.77%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.4900
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.8932
#   PC1 explained variance: 65.84%
#   PC2 explained variance: 34.16%
# C(treatment):C(timepoint) - Sum of Squares: 61.0347
#   PC1 explained variance: 67.78%
#   PC2 explained variance: 32.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 56.1040
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.4448
#   PC1 explained variance: 74.62%
#   PC2 explained variance: 25.38%
# C(treatment):C(timepoint) - Sum of Squares: 64.5216
#   PC1 explained variance: 79.67%
#   PC2 explained variance: 20.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.3521
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 33.5562
#   PC1 explained variance: 87.55%
#   PC2 explained variance: 12.45%
# C(treatment):C(timepoint) - Sum of Squares: 84.1905
#   PC1 explained variance: 67.73%
#   PC2 explained variance: 32.27%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.3488
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.3861
#   PC1 explained variance: 83.69%
#   PC2 explained variance: 16.31%
# C(treatment):C(timepoint) - Sum of Squares: 117.8758
#   PC1 explained variance: 92.33%
#   PC2 explained variance: 7.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 119.7560
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.4994
#   PC1 explained variance: 64.97%
#   PC2 explained variance: 35.03%
# C(treatment):C(timepoint) - Sum of Squares: 101.7801
#   PC1 explained variance: 90.28%
#   PC2 explained variance: 9.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.4274
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 292.2594
#   PC1 explained variance: 80.77%
#   PC2 explained variance: 19.23%
# C(treatment):C(timepoint) - Sum of Squares: 274.1979
#   PC1 explained variance: 93.41%
#   PC2 explained variance: 6.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.2691
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.4632
#   PC1 explained variance: 60.79%
#   PC2 explained variance: 39.21%
# C(treatment):C(timepoint) - Sum of Squares: 40.5269
#   PC1 explained variance: 52.17%
#   PC2 explained variance: 47.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.4748
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.5931
#   PC1 explained variance: 75.28%
#   PC2 explained variance: 24.72%
# C(treatment):C(timepoint) - Sum of Squares: 78.1761
#   PC1 explained variance: 82.65%
#   PC2 explained variance: 17.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 104.3061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.7680
#   PC1 explained variance: 83.58%
#   PC2 explained variance: 16.42%
# C(treatment):C(timepoint) - Sum of Squares: 166.3818
#   PC1 explained variance: 92.21%
#   PC2 explained variance: 7.79%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.0712
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.6801
#   PC1 explained variance: 85.09%
#   PC2 explained variance: 14.91%
# C(treatment):C(timepoint) - Sum of Squares: 25.5896
#   PC1 explained variance: 63.92%
#   PC2 explained variance: 36.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.8358
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.0702
#   PC1 explained variance: 71.00%
#   PC2 explained variance: 29.00%
# C(treatment):C(timepoint) - Sum of Squares: 70.7602
#   PC1 explained variance: 70.46%
#   PC2 explained variance: 29.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.2134
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.5668
#   PC1 explained variance: 71.18%
#   PC2 explained variance: 28.82%
# C(treatment):C(timepoint) - Sum of Squares: 87.9664
#   PC1 explained variance: 65.44%
#   PC2 explained variance: 34.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.0694
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.5833
#   PC1 explained variance: 85.87%
#   PC2 explained variance: 14.13%
# C(treatment):C(timepoint) - Sum of Squares: 63.9424
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.3805
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.5281
#   PC1 explained variance: 71.86%
#   PC2 explained variance: 28.14%
# C(treatment):C(timepoint) - Sum of Squares: 78.4305
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.0706
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.7534
#   PC1 explained variance: 80.23%
#   PC2 explained variance: 19.77%
# C(treatment):C(timepoint) - Sum of Squares: 33.6868
#   PC1 explained variance: 78.33%
#   PC2 explained variance: 21.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.6780
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.4774
# ...
# C(timepoint) - Sum of Squares: 69.2602
#   PC1 explained variance: 68.95%
#   PC2 explained variance: 31.05%
# C(treatment):C(timepoint) - Sum of Squares: 63.1520
#   PC1 explained variance: 74.10%
#   PC2 explained variance: 25.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.9237
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 95.5056
#   PC1 explained variance: 60.68%
#   PC2 explained variance: 39.32%
# C(treatment):C(timepoint) - Sum of Squares: 136.6338
#   PC1 explained variance: 90.09%
#   PC2 explained variance: 9.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 88.1704
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.1625
#   PC1 explained variance: 58.49%
#   PC2 explained variance: 41.51%
# C(treatment):C(timepoint) - Sum of Squares: 101.6801
#   PC1 explained variance: 76.77%
#   PC2 explained variance: 23.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 47.6582
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.3988
#   PC1 explained variance: 76.76%
#   PC2 explained variance: 23.24%
# C(treatment):C(timepoint) - Sum of Squares: 47.2619
#   PC1 explained variance: 77.14%
#   PC2 explained variance: 22.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.7100
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.0689
#   PC1 explained variance: 62.95%
#   PC2 explained variance: 37.05%
# C(treatment):C(timepoint) - Sum of Squares: 120.3598
#   PC1 explained variance: 85.24%
#   PC2 explained variance: 14.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.8829
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 120.4077
#   PC1 explained variance: 77.76%
#   PC2 explained variance: 22.24%
# C(treatment):C(timepoint) - Sum of Squares: 77.6796
#   PC1 explained variance: 82.41%
#   PC2 explained variance: 17.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.4400
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 137.8710
#   PC1 explained variance: 83.19%
#   PC2 explained variance: 16.81%
# C(treatment):C(timepoint) - Sum of Squares: 110.3439
#   PC1 explained variance: 91.43%
#   PC2 explained variance: 8.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 76.1432
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.2186
#   PC1 explained variance: 93.52%
#   PC2 explained variance: 6.48%
# C(treatment):C(timepoint) - Sum of Squares: 86.8230
#   PC1 explained variance: 81.99%
#   PC2 explained variance: 18.01%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 102.0603
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.8807
#   PC1 explained variance: 78.11%
#   PC2 explained variance: 21.89%
# C(treatment):C(timepoint) - Sum of Squares: 87.8910
#   PC1 explained variance: 79.61%
#   PC2 explained variance: 20.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.5836
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.0955
#   PC1 explained variance: 64.09%
#   PC2 explained variance: 35.91%
# C(treatment):C(timepoint) - Sum of Squares: 89.7561
#   PC1 explained variance: 73.79%
#   PC2 explained variance: 26.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.8809
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8847
#   PC1 explained variance: 68.70%
#   PC2 explained variance: 31.30%
# C(treatment):C(timepoint) - Sum of Squares: 111.9250
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.3107
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.2221
#   PC1 explained variance: 73.84%
#   PC2 explained variance: 26.16%
# C(treatment):C(timepoint) - Sum of Squares: 33.5333
#   PC1 explained variance: 61.64%
#   PC2 explained variance: 38.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.2305
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.6220
#   PC1 explained variance: 80.90%
#   PC2 explained variance: 19.10%
# C(treatment):C(timepoint) - Sum of Squares: 62.6292
#   PC1 explained variance: 82.43%
#   PC2 explained variance: 17.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.6755
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.6832
#   PC1 explained variance: 79.61%
#   PC2 explained variance: 20.39%
# C(treatment):C(timepoint) - Sum of Squares: 36.2975
#   PC1 explained variance: 76.14%
#   PC2 explained variance: 23.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 82.0695
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 169.7588
#   PC1 explained variance: 65.47%
#   PC2 explained variance: 34.53%
# C(treatment):C(timepoint) - Sum of Squares: 100.5631
#   PC1 explained variance: 70.18%
#   PC2 explained variance: 29.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.2536
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 154.5043
#   PC1 explained variance: 65.99%
#   PC2 explained variance: 34.01%
# C(treatment):C(timepoint) - Sum of Squares: 100.4817
#   PC1 explained variance: 77.38%
#   PC2 explained variance: 22.62%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.9171
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.9731
#   PC1 explained variance: 79.94%
#   PC2 explained variance: 20.06%
# C(treatment):C(timepoint) - Sum of Squares: 55.1832
#   PC1 explained variance: 90.63%
#   PC2 explained variance: 9.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.7000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.0747
#   PC1 explained variance: 73.10%
#   PC2 explained variance: 26.90%
# C(treatment):C(timepoint) - Sum of Squares: 104.1923
#   PC1 explained variance: 74.57%
#   PC2 explained variance: 25.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 86.1368
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.3396
#   PC1 explained variance: 56.55%
#   PC2 explained variance: 43.45%
# C(treatment):C(timepoint) - Sum of Squares: 80.8967
#   PC1 explained variance: 81.75%
#   PC2 explained variance: 18.25%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.2401
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.8405
#   PC1 explained variance: 89.21%
#   PC2 explained variance: 10.79%
# C(treatment):C(timepoint) - Sum of Squares: 79.3683
#   PC1 explained variance: 83.86%
#   PC2 explained variance: 16.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.8464
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.6921
#   PC1 explained variance: 73.60%
#   PC2 explained variance: 26.40%
# C(treatment):C(timepoint) - Sum of Squares: 57.0193
#   PC1 explained variance: 82.92%
#   PC2 explained variance: 17.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.7517
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.0911
#   PC1 explained variance: 69.21%
#   PC2 explained variance: 30.79%
# C(treatment):C(timepoint) - Sum of Squares: 75.8686
#   PC1 explained variance: 92.48%
#   PC2 explained variance: 7.52%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 124.4198
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.9115
#   PC1 explained variance: 54.25%
#   PC2 explained variance: 45.75%
# C(treatment):C(timepoint) - Sum of Squares: 167.4655
#   PC1 explained variance: 88.90%
#   PC2 explained variance: 11.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.0554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.0043
#   PC1 explained variance: 71.45%
#   PC2 explained variance: 28.55%
# C(treatment):C(timepoint) - Sum of Squares: 89.1698
#   PC1 explained variance: 80.02%
#   PC2 explained variance: 19.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.6886
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.8459
#   PC1 explained variance: 85.54%
#   PC2 explained variance: 14.46%
# C(treatment):C(timepoint) - Sum of Squares: 108.7505
#   PC1 explained variance: 65.85%
#   PC2 explained variance: 34.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.0839
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.8811
#   PC1 explained variance: 61.64%
#   PC2 explained variance: 38.36%
# C(treatment):C(timepoint) - Sum of Squares: 90.1772
#   PC1 explained variance: 85.87%
#   PC2 explained variance: 14.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.7535
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.4711
#   PC1 explained variance: 75.57%
#   PC2 explained variance: 24.43%
# C(treatment):C(timepoint) - Sum of Squares: 77.6781
#   PC1 explained variance: 73.12%
#   PC2 explained variance: 26.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.0652
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 26.3034
#   PC1 explained variance: 85.09%
#   PC2 explained variance: 14.91%
# C(treatment):C(timepoint) - Sum of Squares: 53.9173
#   PC1 explained variance: 74.25%
#   PC2 explained variance: 25.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.9520
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.6682
#   PC1 explained variance: 56.52%
#   PC2 explained variance: 43.48%
# C(treatment):C(timepoint) - Sum of Squares: 95.8840
#   PC1 explained variance: 63.82%
#   PC2 explained variance: 36.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 106.0836
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.3751
#   PC1 explained variance: 84.53%
#   PC2 explained variance: 15.47%
# C(treatment):C(timepoint) - Sum of Squares: 132.1044
#   PC1 explained variance: 81.33%
#   PC2 explained variance: 18.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.8853
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 33.2320
#   PC1 explained variance: 53.47%
#   PC2 explained variance: 46.53%
# C(treatment):C(timepoint) - Sum of Squares: 45.0746
#   PC1 explained variance: 83.22%
#   PC2 explained variance: 16.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.9886
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7221
#   PC1 explained variance: 74.95%
#   PC2 explained variance: 25.05%
# C(treatment):C(timepoint) - Sum of Squares: 129.4101
#   PC1 explained variance: 90.30%
#   PC2 explained variance: 9.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 16.1806
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.9546
#   PC1 explained variance: 83.20%
#   PC2 explained variance: 16.80%
# C(treatment):C(timepoint) - Sum of Squares: 35.5608
#   PC1 explained variance: 67.16%
#   PC2 explained variance: 32.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.8187
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.3044
#   PC1 explained variance: 90.88%
#   PC2 explained variance: 9.12%
# C(treatment):C(timepoint) - Sum of Squares: 112.9431
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.5554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.9289
#   PC1 explained variance: 90.95%
#   PC2 explained variance: 9.05%
# C(treatment):C(timepoint) - Sum of Squares: 86.6625
#   PC1 explained variance: 74.91%
#   PC2 explained variance: 25.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.3713
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.3385
#   PC1 explained variance: 72.00%
#   PC2 explained variance: 28.00%
# C(treatment):C(timepoint) - Sum of Squares: 93.4994
#   PC1 explained variance: 73.91%
#   PC2 explained variance: 26.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.0186
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 148.7258
#   PC1 explained variance: 81.33%
#   PC2 explained variance: 18.67%
# C(treatment):C(timepoint) - Sum of Squares: 42.7511
#   PC1 explained variance: 76.53%
#   PC2 explained variance: 23.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.9986
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.5059
#   PC1 explained variance: 79.60%
#   PC2 explained variance: 20.40%
# C(treatment):C(timepoint) - Sum of Squares: 87.9624
#   PC1 explained variance: 82.18%
#   PC2 explained variance: 17.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.0970
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 143.7985
#   PC1 explained variance: 65.55%
#   PC2 explained variance: 34.45%
# C(treatment):C(timepoint) - Sum of Squares: 85.5233
#   PC1 explained variance: 80.62%
#   PC2 explained variance: 19.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.6160
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 30.0711
#   PC1 explained variance: 74.73%
#   PC2 explained variance: 25.27%
# C(treatment):C(timepoint) - Sum of Squares: 45.9914
#   PC1 explained variance: 84.90%
#   PC2 explained variance: 15.10%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0600 (not significant)
# Effect C(treatment) is significant (p=0.0100) and included in enhanced model
# Effect C(timepoint) is significant (p=0.0100) and included in enhanced model
# Effect C(treatment):C(timepoint) is not significant (p=0.0600) and added to residuals
# C(treatment) - Sum of Squares: 592.6881 (35.97% of total)
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804 (35.93% of total)
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
#
# ===== METHOD 4: LiMM-PCA =====
#
# === LiMM-PCA Analysis (Linear Mixed Models with PCA) ===
# Processing feature 1/10...
# Error fitting model for feature_1: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_2: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_3: unhashable type: 'numpy.ndarray'
# Processing feature 4/10...
# Error fitting model for feature_4: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_5: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_6: unhashable type: 'numpy.ndarray'
# Processing feature 7/10...
# Error fitting model for feature_7: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_8: unhashable type: 'numpy.ndarray'
# Error fitting model for feature_9: unhashable type: 'numpy.ndarray'
# Processing feature 10/10...
# Error fitting model for feature_10: unhashable type: 'numpy.ndarray'
#
# Variance Partition:
# Fixed Effects: 0.00%
# Random Effects: 0.00%
# Residuals: 100.00%
#
# PCA on Fixed Effects:
# PC1 explained variance: nan%
# PC2 explained variance: nan%
#
# ===== METHOD 5: MSCA =====
#
# === MSCA Analysis (Multilevel Simultaneous Component Analysis) ===
#
# Variance Partition:
# Between-subject: 51.77%
# Within-subject: 48.23%
#
# PCA on Between-subject Variation:
# PC1 explained variance: 53.02%
# PC2 explained variance: 13.09%
#
# PCA on Within-subject Variation:
# PC1 explained variance: 52.73%
# PC2 explained variance: 23.16%

# %%
# Improved implementation of LiMM-PCA to fix the 'unhashable type: numpy.ndarray' error

def limm_pca_fixed(data, feature_cols, verbose=True):
    """
    Implement LiMM-PCA (Linear Mixed Models with PCA) with fixed implementation
    to resolve the 'unhashable type: numpy.ndarray' error.

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing LiMM-PCA results
    """
    if verbose:
        print("\n=== LiMM-PCA Analysis (Linear Mixed Models with PCA) ===")

    # Extract data matrix
    X = data[feature_cols].values

    # Standardize the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Create copy of data with proper string conversion for categorical variables
    data_copy = data.copy()

    # Convert categorical variables to strings
    data_copy['subject_id'] = data_copy['subject_id'].astype(str)
    data_copy['treatment'] = data_copy['treatment'].astype(str)
    data_copy['timepoint'] = data_copy['timepoint'].astype(str)

    # Initialize containers for results
    fixed_effects = {}
    random_effects = {}
    residuals = {}
    pvalues = {}

    # Apply mixed model to each feature
    for i, feature in enumerate(feature_cols):
        if verbose and i % 3 == 0:
            print(f"Processing feature {i+1}/{len(feature_cols)}...")

        # Create mixed model formula
        formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit mixed effects model
        try:
            # Fit the model with explicit specification of groups
            model = mixedlm(formula, data_copy, groups=data_copy['subject_id'])
            result = model.fit(reml=True)

            # Extract fixed effects (predicted values without random effects)
            subjects = data_copy['subject_id'].values
            re_dict = {str(subj): val[0] for subj, val in result.random_effects.items()}

            # Create array for random effects
            subject_effect = np.array([re_dict.get(str(subj), 0) for subj in subjects])

            # Fixed effects = fitted values - random effects
            fixed_effects[feature] = result.fittedvalues - subject_effect

            # Store random effects
            random_effects[feature] = subject_effect

            # Extract residuals
            residuals[feature] = result.resid

            # Store p-values for fixed effects
            pvalues[feature] = result.pvalues

        except Exception as e:
            if verbose:
                print(f"Error fitting model for {feature}: {e}")
            # Use simpler approach if model fails
            fixed_effects[feature] = np.zeros(len(data))
            random_effects[feature] = np.zeros(len(data))
            residuals[feature] = X_scaled[:, i]

    # Convert to matrices
    fixed_matrix = np.column_stack([fixed_effects[feature] for feature in feature_cols])
    random_matrix = np.column_stack([random_effects[feature] for feature in feature_cols])
    resid_matrix = np.column_stack([residuals[feature] for feature in feature_cols])

    # Calculate variance explained
    total_var = np.sum(X_scaled**2)
    fixed_var = np.sum(fixed_matrix**2)
    random_var = np.sum(random_matrix**2)
    resid_var = np.sum(resid_matrix**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Fixed Effects: {fixed_var/total_var*100:.2f}%")
        print(f"Random Effects: {random_var/total_var*100:.2f}%")
        print(f"Residuals: {resid_var/total_var*100:.2f}%")

    # Apply PCA to fixed effects matrix
    pca_fixed = PCA()
    pca_fixed.fit(fixed_matrix)

    if verbose and len(pca_fixed.explained_variance_ratio_) > 0:
        print("\nPCA on Fixed Effects:")
        print(f"PC1 explained variance: {pca_fixed.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_fixed.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_fixed.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'fixed_matrix': fixed_matrix,
        'random_matrix': random_matrix,
        'resid_matrix': resid_matrix,
        'pca_fixed': pca_fixed,
        'fixed_scores': pca_fixed.transform(fixed_matrix) if len(pca_fixed.explained_variance_ratio_) > 0 else np.array([]),
        'total_var': total_var,
        'fixed_var': fixed_var,
        'random_var': random_var,
        'resid_var': resid_var
    }

    return results

# Example usage:
# limm_pca_results = limm_pca_fixed(X_matrix, feature_cols)

# %%
# Install required packages (run this once)
# !pip install -q numpy pandas matplotlib seaborn scikit-learn scipy statsmodels

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy import stats
from scipy.linalg import svd
import statsmodels.api as sm
from statsmodels.formula.api import ols, mixedlm
from statsmodels.stats.anova import anova_lm
import random
from itertools import product
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
import matplotlib.gridspec as gridspec
import warnings
warnings.filterwarnings('ignore')

# Set up plotting styles
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("notebook", font_scale=1.2)
np.random.seed(42)  # For reproducibility

# %%
def generate_synthetic_data(n_subjects=20, n_timepoints=3, n_features=10,
                          n_treatments=2, effect_size=0.5, random_effect_size=0.3,
                          noise_level=0.2):
    """Generate synthetic multivariate longitudinal data"""
    # Create empty dataframe
    columns = ['subject_id', 'treatment', 'timepoint'] + [f'feature_{i+1}' for i in range(n_features)]
    data = []

    # Treatment effects (different for each feature)
    treatment_effects = np.random.normal(0, effect_size, (n_treatments, n_features))

    # Timepoint effects (different for each feature)
    time_effects = np.random.normal(0, effect_size * 0.8, (n_timepoints, n_features))

    # Treatment x Time interaction effects
    interaction_effects = np.random.normal(0, effect_size * 0.5,
                                          (n_treatments, n_timepoints, n_features))

    # Generate data for each subject
    for subject in range(n_subjects):
        # Assign treatment (balanced design)
        treatment = subject % n_treatments

        # Random subject effect (consistent across timepoints)
        subject_effect = np.random.normal(0, random_effect_size, n_features)

        for timepoint in range(n_timepoints):
            # Base values for this subject at this timepoint
            feature_values = np.zeros(n_features)

            # Add treatment effect
            feature_values += treatment_effects[treatment]

            # Add time effect
            feature_values += time_effects[timepoint]

            # Add treatment x time interaction
            feature_values += interaction_effects[treatment, timepoint]

            # Add subject-specific effect
            feature_values += subject_effect

            # Add random noise
            feature_values += np.random.normal(0, noise_level, n_features)

            # Add row to data
            row = [f'S{subject+1}', f'T{treatment+1}', f'TP{timepoint+1}'] + feature_values.tolist()
            data.append(row)

    # Create DataFrame
    df = pd.DataFrame(data, columns=columns)

    # Convert features to float
    for i in range(n_features):
        df[f'feature_{i+1}'] = df[f'feature_{i+1}'].astype(float)

    return df

# Generate balanced dataset with 30 subjects, 3 timepoints, 10 features, 2 treatments
df = generate_synthetic_data(n_subjects=30, n_timepoints=3, n_features=10,
                          n_treatments=2, effect_size=0.7, random_effect_size=0.4,
                          noise_level=0.3)

# %%
# Extract feature columns
feature_cols = [col for col in df.columns if 'feature' in col]
X = df[feature_cols].values

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create a data matrix for easier handling
X_matrix = pd.DataFrame(X_scaled, columns=feature_cols)
X_matrix['subject_id'] = df['subject_id']
X_matrix['treatment'] = df['treatment']
X_matrix['timepoint'] = df['timepoint']

print("Data prepared for analysis.")
print("Number of samples:", X_matrix.shape[0])
print("Number of features:", len(feature_cols))
print("Factors: treatment, timepoint, subject_id")

# Visualize the data
plt.figure(figsize=(12, 8))
feature_data = df[feature_cols].values

# Apply PCA for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Add PCA results to the dataframe for plotting
df_plot = df.copy()
df_plot['PC1'] = pca_result[:, 0]
df_plot['PC2'] = pca_result[:, 1]

# Plot by treatment and timepoint
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(data=df_plot, x='PC1', y='PC2', hue='treatment', style='timepoint', s=80, alpha=0.7)
plt.title('PCA of Data by Treatment and Timepoint')
plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.2f}%)')
plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.2f}%)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.subplot(1, 2, 2)
# Correlation heatmap of features
corr = df[feature_cols].corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title('Feature Correlation Heatmap')

plt.tight_layout()
plt.show()
# Out:
# Data prepared for analysis.
# Number of samples: 90
# Number of features: 10
# Factors: treatment, timepoint, subject_id

# %% [markdown]
# Method 1: ASCA (ANOVA-Simultaneous Component Analysis)

# %%
def asca(data, formula, design_cols, feature_cols):
    """
    Implement ASCA (ANOVA-Simultaneous Component Analysis)
    """
    print("\n=== ASCA Analysis ===")

    # Extract design and data matrices
    X = data[feature_cols].values
    n_samples, n_features = X.shape

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Fit the ANOVA model for each feature
    effect_matrices = {}
    anova_summaries = []

    # ANOVA decomposition
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model
        model = ols(feature_formula, data=data).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        # Store ANOVA summary for this feature
        if feature_idx == 0:  # Only store once
            anova_summaries.append(anova_table)

    # Extract effects from ANOVA model
    # Create empty matrices for each effect
    effects = ['C(treatment)', 'C(timepoint)', 'C(treatment):C(timepoint)', 'Residual']
    effect_matrices = {effect: np.zeros((n_samples, n_features)) for effect in effects}

    # Fill effect matrices feature by feature
    for feature_idx, feature in enumerate(feature_cols):
        # Create formula for this feature
        feature_formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit ANOVA model for this feature
        model = ols(feature_formula, data=data).fit()

        # Get predicted values for each effect
        # Treatment effect
        treatment_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            param_name = f"C(treatment)[T.{treatment}]"
            if param_name in model.params:
                treatment_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment)'][:, feature_idx] = treatment_effect

        # Timepoint effect
        timepoint_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            timepoint = row['timepoint']
            param_name = f"C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                timepoint_effect[idx] = model.params[param_name]
        effect_matrices['C(timepoint)'][:, feature_idx] = timepoint_effect

        # Interaction effect
        interaction_effect = np.zeros(n_samples)
        for idx, row in data.iterrows():
            treatment = row['treatment']
            timepoint = row['timepoint']
            param_name = f"C(treatment)[T.{treatment}]:C(timepoint)[T.{timepoint}]"
            if param_name in model.params:
                interaction_effect[idx] = model.params[param_name]
        effect_matrices['C(treatment):C(timepoint)'][:, feature_idx] = interaction_effect

        # Residual effect
        effect_matrices['Residual'][:, feature_idx] = model.resid

    # Apply PCA to each effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in effect_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            print(f"{effect} - Sum of Squares: {effect_ss:.4f}")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Calculate total variance
    total_variance = np.sum(X_centered**2)

    return {
        'effect_matrices': effect_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'total_variance': total_variance,
        'anova_summaries': anova_summaries
    }

# Prepare formula and design columns
formula = "~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"
design_cols = ['treatment', 'timepoint', 'subject_id']

# Run ASCA analysis
asca_results = asca(X_matrix, formula, design_cols, feature_cols)

# Visualize ASCA results
plt.figure(figsize=(18, 6))

# Treatment effect
plt.subplot(1, 3, 1)
if 'C(treatment)' in asca_results['pca_results']:
    treatment_pc = asca_results['pca_results']['C(treatment)'][:, 0]
    sns.boxplot(x=X_matrix['treatment'], y=treatment_pc)
    plt.title('Treatment Effect (PC1)')
    plt.xlabel('Treatment')
    plt.ylabel('PC1 Score')

# Timepoint effect
plt.subplot(1, 3, 2)
if 'C(timepoint)' in asca_results['pca_results']:
    timepoint_pc = asca_results['pca_results']['C(timepoint)'][:, 0]
    sns.boxplot(x=X_matrix['timepoint'], y=timepoint_pc)
    plt.title('Timepoint Effect (PC1)')
    plt.xlabel('Timepoint')
    plt.ylabel('PC1 Score')

# Interaction effect
plt.subplot(1, 3, 3)
if 'C(treatment):C(timepoint)' in asca_results['pca_results']:
    interaction_pc = asca_results['pca_results']['C(treatment):C(timepoint)'][:, 0]
    sns.boxplot(x=X_matrix['treatment'], y=interaction_pc, hue=X_matrix['timepoint'])
    plt.title('Treatment × Timepoint Interaction (PC1)')
    plt.xlabel('Treatment')
    plt.ylabel('PC1 Score')
    plt.legend(title='Timepoint')

plt.tight_layout()
plt.show()
# Out:
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%

# %% [markdown]
# Method 2: ASCA+ (ASCA with Permutation Testing)

# %%
def asca_plus(data, formula, design_cols, feature_cols, n_permutations=99):
    """
    Implement ASCA+ (ASCA with permutation testing)

    Note: For real analyses, increase n_permutations to 999 or more
    """
    print("\n=== ASCA+ Analysis (ASCA with Permutation Testing) ===")

    # Run standard ASCA
    asca_results = asca(data, formula, design_cols, feature_cols)

    # Get effect matrices and calculate sum of squares for each effect
    effect_matrices = asca_results['effect_matrices']
    observed_ss = {effect: np.sum(matrix**2) for effect, matrix in effect_matrices.items()
                 if effect != 'Residual'}

    # Permutation testing
    permuted_ss = {effect: [] for effect in observed_ss.keys()}

    print(f"\nRunning permutation tests with {n_permutations} permutations...")

    for perm in range(n_permutations):
        if perm % 20 == 0 and perm > 0:
            print(f"  Completed {perm} permutations")

        # Create permuted data
        perm_data = data.copy()

        # Permute each factor separately
        for effect in observed_ss.keys():
            if effect == 'C(treatment)':
                # Permute treatment labels
                perm_data['treatment'] = np.random.permutation(perm_data['treatment'].values)
            elif effect == 'C(timepoint)':
                # Permute timepoint labels
                perm_data['timepoint'] = np.random.permutation(perm_data['timepoint'].values)
            elif effect == 'C(treatment):C(timepoint)':
                # Permute interaction by shuffling combinations
                combinations = perm_data[['treatment', 'timepoint']].values
                np.random.shuffle(combinations)
                perm_data['treatment'] = combinations[:, 0]
                perm_data['timepoint'] = combinations[:, 1]

        # Run ASCA on permuted data
        perm_asca = asca(perm_data, formula, design_cols, feature_cols)
        perm_effect_matrices = perm_asca['effect_matrices']

        # Calculate sum of squares for each permuted effect
        for effect in observed_ss.keys():
            perm_ss = np.sum(perm_effect_matrices[effect]**2)
            permuted_ss[effect].append(perm_ss)

    # Calculate p-values
    p_values = {}
    for effect in observed_ss.keys():
        # Count how many permuted SS are >= observed SS
        p_values[effect] = (np.sum(np.array(permuted_ss[effect]) >= observed_ss[effect]) + 1) / (n_permutations + 1)

    print("\nPermutation Test Results:")
    for effect, p_value in p_values.items():
        significance = "significant" if p_value < 0.05 else "not significant"
        print(f"{effect}: p-value = {p_value:.4f} ({significance})")

    # Add results to ASCA results
    asca_results['p_values'] = p_values
    asca_results['permuted_ss'] = permuted_ss

    # Visualize permutation test results
    plt.figure(figsize=(15, 5))

    for i, effect in enumerate(observed_ss.keys()):
        plt.subplot(1, 3, i+1)
        sns.histplot(permuted_ss[effect], bins=20, kde=True)
        plt.axvline(observed_ss[effect], color='red', linestyle='--',
                    label=f'Observed ({p_values[effect]:.3f})')
        plt.title(f'{effect} Permutation Test')
        plt.xlabel('Sum of Squares')
        plt.ylabel('Frequency')
        plt.legend()

    plt.tight_layout()
    plt.show()

    return asca_results

# Run ASCA+ with fewer permutations for demonstration
# For real analyses, use n_permutations=999 or more
asca_plus_results = asca_plus(X_matrix, formula, design_cols, feature_cols, n_permutations=99)
# Out:
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 93.5400
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 96.5207
#   PC1 explained variance: 76.73%
#   PC2 explained variance: 23.27%
# C(treatment):C(timepoint) - Sum of Squares: 82.5380
#   PC1 explained variance: 92.53%
#   PC2 explained variance: 7.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2851
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.3140
#   PC1 explained variance: 79.42%
#   PC2 explained variance: 20.58%
# C(treatment):C(timepoint) - Sum of Squares: 130.5723
#   PC1 explained variance: 91.47%
#   PC2 explained variance: 8.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.1554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 64.0552
#   PC1 explained variance: 76.88%
#   PC2 explained variance: 23.12%
# C(treatment):C(timepoint) - Sum of Squares: 90.4537
#   PC1 explained variance: 87.18%
#   PC2 explained variance: 12.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.8071
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.7020
#   PC1 explained variance: 70.36%
#   PC2 explained variance: 29.64%
# C(treatment):C(timepoint) - Sum of Squares: 62.3506
#   PC1 explained variance: 60.63%
#   PC2 explained variance: 39.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.0950
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.2996
#   PC1 explained variance: 61.92%
#   PC2 explained variance: 38.08%
# C(treatment):C(timepoint) - Sum of Squares: 54.3761
#   PC1 explained variance: 61.31%
#   PC2 explained variance: 38.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0112
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.0225
#   PC1 explained variance: 78.27%
#   PC2 explained variance: 21.73%
# C(treatment):C(timepoint) - Sum of Squares: 144.6457
#   PC1 explained variance: 94.79%
#   PC2 explained variance: 5.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.4633
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.6746
#   PC1 explained variance: 69.23%
#   PC2 explained variance: 30.77%
# C(treatment):C(timepoint) - Sum of Squares: 61.8270
#   PC1 explained variance: 72.24%
#   PC2 explained variance: 27.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.9151
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.5919
#   PC1 explained variance: 70.76%
#   PC2 explained variance: 29.24%
# C(treatment):C(timepoint) - Sum of Squares: 75.5881
#   PC1 explained variance: 75.78%
#   PC2 explained variance: 24.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.5258
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.2187
#   PC1 explained variance: 65.27%
#   PC2 explained variance: 34.73%
# C(treatment):C(timepoint) - Sum of Squares: 100.4018
#   PC1 explained variance: 68.80%
#   PC2 explained variance: 31.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.6102
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 34.7627
#   PC1 explained variance: 81.59%
#   PC2 explained variance: 18.41%
# C(treatment):C(timepoint) - Sum of Squares: 61.9159
#   PC1 explained variance: 74.27%
#   PC2 explained variance: 25.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.0804
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.4985
#   PC1 explained variance: 62.42%
#   PC2 explained variance: 37.58%
# C(treatment):C(timepoint) - Sum of Squares: 69.7323
#   PC1 explained variance: 82.19%
#   PC2 explained variance: 17.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.0806
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.1339
#   PC1 explained variance: 60.47%
#   PC2 explained variance: 39.53%
# C(treatment):C(timepoint) - Sum of Squares: 86.1851
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.4656
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 128.2963
#   PC1 explained variance: 88.88%
#   PC2 explained variance: 11.12%
# C(treatment):C(timepoint) - Sum of Squares: 77.9805
#   PC1 explained variance: 91.59%
#   PC2 explained variance: 8.41%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 88.1323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.5339
#   PC1 explained variance: 78.68%
#   PC2 explained variance: 21.32%
# C(treatment):C(timepoint) - Sum of Squares: 109.2450
#   PC1 explained variance: 87.08%
#   PC2 explained variance: 12.92%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.8497
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.5703
#   PC1 explained variance: 68.90%
#   PC2 explained variance: 31.10%
# C(treatment):C(timepoint) - Sum of Squares: 41.4442
#   PC1 explained variance: 70.54%
#   PC2 explained variance: 29.46%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 150.9762
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.2468
#   PC1 explained variance: 81.94%
#   PC2 explained variance: 18.06%
# C(treatment):C(timepoint) - Sum of Squares: 203.2224
#   PC1 explained variance: 80.03%
#   PC2 explained variance: 19.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.5539
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 105.1444
#   PC1 explained variance: 60.34%
#   PC2 explained variance: 39.66%
# C(treatment):C(timepoint) - Sum of Squares: 61.4169
#   PC1 explained variance: 75.03%
#   PC2 explained variance: 24.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.6092
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 82.1656
#   PC1 explained variance: 67.65%
#   PC2 explained variance: 32.35%
# C(treatment):C(timepoint) - Sum of Squares: 92.6206
#   PC1 explained variance: 57.93%
#   PC2 explained variance: 42.07%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 96.3889
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 194.9687
#   PC1 explained variance: 69.51%
#   PC2 explained variance: 30.49%
# C(treatment):C(timepoint) - Sum of Squares: 80.4608
#   PC1 explained variance: 70.57%
#   PC2 explained variance: 29.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 106.0029
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.0969
#   PC1 explained variance: 79.67%
#   PC2 explained variance: 20.33%
# C(treatment):C(timepoint) - Sum of Squares: 120.1617
#   PC1 explained variance: 90.43%
#   PC2 explained variance: 9.57%
#   Completed 20 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.9269
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.7287
#   PC1 explained variance: 89.48%
#   PC2 explained variance: 10.52%
# C(treatment):C(timepoint) - Sum of Squares: 31.3438
#   PC1 explained variance: 71.63%
#   PC2 explained variance: 28.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.1983
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.0953
#   PC1 explained variance: 80.80%
#   PC2 explained variance: 19.20%
# C(treatment):C(timepoint) - Sum of Squares: 36.2068
#   PC1 explained variance: 91.62%
#   PC2 explained variance: 8.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.0944
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.6501
#   PC1 explained variance: 77.30%
#   PC2 explained variance: 22.70%
# C(treatment):C(timepoint) - Sum of Squares: 68.6838
#   PC1 explained variance: 72.91%
#   PC2 explained variance: 27.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.7903
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.9533
#   PC1 explained variance: 97.41%
#   PC2 explained variance: 2.59%
# C(treatment):C(timepoint) - Sum of Squares: 72.6324
#   PC1 explained variance: 94.05%
#   PC2 explained variance: 5.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.6203
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.2152
#   PC1 explained variance: 89.43%
#   PC2 explained variance: 10.57%
# C(treatment):C(timepoint) - Sum of Squares: 61.1255
#   PC1 explained variance: 79.38%
#   PC2 explained variance: 20.62%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 129.4940
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 118.9843
#   PC1 explained variance: 51.20%
#   PC2 explained variance: 48.80%
# C(treatment):C(timepoint) - Sum of Squares: 101.1683
#   PC1 explained variance: 69.65%
#   PC2 explained variance: 30.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.0976
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.6821
#   PC1 explained variance: 74.51%
#   PC2 explained variance: 25.49%
# C(treatment):C(timepoint) - Sum of Squares: 71.3826
#   PC1 explained variance: 89.74%
#   PC2 explained variance: 10.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.1381
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 80.8763
#   PC1 explained variance: 73.17%
#   PC2 explained variance: 26.83%
# C(treatment):C(timepoint) - Sum of Squares: 95.5416
#   PC1 explained variance: 88.18%
#   PC2 explained variance: 11.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.8415
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 137.1565
#   PC1 explained variance: 69.95%
#   PC2 explained variance: 30.05%
# C(treatment):C(timepoint) - Sum of Squares: 63.1305
#   PC1 explained variance: 78.60%
#   PC2 explained variance: 21.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0848
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.0256
#   PC1 explained variance: 67.54%
#   PC2 explained variance: 32.46%
# C(treatment):C(timepoint) - Sum of Squares: 61.8478
#   PC1 explained variance: 73.13%
#   PC2 explained variance: 26.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.0923
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 110.0554
#   PC1 explained variance: 86.80%
#   PC2 explained variance: 13.20%
# C(treatment):C(timepoint) - Sum of Squares: 75.0035
#   PC1 explained variance: 93.76%
#   PC2 explained variance: 6.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.9729
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 36.5159
#   PC1 explained variance: 58.43%
#   PC2 explained variance: 41.57%
# C(treatment):C(timepoint) - Sum of Squares: 32.8670
#   PC1 explained variance: 71.24%
#   PC2 explained variance: 28.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.6695
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 28.0609
#   PC1 explained variance: 60.97%
#   PC2 explained variance: 39.03%
# C(treatment):C(timepoint) - Sum of Squares: 44.9596
#   PC1 explained variance: 59.78%
#   PC2 explained variance: 40.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.8023
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.4681
#   PC1 explained variance: 61.51%
#   PC2 explained variance: 38.49%
# C(treatment):C(timepoint) - Sum of Squares: 53.7541
#   PC1 explained variance: 74.16%
#   PC2 explained variance: 25.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.5095
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 258.2013
#   PC1 explained variance: 90.51%
#   PC2 explained variance: 9.49%
# C(treatment):C(timepoint) - Sum of Squares: 155.7456
#   PC1 explained variance: 77.12%
#   PC2 explained variance: 22.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.5777
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.0168
#   PC1 explained variance: 65.91%
#   PC2 explained variance: 34.09%
# C(treatment):C(timepoint) - Sum of Squares: 88.8284
#   PC1 explained variance: 88.32%
#   PC2 explained variance: 11.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.2282
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.4503
#   PC1 explained variance: 68.75%
#   PC2 explained variance: 31.25%
# C(treatment):C(timepoint) - Sum of Squares: 80.1619
#   PC1 explained variance: 87.88%
#   PC2 explained variance: 12.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 98.8811
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 83.2326
#   PC1 explained variance: 83.83%
#   PC2 explained variance: 16.17%
# C(treatment):C(timepoint) - Sum of Squares: 88.8374
#   PC1 explained variance: 66.53%
#   PC2 explained variance: 33.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 133.3942
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 107.2813
#   PC1 explained variance: 53.60%
#   PC2 explained variance: 46.40%
# C(treatment):C(timepoint) - Sum of Squares: 82.5099
#   PC1 explained variance: 86.44%
#   PC2 explained variance: 13.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.1643
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.9890
#   PC1 explained variance: 60.34%
#   PC2 explained variance: 39.66%
# C(treatment):C(timepoint) - Sum of Squares: 52.0364
#   PC1 explained variance: 66.11%
#   PC2 explained variance: 33.89%
#   Completed 40 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.6014
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 122.6156
#   PC1 explained variance: 77.89%
#   PC2 explained variance: 22.11%
# C(treatment):C(timepoint) - Sum of Squares: 146.4008
#   PC1 explained variance: 76.43%
#   PC2 explained variance: 23.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 11.1502
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.5562
#   PC1 explained variance: 73.95%
#   PC2 explained variance: 26.05%
# C(treatment):C(timepoint) - Sum of Squares: 104.2733
#   PC1 explained variance: 69.23%
#   PC2 explained variance: 30.77%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 59.1691
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.1928
#   PC1 explained variance: 56.77%
#   PC2 explained variance: 43.23%
# C(treatment):C(timepoint) - Sum of Squares: 118.4736
#   PC1 explained variance: 88.86%
#   PC2 explained variance: 11.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 83.3409
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.9356
#   PC1 explained variance: 90.80%
#   PC2 explained variance: 9.20%
# C(treatment):C(timepoint) - Sum of Squares: 147.1410
#   PC1 explained variance: 79.43%
#   PC2 explained variance: 20.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 72.1827
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.3797
#   PC1 explained variance: 63.36%
#   PC2 explained variance: 36.64%
# C(treatment):C(timepoint) - Sum of Squares: 167.9569
#   PC1 explained variance: 66.19%
#   PC2 explained variance: 33.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.7733
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.6793
#   PC1 explained variance: 66.44%
#   PC2 explained variance: 33.56%
# C(treatment):C(timepoint) - Sum of Squares: 80.1525
#   PC1 explained variance: 74.30%
#   PC2 explained variance: 25.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.1051
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.2113
#   PC1 explained variance: 64.66%
#   PC2 explained variance: 35.34%
# C(treatment):C(timepoint) - Sum of Squares: 120.9629
#   PC1 explained variance: 80.21%
#   PC2 explained variance: 19.79%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.6980
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.5284
#   PC1 explained variance: 70.65%
#   PC2 explained variance: 29.35%
# C(treatment):C(timepoint) - Sum of Squares: 54.0949
#   PC1 explained variance: 74.68%
#   PC2 explained variance: 25.32%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.0692
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.9364
#   PC1 explained variance: 80.52%
#   PC2 explained variance: 19.48%
# C(treatment):C(timepoint) - Sum of Squares: 47.2228
#   PC1 explained variance: 95.31%
#   PC2 explained variance: 4.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.5874
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.7022
#   PC1 explained variance: 88.64%
#   PC2 explained variance: 11.36%
# C(treatment):C(timepoint) - Sum of Squares: 109.1821
#   PC1 explained variance: 90.20%
#   PC2 explained variance: 9.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.9056
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.5472
#   PC1 explained variance: 80.72%
#   PC2 explained variance: 19.28%
# C(treatment):C(timepoint) - Sum of Squares: 66.1365
#   PC1 explained variance: 69.09%
#   PC2 explained variance: 30.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.3856
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.4939
#   PC1 explained variance: 63.62%
#   PC2 explained variance: 36.38%
# C(treatment):C(timepoint) - Sum of Squares: 107.7522
#   PC1 explained variance: 83.46%
#   PC2 explained variance: 16.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.8883
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.7716
#   PC1 explained variance: 90.36%
#   PC2 explained variance: 9.64%
# C(treatment):C(timepoint) - Sum of Squares: 66.8466
#   PC1 explained variance: 82.26%
#   PC2 explained variance: 17.74%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.5969
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.7536
#   PC1 explained variance: 80.74%
#   PC2 explained variance: 19.26%
# C(treatment):C(timepoint) - Sum of Squares: 92.5669
#   PC1 explained variance: 87.98%
#   PC2 explained variance: 12.02%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.3168
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.0332
#   PC1 explained variance: 74.51%
#   PC2 explained variance: 25.49%
# C(treatment):C(timepoint) - Sum of Squares: 64.0935
#   PC1 explained variance: 85.34%
#   PC2 explained variance: 14.66%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.8790
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.3961
#   PC1 explained variance: 55.91%
#   PC2 explained variance: 44.09%
# C(treatment):C(timepoint) - Sum of Squares: 47.0185
#   PC1 explained variance: 83.32%
#   PC2 explained variance: 16.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.4887
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.8698
#   PC1 explained variance: 72.76%
#   PC2 explained variance: 27.24%
# C(treatment):C(timepoint) - Sum of Squares: 54.0652
#   PC1 explained variance: 73.04%
#   PC2 explained variance: 26.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.5641
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 52.1758
#   PC1 explained variance: 78.39%
#   PC2 explained variance: 21.61%
# C(treatment):C(timepoint) - Sum of Squares: 85.6186
#   PC1 explained variance: 69.17%
#   PC2 explained variance: 30.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.2135
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.7153
#   PC1 explained variance: 71.44%
#   PC2 explained variance: 28.56%
# C(treatment):C(timepoint) - Sum of Squares: 87.0360
#   PC1 explained variance: 77.46%
#   PC2 explained variance: 22.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.9115
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.1116
#   PC1 explained variance: 71.61%
#   PC2 explained variance: 28.39%
# C(treatment):C(timepoint) - Sum of Squares: 34.3068
#   PC1 explained variance: 57.65%
#   PC2 explained variance: 42.35%
#   Completed 60 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.6722
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.8897
#   PC1 explained variance: 67.50%
#   PC2 explained variance: 32.50%
# C(treatment):C(timepoint) - Sum of Squares: 43.0181
#   PC1 explained variance: 72.78%
#   PC2 explained variance: 27.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.4168
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.5863
#   PC1 explained variance: 71.31%
#   PC2 explained variance: 28.69%
# C(treatment):C(timepoint) - Sum of Squares: 47.7428
#   PC1 explained variance: 80.85%
#   PC2 explained variance: 19.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.1139
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 19.4607
#   PC1 explained variance: 73.55%
#   PC2 explained variance: 26.45%
# C(treatment):C(timepoint) - Sum of Squares: 39.4761
#   PC1 explained variance: 61.10%
#   PC2 explained variance: 38.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.0236
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.3325
#   PC1 explained variance: 61.09%
#   PC2 explained variance: 38.91%
# C(treatment):C(timepoint) - Sum of Squares: 90.5732
#   PC1 explained variance: 59.09%
#   PC2 explained variance: 40.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.7110
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 79.6146
#   PC1 explained variance: 87.50%
#   PC2 explained variance: 12.50%
# C(treatment):C(timepoint) - Sum of Squares: 45.0781
#   PC1 explained variance: 82.47%
#   PC2 explained variance: 17.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.1345
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 24.6737
#   PC1 explained variance: 85.63%
#   PC2 explained variance: 14.37%
# C(treatment):C(timepoint) - Sum of Squares: 23.1230
#   PC1 explained variance: 77.52%
#   PC2 explained variance: 22.48%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 76.1873
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8768
#   PC1 explained variance: 59.26%
#   PC2 explained variance: 40.74%
# C(treatment):C(timepoint) - Sum of Squares: 97.3391
#   PC1 explained variance: 91.20%
#   PC2 explained variance: 8.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.0879
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.9164
#   PC1 explained variance: 81.88%
#   PC2 explained variance: 18.12%
# C(treatment):C(timepoint) - Sum of Squares: 44.8200
#   PC1 explained variance: 70.04%
#   PC2 explained variance: 29.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 82.6659
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.4200
#   PC1 explained variance: 84.89%
#   PC2 explained variance: 15.11%
# C(treatment):C(timepoint) - Sum of Squares: 116.9591
#   PC1 explained variance: 75.73%
#   PC2 explained variance: 24.27%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2961
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.6037
#   PC1 explained variance: 79.71%
#   PC2 explained variance: 20.29%
# C(treatment):C(timepoint) - Sum of Squares: 57.4077
#   PC1 explained variance: 66.17%
#   PC2 explained variance: 33.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.0463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.8388
#   PC1 explained variance: 78.24%
#   PC2 explained variance: 21.76%
# C(treatment):C(timepoint) - Sum of Squares: 50.8574
#   PC1 explained variance: 53.06%
#   PC2 explained variance: 46.94%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.7463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.7902
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 52.8370
#   PC1 explained variance: 70.95%
#   PC2 explained variance: 29.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 75.1025
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.4943
#   PC1 explained variance: 68.76%
#   PC2 explained variance: 31.24%
# C(treatment):C(timepoint) - Sum of Squares: 31.9683
#   PC1 explained variance: 63.74%
#   PC2 explained variance: 36.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.8244
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.7738
#   PC1 explained variance: 57.76%
#   PC2 explained variance: 42.24%
# C(treatment):C(timepoint) - Sum of Squares: 46.0627
#   PC1 explained variance: 87.11%
#   PC2 explained variance: 12.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.9643
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 87.2915
#   PC1 explained variance: 69.03%
#   PC2 explained variance: 30.97%
# C(treatment):C(timepoint) - Sum of Squares: 81.1964
#   PC1 explained variance: 86.42%
#   PC2 explained variance: 13.58%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 100.0165
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 20.2013
#   PC1 explained variance: 75.09%
#   PC2 explained variance: 24.91%
# C(treatment):C(timepoint) - Sum of Squares: 91.0284
#   PC1 explained variance: 85.82%
#   PC2 explained variance: 14.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.5674
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.6836
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
# C(treatment):C(timepoint) - Sum of Squares: 67.1162
#   PC1 explained variance: 65.17%
#   PC2 explained variance: 34.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.0037
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 88.7425
#   PC1 explained variance: 64.04%
#   PC2 explained variance: 35.96%
# C(treatment):C(timepoint) - Sum of Squares: 96.4032
#   PC1 explained variance: 59.67%
#   PC2 explained variance: 40.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.3477
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 172.3101
#   PC1 explained variance: 85.24%
#   PC2 explained variance: 14.76%
# C(treatment):C(timepoint) - Sum of Squares: 90.5997
#   PC1 explained variance: 91.28%
#   PC2 explained variance: 8.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.4772
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.3400
#   PC1 explained variance: 81.86%
#   PC2 explained variance: 18.14%
# C(treatment):C(timepoint) - Sum of Squares: 67.0503
#   PC1 explained variance: 72.08%
#   PC2 explained variance: 27.92%
#   Completed 80 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.3279
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.3083
#   PC1 explained variance: 60.24%
#   PC2 explained variance: 39.76%
# C(treatment):C(timepoint) - Sum of Squares: 68.1674
#   PC1 explained variance: 68.98%
#   PC2 explained variance: 31.02%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 115.9950
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.3651
#   PC1 explained variance: 59.88%
#   PC2 explained variance: 40.12%
# C(treatment):C(timepoint) - Sum of Squares: 125.7500
#   PC1 explained variance: 74.19%
#   PC2 explained variance: 25.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 121.5654
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.1756
#   PC1 explained variance: 66.54%
#   PC2 explained variance: 33.46%
# C(treatment):C(timepoint) - Sum of Squares: 145.0826
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.0745
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.4451
#   PC1 explained variance: 74.59%
#   PC2 explained variance: 25.41%
# C(treatment):C(timepoint) - Sum of Squares: 57.5403
#   PC1 explained variance: 67.64%
#   PC2 explained variance: 32.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 161.5636
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.4645
#   PC1 explained variance: 64.49%
#   PC2 explained variance: 35.51%
# C(treatment):C(timepoint) - Sum of Squares: 159.6772
#   PC1 explained variance: 94.84%
#   PC2 explained variance: 5.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.9730
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 116.7388
#   PC1 explained variance: 65.27%
#   PC2 explained variance: 34.73%
# C(treatment):C(timepoint) - Sum of Squares: 89.0334
#   PC1 explained variance: 74.91%
#   PC2 explained variance: 25.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.8126
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.0615
#   PC1 explained variance: 59.19%
#   PC2 explained variance: 40.81%
# C(treatment):C(timepoint) - Sum of Squares: 49.5193
#   PC1 explained variance: 70.04%
#   PC2 explained variance: 29.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.8843
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 82.3132
#   PC1 explained variance: 70.80%
#   PC2 explained variance: 29.20%
# C(treatment):C(timepoint) - Sum of Squares: 67.4278
#   PC1 explained variance: 83.57%
#   PC2 explained variance: 16.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 154.7291
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 259.5835
#   PC1 explained variance: 90.19%
#   PC2 explained variance: 9.81%
# C(treatment):C(timepoint) - Sum of Squares: 261.9607
#   PC1 explained variance: 93.56%
#   PC2 explained variance: 6.44%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.0679
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 113.3129
#   PC1 explained variance: 81.70%
#   PC2 explained variance: 18.30%
# C(treatment):C(timepoint) - Sum of Squares: 57.2653
#   PC1 explained variance: 77.50%
#   PC2 explained variance: 22.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.1429
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.5064
#   PC1 explained variance: 81.12%
#   PC2 explained variance: 18.88%
# C(treatment):C(timepoint) - Sum of Squares: 119.7950
#   PC1 explained variance: 92.90%
#   PC2 explained variance: 7.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.9001
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.7434
#   PC1 explained variance: 76.67%
#   PC2 explained variance: 23.33%
# C(treatment):C(timepoint) - Sum of Squares: 55.2513
#   PC1 explained variance: 93.30%
#   PC2 explained variance: 6.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.7737
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.2581
#   PC1 explained variance: 90.70%
#   PC2 explained variance: 9.30%
# C(treatment):C(timepoint) - Sum of Squares: 132.4805
#   PC1 explained variance: 83.13%
#   PC2 explained variance: 16.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 77.7771
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.9942
#   PC1 explained variance: 79.85%
#   PC2 explained variance: 20.15%
# C(treatment):C(timepoint) - Sum of Squares: 70.6955
#   PC1 explained variance: 62.92%
#   PC2 explained variance: 37.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 56.2701
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.9836
#   PC1 explained variance: 82.68%
#   PC2 explained variance: 17.32%
# C(treatment):C(timepoint) - Sum of Squares: 33.6657
#   PC1 explained variance: 84.36%
#   PC2 explained variance: 15.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.4394
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.4072
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
# C(treatment):C(timepoint) - Sum of Squares: 83.4620
#   PC1 explained variance: 63.95%
#   PC2 explained variance: 36.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.9036
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 43.1588
#   PC1 explained variance: 67.38%
#   PC2 explained variance: 32.62%
# C(treatment):C(timepoint) - Sum of Squares: 54.7247
#   PC1 explained variance: 52.50%
#   PC2 explained variance: 47.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.3547
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.9884
#   PC1 explained variance: 57.75%
#   PC2 explained variance: 42.25%
# C(treatment):C(timepoint) - Sum of Squares: 102.1661
#   PC1 explained variance: 78.90%
#   PC2 explained variance: 21.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.4475
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.3868
#   PC1 explained variance: 91.05%
#   PC2 explained variance: 8.95%
# C(treatment):C(timepoint) - Sum of Squares: 79.6215
#   PC1 explained variance: 78.77%
#   PC2 explained variance: 21.23%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0600 (not significant)

# %%
# Continued from PE-ASCA implementation

def pe_asca(data, formula, design_cols, feature_cols, n_permutations=99, alpha=0.05):
    """
    Implement PE-ASCA (Permutation-Enhanced ASCA)

    Note: For real analyses, increase n_permutations to 999 or more
    """
    print("\n=== PE-ASCA Analysis (Permutation-Enhanced ASCA) ===")

    # First, run ASCA+ to get permutation test results
    asca_plus_results = asca_plus(data, formula, design_cols, feature_cols, n_permutations)

    # Extract relevant information
    effect_matrices = asca_plus_results['effect_matrices']
    p_values = asca_plus_results['p_values']

    # Enhanced decomposition: only keep significant effects
    enhanced_matrices = {}
    for effect, p_value in p_values.items():
        if p_value <= alpha:
            enhanced_matrices[effect] = effect_matrices[effect]
            print(f"Effect {effect} is significant (p={p_value:.4f}) and included in enhanced model")
        else:
            # Add non-significant effects to residuals
            if 'Residual' not in enhanced_matrices:
                enhanced_matrices['Residual'] = effect_matrices[effect].copy()
            else:
                enhanced_matrices['Residual'] += effect_matrices[effect]
            print(f"Effect {effect} is not significant (p={p_value:.4f}) and added to residuals")

    # Add original residuals if not already included
    if 'Residual' not in enhanced_matrices:
        enhanced_matrices['Residual'] = effect_matrices['Residual']
    else:
        enhanced_matrices['Residual'] += effect_matrices['Residual']

    # Apply PCA to each significant effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in enhanced_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            total_ss = np.sum([np.sum(m**2) for m in enhanced_matrices.values()])
            print(f"{effect} - Sum of Squares: {effect_ss:.4f} ({effect_ss/total_ss*100:.2f}% of total)")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Create result structure
    pe_asca_results = {
        'effect_matrices': enhanced_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'p_values': p_values,
        'total_variance': asca_plus_results['total_variance']
    }

    # Visualize PE-ASCA results
    plt.figure(figsize=(12, 5))

    plot_idx = 1
    for effect in enhanced_matrices.keys():
        if effect != 'Residual' and effect in pca_results:
            plt.subplot(1, len(pca_results), plot_idx)

            # Get PC scores
            pc_scores = pca_results[effect][:, 0]

            # Plot based on the effect type
            if effect == 'C(treatment)':
                sns.boxplot(x=data['treatment'], y=pc_scores)
                plt.title(f'PE-ASCA: {effect} (p={p_values[effect]:.3f})')
                plt.xlabel('Treatment')
            elif effect == 'C(timepoint)':
                sns.boxplot(x=data['timepoint'], y=pc_scores)
                plt.title(f'PE-ASCA: {effect} (p={p_values[effect]:.3f})')
                plt.xlabel('Timepoint')
            else:
                # For interaction, create a combined factor
                combined = data['treatment'].astype(str) + '-' + data['timepoint'].astype(str)
                sns.boxplot(x=combined, y=pc_scores)
                plt.title(f'PE-ASCA: {effect} (p={p_values[effect]:.3f})')
                plt.xlabel('Treatment-Timepoint')
                plt.xticks(rotation=45)

            plt.ylabel('PC1 Score')
            plot_idx += 1

    plt.tight_layout()
    plt.show()

    return pe_asca_results

# Run PE-ASCA
pe_asca_results = pe_asca(X_matrix, formula, design_cols, feature_cols, n_permutations=99, alpha=0.05)

# Method 4: LiMM-PCA (Linear Mixed Models with PCA)

def limm_pca(data, feature_cols, verbose=True):
    """
    Implement LiMM-PCA (Linear Mixed Models with PCA)
    """
    if verbose:
        print("\n=== LiMM-PCA Analysis (Linear Mixed Models with PCA) ===")

    # Extract data matrix
    X = data[feature_cols].values

    # Standardize the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Create copy of data with proper string conversion for categorical variables
    data_copy = data.copy()

    # Convert categorical variables to strings
    data_copy['subject_id'] = data_copy['subject_id'].astype(str)
    data_copy['treatment'] = data_copy['treatment'].astype(str)
    data_copy['timepoint'] = data_copy['timepoint'].astype(str)

    # Initialize containers for results
    fixed_effects = {}
    random_effects = {}
    residuals = {}
    pvalues = {}

    # Apply mixed model to each feature
    for i, feature in enumerate(feature_cols):
        if verbose and i % 3 == 0:
            print(f"Processing feature {i+1}/{len(feature_cols)}...")

        # Create mixed model formula
        formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit mixed effects model
        try:
            # Fit the model with explicit specification of groups
            model = mixedlm(formula, data_copy, groups=data_copy['subject_id'])
            result = model.fit(reml=True)

            # Extract fixed effects (predicted values without random effects)
            subjects = data_copy['subject_id'].values
            re_dict = {str(subj): val[0] for subj, val in result.random_effects.items()}

            # Create array for random effects
            subject_effect = np.array([re_dict.get(str(subj), 0) for subj in subjects])

            # Fixed effects = fitted values - random effects
            fixed_effects[feature] = result.fittedvalues - subject_effect

            # Store random effects
            random_effects[feature] = subject_effect

            # Extract residuals
            residuals[feature] = result.resid

            # Store p-values for fixed effects
            pvalues[feature] = result.pvalues

        except Exception as e:
            if verbose:
                print(f"Error fitting model for {feature}: {e}")
            # Use simpler approach if model fails
            fixed_effects[feature] = np.zeros(len(data))
            random_effects[feature] = np.zeros(len(data))
            residuals[feature] = X_scaled[:, i]

    # Convert to matrices
    fixed_matrix = np.column_stack([fixed_effects[feature] for feature in feature_cols])
    random_matrix = np.column_stack([random_effects[feature] for feature in feature_cols])
    resid_matrix = np.column_stack([residuals[feature] for feature in feature_cols])

    # Calculate variance explained
    total_var = np.sum(X_scaled**2)
    fixed_var = np.sum(fixed_matrix**2)
    random_var = np.sum(random_matrix**2)
    resid_var = np.sum(resid_matrix**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Fixed Effects: {fixed_var/total_var*100:.2f}%")
        print(f"Random Effects: {random_var/total_var*100:.2f}%")
        print(f"Residuals: {resid_var/total_var*100:.2f}%")

    # Apply PCA to fixed effects matrix
    pca_fixed = PCA()
    pca_fixed.fit(fixed_matrix)
    fixed_scores = pca_fixed.transform(fixed_matrix)

    if verbose and len(pca_fixed.explained_variance_ratio_) > 0:
        print("\nPCA on Fixed Effects:")
        print(f"PC1 explained variance: {pca_fixed.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_fixed.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_fixed.explained_variance_ratio_[1]*100:.2f}%")

    # Visualize results
    plt.figure(figsize=(15, 5))

    # Plot PC1 scores by treatment
    plt.subplot(1, 3, 1)
    sns.boxplot(x=data['treatment'], y=fixed_scores[:, 0])
    plt.title('LiMM-PCA: Treatment Effect (PC1)')
    plt.xlabel('Treatment')
    plt.ylabel('PC1 Score')

    # Plot PC1 scores by timepoint
    plt.subplot(1, 3, 2)
    sns.boxplot(x=data['timepoint'], y=fixed_scores[:, 0])
    plt.title('LiMM-PCA: Timepoint Effect (PC1)')
    plt.xlabel('Timepoint')
    plt.ylabel('PC1 Score')

    # Plot variance partition
    plt.subplot(1, 3, 3)
    var_df = pd.DataFrame({
        'Component': ['Fixed Effects', 'Random Effects', 'Residuals'],
        'Variance (%)': [fixed_var/total_var*100, random_var/total_var*100, resid_var/total_var*100]
    })
    sns.barplot(x='Component', y='Variance (%)', data=var_df)
    plt.title('LiMM-PCA: Variance Partition')
    plt.ylim(0, 100)
    plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

    # Store results
    results = {
        'fixed_matrix': fixed_matrix,
        'random_matrix': random_matrix,
        'resid_matrix': resid_matrix,
        'pca_fixed': pca_fixed,
        'fixed_scores': fixed_scores,
        'total_var': total_var,
        'fixed_var': fixed_var,
        'random_var': random_var,
        'resid_var': resid_var
    }

    return results

# Run LiMM-PCA
limm_pca_results = limm_pca(X_matrix, feature_cols)

# Method 5: MSCA (Multilevel Simultaneous Component Analysis)

def msca(data, feature_cols, verbose=True):
    """
    Implement MSCA (Multilevel Simultaneous Component Analysis)
    """
    if verbose:
        print("\n=== MSCA Analysis (Multilevel Simultaneous Component Analysis) ===")

    # Extract data
    X = data[feature_cols].values
    subjects = data['subject_id'].unique()
    n_subjects = len(subjects)

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Split data into between-subject and within-subject parts
    X_between = np.zeros_like(X)
    X_within = np.zeros_like(X)

    # Calculate between-subject variation (level 2)
    for subject in subjects:
        subject_indices = data['subject_id'] == subject
        subject_mean = np.mean(X[subject_indices], axis=0)
        X_between[subject_indices] = subject_mean

    # Calculate within-subject variation (level 1)
    X_within = X - X_between

    # Calculate variance explained by each level
    total_var = np.sum(X_centered**2)
    between_var = np.sum(X_between**2)
    within_var = np.sum(X_within**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Between-subject: {between_var/total_var*100:.2f}%")
        print(f"Within-subject: {within_var/total_var*100:.2f}%")

    # Apply PCA to between-subject variation
    pca_between = PCA()
    between_scores = pca_between.fit_transform(X_between)

    # Apply PCA to within-subject variation
    pca_within = PCA()
    within_scores = pca_within.fit_transform(X_within)

    if verbose:
        print("\nPCA on Between-subject Variation:")
        print(f"PC1 explained variance: {pca_between.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_between.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_between.explained_variance_ratio_[1]*100:.2f}%")

        print("\nPCA on Within-subject Variation:")
        print(f"PC1 explained variance: {pca_within.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_within.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_within.explained_variance_ratio_[1]*100:.2f}%")

    # Visualize MSCA results
    plt.figure(figsize=(15, 10))

    # Plot between-subject PC1 vs PC2
    plt.subplot(2, 2, 1)
    sns.scatterplot(x=between_scores[:, 0], y=between_scores[:, 1],
                    hue=data['treatment'], style=data['subject_id'], s=80)
    plt.title('Between-subject: PC1 vs PC2')
    plt.xlabel(f'PC1 ({pca_between.explained_variance_ratio_[0]*100:.1f}%)')
    plt.ylabel(f'PC2 ({pca_between.explained_variance_ratio_[1]*100:.1f}%)')
    plt.legend(title='Treatment', loc='upper right')

    # Plot within-subject PC1 vs PC2
    plt.subplot(2, 2, 2)
    sns.scatterplot(x=within_scores[:, 0], y=within_scores[:, 1],
                    hue=data['timepoint'], style=data['subject_id'], s=80)
    plt.title('Within-subject: PC1 vs PC2')
    plt.xlabel(f'PC1 ({pca_within.explained_variance_ratio_[0]*100:.1f}%)')
    plt.ylabel(f'PC2 ({pca_within.explained_variance_ratio_[1]*100:.1f}%)')
    plt.legend(title='Timepoint', loc='upper right')

    # Plot between-subject PC1 by treatment
    plt.subplot(2, 2, 3)
    sns.boxplot(x=data['treatment'], y=between_scores[:, 0])
    plt.title('Between-subject PC1 by Treatment')
    plt.xlabel('Treatment')
    plt.ylabel('PC1 Score')

    # Plot within-subject PC1 by timepoint
    plt.subplot(2, 2, 4)
    sns.boxplot(x=data['timepoint'], y=within_scores[:, 0])
    plt.title('Within-subject PC1 by Timepoint')
    plt.xlabel('Timepoint')
    plt.ylabel('PC1 Score')

    plt.tight_layout()
    plt.show()

    # Store results
    results = {
        'X_between': X_between,
        'X_within': X_within,
        'pca_between': pca_between,
        'pca_within': pca_within,
        'between_scores': between_scores,
        'within_scores': within_scores,
        'total_var': total_var,
        'between_var': between_var,
        'within_var': within_var
    }

    return results

# Run MSCA analysis
msca_results = msca(X_matrix, feature_cols)

# Method Comparison

def compare_methods(df, asca_results, asca_plus_results, pe_asca_results, limm_pca_results, msca_results):
    """
    Comprehensive comparison of all multivariate methods
    """
    print("\n==== COMPARATIVE ANALYSIS OF MULTIVARIATE METHODS ====")

    # 1. Setup figure for visualization
    fig = plt.figure(figsize=(20, 22))
    gs = gridspec.GridSpec(4, 2, height_ratios=[1, 1, 1, 1])

    # 2. Compare variance decomposition across methods
    print("\n1. Variance Decomposition Comparison:")

    # Extract variance components
    variances = {
        'ASCA': {
            'Treatment': np.sum(asca_results['effect_matrices']['C(treatment)']**2) / asca_results['total_variance'],
            'Timepoint': np.sum(asca_results['effect_matrices']['C(timepoint)']**2) / asca_results['total_variance'],
            'Interaction': np.sum(asca_results['effect_matrices']['C(treatment):C(timepoint)']**2) / asca_results['total_variance'],
            'Residual': np.sum(asca_results['effect_matrices']['Residual']**2) / asca_results['total_variance']
        }
    }

    # Add PE-ASCA variance components (might be different due to non-significant effects)
    variances['PE-ASCA'] = {}
    for effect in asca_results['effect_matrices'].keys():
        if effect in pe_asca_results['effect_matrices']:
            variances['PE-ASCA'][effect.replace('C(', '').replace(')', '')] = (
                np.sum(pe_asca_results['effect_matrices'][effect]**2) / pe_asca_results['total_variance']
            )
        else:
            variances['PE-ASCA'][effect.replace('C(', '').replace(')', '')] = 0

    # Add LiMM-PCA variance components
    variances['LiMM-PCA'] = {
        'Fixed Effects': limm_pca_results['fixed_var'] / limm_pca_results['total_var'],
        'Random Effects': limm_pca_results['random_var'] / limm_pca_results['total_var'],
        'Residual': limm_pca_results['resid_var'] / limm_pca_results['total_var']
    }

    # Add MSCA variance components
    variances['MSCA'] = {
        'Between-subject': msca_results['between_var'] / msca_results['total_var'],
        'Within-subject': msca_results['within_var'] / msca_results['total_var']
    }

    # Create variance decomposition dataframe
    variance_df = pd.DataFrame(columns=['Method', 'Component', 'Variance Percentage'])

    for method, components in variances.items():
        for component, value in components.items():
            variance_df = pd.concat([variance_df, pd.DataFrame({
                'Method': [method],
                'Component': [component],
                'Variance Percentage': [value * 100]
            })], ignore_index=True)

    # Plot variance decomposition
    ax1 = plt.subplot(gs[0, :])
    sns.barplot(x='Method', y='Variance Percentage', hue='Component', data=variance_df, ax=ax1)
    ax1.set_title('Variance Decomposition Across Methods', fontsize=14)
    ax1.set_ylabel('Percentage of Total Variance (%)')
    ax1.legend(title='Component', bbox_to_anchor=(1.05, 1), loc='upper left')

    # Print variance decomposition table
    print(variance_df.pivot(index='Component', columns='Method', values='Variance Percentage').round(2))

    plt.tight_layout()
    plt.show()

    return variance_df

# Only run this if you've successfully run all methods
try:
    variance_df = compare_methods(df, asca_results, asca_plus_results, pe_asca_results, limm_pca_results, msca_results)
except Exception as e:
    print(f"Could not complete method comparison: {e}")
    print("Make sure you've successfully run all methods before comparison.")

# Exporting Results

def export_results_summary(df, asca_results, pe_asca_results, msca_results):
    """Export summary of results to CSV files"""

    # 1. Variance decomposition summary
    variance_summary = pd.DataFrame({
        'Component': ['Treatment', 'Timepoint', 'Interaction', 'Between-subject', 'Within-subject', 'Residual'],
        'ASCA_pct': [
            np.sum(asca_results['effect_matrices']['C(treatment)']**2) / asca_results['total_variance'] * 100,
            np.sum(asca_results['effect_matrices']['C(timepoint)']**2) / asca_results['total_variance'] * 100,
            np.sum(asca_results['effect_matrices']['C(treatment):C(timepoint)']**2) / asca_results['total_variance'] * 100,
            np.nan,
            np.nan,
            np.sum(asca_results['effect_matrices']['Residual']**2) / asca_results['total_variance'] * 100
        ],
        'PE-ASCA_pct': [
            np.sum(pe_asca_results['effect_matrices'].get('C(treatment)', np.zeros_like(df[feature_cols].values))**2) / pe_asca_results['total_variance'] * 100,
            np.sum(pe_asca_results['effect_matrices'].get('C(timepoint)', np.zeros_like(df[feature_cols].values))**2) / pe_asca_results['total_variance'] * 100,
            np.sum(pe_asca_results['effect_matrices'].get('C(treatment):C(timepoint)', np.zeros_like(df[feature_cols].values))**2) / pe_asca_results['total_variance'] * 100,
            np.nan,
            np.nan,
            np.sum(pe_asca_results['effect_matrices']['Residual']**2) / pe_asca_results['total_variance'] * 100
        ],
        'MSCA_pct': [
            np.nan,
            np.nan,
            np.nan,
            msca_results['between_var'] / msca_results['total_var'] * 100,
            msca_results['within_var'] / msca_results['total_var'] * 100,
            np.nan
        ]
    })

    # 2. PCA explained variance summary
    pca_summary = pd.DataFrame({
        'Component': ['Treatment_PC1', 'Treatment_PC2', 'Timepoint_PC1', 'Timepoint_PC2',
                     'Interaction_PC1', 'Interaction_PC2', 'Between_PC1', 'Between_PC2',
                     'Within_PC1', 'Within_PC2'],
        'ASCA_pct': [
            asca_results['explained_var']['C(treatment)'][0] * 100 if len(asca_results['explained_var']['C(treatment)']) > 0 else np.nan,
            asca_results['explained_var']['C(treatment)'][1] * 100 if len(asca_results['explained_var']['C(treatment)']) > 1 else np.nan,
            asca_results['explained_var']['C(timepoint)'][0] * 100 if len(asca_results['explained_var']['C(timepoint)']) > 0 else np.nan,
            asca_results['explained_var']['C(timepoint)'][1] * 100 if len(asca_results['explained_var']['C(timepoint)']) > 1 else np.nan,
            asca_results['explained_var']['C(treatment):C(timepoint)'][0] * 100 if len(asca_results['explained_var']['C(treatment):C(timepoint)']) > 0 else np.nan,
            asca_results['explained_var']['C(treatment):C(timepoint)'][1] * 100 if len(asca_results['explained_var']['C(treatment):C(timepoint)']) > 1 else np.nan,
            np.nan, np.nan, np.nan, np.nan
        ],
        'PE-ASCA_pct': [
            pe_asca_results['explained_var'].get('C(treatment)', [0, 0])[0] * 100 if 'C(treatment)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(treatment)']) > 0 else np.nan,
            pe_asca_results['explained_var'].get('C(treatment)', [0, 0])[1] * 100 if 'C(treatment)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(treatment)']) > 1 else np.nan,
            pe_asca_results['explained_var'].get('C(timepoint)', [0, 0])[0] * 100 if 'C(timepoint)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(timepoint)']) > 0 else np.nan,
            pe_asca_results['explained_var'].get('C(timepoint)', [0, 0])[1] * 100 if 'C(timepoint)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(timepoint)']) > 1 else np.nan,
            pe_asca_results['explained_var'].get('C(treatment):C(timepoint)', [0, 0])[0] * 100 if 'C(treatment):C(timepoint)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(treatment):C(timepoint)']) > 0 else np.nan,
            pe_asca_results['explained_var'].get('C(treatment):C(timepoint)', [0, 0])[1] * 100 if 'C(treatment):C(timepoint)' in pe_asca_results['explained_var'] and len(pe_asca_results['explained_var']['C(treatment):C(timepoint)']) > 1 else np.nan,
            np.nan, np.nan, np.nan, np.nan
        ],
        'MSCA_pct': [
            np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
            msca_results['pca_between'].explained_variance_ratio_[0] * 100,
            msca_results['pca_between'].explained_variance_ratio_[1] * 100,
            msca_results['pca_within'].explained_variance_ratio_[0] * 100,
            msca_results['pca_within'].explained_variance_ratio_[1] * 100
        ]
    })

    # Export to CSV
    variance_summary.to_csv('variance_decomposition_summary.csv', index=False)
    pca_summary.to_csv('pca_explained_variance_summary.csv', index=False)

    print("Results exported to CSV files:")
    print("- variance_decomposition_summary.csv")
    print("- pca_explained_variance_summary.csv")

# Export results (if all methods completed successfully)
try:
    export_results_summary(df, asca_results, pe_asca_results, msca_results)
except Exception as e:
    print(f"Could not export all results: {e}")
    print("Make sure you've successfully run all methods before exporting.")
# Out:
# === PE-ASCA Analysis (Permutation-Enhanced ASCA) ===
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.2545
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 27.3329
#   PC1 explained variance: 78.49%
#   PC2 explained variance: 21.51%
# C(treatment):C(timepoint) - Sum of Squares: 29.4738
#   PC1 explained variance: 83.97%
#   PC2 explained variance: 16.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.7013
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.1399
#   PC1 explained variance: 74.90%
#   PC2 explained variance: 25.10%
# C(treatment):C(timepoint) - Sum of Squares: 111.8756
#   PC1 explained variance: 81.36%
#   PC2 explained variance: 18.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.1361
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.7540
#   PC1 explained variance: 62.81%
#   PC2 explained variance: 37.19%
# C(treatment):C(timepoint) - Sum of Squares: 48.1752
#   PC1 explained variance: 82.64%
#   PC2 explained variance: 17.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.9011
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.5508
#   PC1 explained variance: 64.13%
#   PC2 explained variance: 35.87%
# C(treatment):C(timepoint) - Sum of Squares: 17.5364
#   PC1 explained variance: 69.16%
#   PC2 explained variance: 30.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 66.1348
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.6486
#   PC1 explained variance: 85.99%
#   PC2 explained variance: 14.01%
# C(treatment):C(timepoint) - Sum of Squares: 50.9172
#   PC1 explained variance: 74.25%
#   PC2 explained variance: 25.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.1784
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 172.8445
#   PC1 explained variance: 59.52%
#   PC2 explained variance: 40.48%
# C(treatment):C(timepoint) - Sum of Squares: 126.7074
#   PC1 explained variance: 94.72%
#   PC2 explained variance: 5.28%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.7101
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.1722
#   PC1 explained variance: 63.71%
#   PC2 explained variance: 36.29%
# C(treatment):C(timepoint) - Sum of Squares: 37.0255
#   PC1 explained variance: 54.58%
#   PC2 explained variance: 45.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 172.2891
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 145.9829
#   PC1 explained variance: 92.95%
#   PC2 explained variance: 7.05%
# C(treatment):C(timepoint) - Sum of Squares: 108.9758
#   PC1 explained variance: 89.92%
#   PC2 explained variance: 10.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.4650
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.9447
#   PC1 explained variance: 70.25%
#   PC2 explained variance: 29.75%
# C(treatment):C(timepoint) - Sum of Squares: 53.3156
#   PC1 explained variance: 55.77%
#   PC2 explained variance: 44.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.0620
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8393
#   PC1 explained variance: 78.12%
#   PC2 explained variance: 21.88%
# C(treatment):C(timepoint) - Sum of Squares: 119.6388
#   PC1 explained variance: 78.86%
#   PC2 explained variance: 21.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.3314
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 30.8562
#   PC1 explained variance: 91.02%
#   PC2 explained variance: 8.98%
# C(treatment):C(timepoint) - Sum of Squares: 57.7767
#   PC1 explained variance: 55.04%
#   PC2 explained variance: 44.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.2414
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.8524
#   PC1 explained variance: 90.01%
#   PC2 explained variance: 9.99%
# C(treatment):C(timepoint) - Sum of Squares: 110.3825
#   PC1 explained variance: 93.76%
#   PC2 explained variance: 6.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 31.4075
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.9352
#   PC1 explained variance: 73.77%
#   PC2 explained variance: 26.23%
# C(treatment):C(timepoint) - Sum of Squares: 47.1571
#   PC1 explained variance: 91.51%
#   PC2 explained variance: 8.49%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.8346
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.4181
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
# C(treatment):C(timepoint) - Sum of Squares: 33.9097
#   PC1 explained variance: 57.71%
#   PC2 explained variance: 42.29%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 97.4321
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.3464
#   PC1 explained variance: 63.43%
#   PC2 explained variance: 36.57%
# C(treatment):C(timepoint) - Sum of Squares: 130.0520
#   PC1 explained variance: 83.87%
#   PC2 explained variance: 16.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.9729
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.6007
#   PC1 explained variance: 91.02%
#   PC2 explained variance: 8.98%
# C(treatment):C(timepoint) - Sum of Squares: 64.2794
#   PC1 explained variance: 58.87%
#   PC2 explained variance: 41.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 138.9466
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 102.7825
#   PC1 explained variance: 90.47%
#   PC2 explained variance: 9.53%
# C(treatment):C(timepoint) - Sum of Squares: 124.1681
#   PC1 explained variance: 86.05%
#   PC2 explained variance: 13.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.7009
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 107.5537
#   PC1 explained variance: 65.70%
#   PC2 explained variance: 34.30%
# C(treatment):C(timepoint) - Sum of Squares: 52.8664
#   PC1 explained variance: 66.19%
#   PC2 explained variance: 33.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.6536
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.3649
#   PC1 explained variance: 63.73%
#   PC2 explained variance: 36.27%
# C(treatment):C(timepoint) - Sum of Squares: 110.5032
#   PC1 explained variance: 84.89%
#   PC2 explained variance: 15.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.6185
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 87.3657
#   PC1 explained variance: 69.15%
#   PC2 explained variance: 30.85%
# C(treatment):C(timepoint) - Sum of Squares: 104.8970
#   PC1 explained variance: 62.88%
#   PC2 explained variance: 37.12%
#   Completed 20 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.6099
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 52.8385
#   PC1 explained variance: 69.85%
#   PC2 explained variance: 30.15%
# C(treatment):C(timepoint) - Sum of Squares: 109.3501
#   PC1 explained variance: 71.22%
#   PC2 explained variance: 28.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.3221
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.5187
#   PC1 explained variance: 54.20%
#   PC2 explained variance: 45.80%
# C(treatment):C(timepoint) - Sum of Squares: 61.2196
#   PC1 explained variance: 66.32%
#   PC2 explained variance: 33.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.4296
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 108.5456
#   PC1 explained variance: 78.22%
#   PC2 explained variance: 21.78%
# C(treatment):C(timepoint) - Sum of Squares: 92.0795
#   PC1 explained variance: 69.47%
#   PC2 explained variance: 30.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.1214
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.3653
#   PC1 explained variance: 76.30%
#   PC2 explained variance: 23.70%
# C(treatment):C(timepoint) - Sum of Squares: 61.7190
#   PC1 explained variance: 83.11%
#   PC2 explained variance: 16.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.4795
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.0259
#   PC1 explained variance: 80.46%
#   PC2 explained variance: 19.54%
# C(treatment):C(timepoint) - Sum of Squares: 116.8375
#   PC1 explained variance: 68.16%
#   PC2 explained variance: 31.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.5356
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.3898
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 69.8600
#   PC1 explained variance: 61.30%
#   PC2 explained variance: 38.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.9924
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.6166
#   PC1 explained variance: 82.73%
#   PC2 explained variance: 17.27%
# C(treatment):C(timepoint) - Sum of Squares: 62.0948
#   PC1 explained variance: 64.14%
#   PC2 explained variance: 35.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.9945
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.1001
#   PC1 explained variance: 61.14%
#   PC2 explained variance: 38.86%
# C(treatment):C(timepoint) - Sum of Squares: 64.4625
#   PC1 explained variance: 72.00%
#   PC2 explained variance: 28.00%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.2137
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.6902
#   PC1 explained variance: 80.22%
#   PC2 explained variance: 19.78%
# C(treatment):C(timepoint) - Sum of Squares: 76.4132
#   PC1 explained variance: 87.92%
#   PC2 explained variance: 12.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 16.0991
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.3942
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
# C(treatment):C(timepoint) - Sum of Squares: 39.7173
#   PC1 explained variance: 86.61%
#   PC2 explained variance: 13.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.6300
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 131.5219
#   PC1 explained variance: 79.77%
#   PC2 explained variance: 20.23%
# C(treatment):C(timepoint) - Sum of Squares: 79.3282
#   PC1 explained variance: 75.14%
#   PC2 explained variance: 24.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 123.8235
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 189.9530
#   PC1 explained variance: 81.02%
#   PC2 explained variance: 18.98%
# C(treatment):C(timepoint) - Sum of Squares: 174.2882
#   PC1 explained variance: 80.03%
#   PC2 explained variance: 19.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.4799
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 106.3065
#   PC1 explained variance: 88.89%
#   PC2 explained variance: 11.11%
# C(treatment):C(timepoint) - Sum of Squares: 63.9541
#   PC1 explained variance: 86.50%
#   PC2 explained variance: 13.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.1764
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.4255
#   PC1 explained variance: 68.95%
#   PC2 explained variance: 31.05%
# C(treatment):C(timepoint) - Sum of Squares: 80.0453
#   PC1 explained variance: 86.65%
#   PC2 explained variance: 13.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.0464
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 105.8244
#   PC1 explained variance: 57.96%
#   PC2 explained variance: 42.04%
# C(treatment):C(timepoint) - Sum of Squares: 42.6747
#   PC1 explained variance: 56.32%
#   PC2 explained variance: 43.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 49.4068
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.9217
#   PC1 explained variance: 75.93%
#   PC2 explained variance: 24.07%
# C(treatment):C(timepoint) - Sum of Squares: 71.9164
#   PC1 explained variance: 56.73%
#   PC2 explained variance: 43.27%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 140.6866
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 122.2296
#   PC1 explained variance: 76.61%
#   PC2 explained variance: 23.39%
# C(treatment):C(timepoint) - Sum of Squares: 123.7475
#   PC1 explained variance: 79.17%
#   PC2 explained variance: 20.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.3024
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 75.1250
#   PC1 explained variance: 66.65%
#   PC2 explained variance: 33.35%
# C(treatment):C(timepoint) - Sum of Squares: 40.9930
#   PC1 explained variance: 63.72%
#   PC2 explained variance: 36.28%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.2699
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 87.8006
#   PC1 explained variance: 63.78%
#   PC2 explained variance: 36.22%
# C(treatment):C(timepoint) - Sum of Squares: 40.3520
#   PC1 explained variance: 81.42%
#   PC2 explained variance: 18.58%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.4721
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.0675
#   PC1 explained variance: 92.51%
#   PC2 explained variance: 7.49%
# C(treatment):C(timepoint) - Sum of Squares: 105.0262
#   PC1 explained variance: 64.69%
#   PC2 explained variance: 35.31%
#   Completed 40 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 16.9922
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 75.9050
#   PC1 explained variance: 94.89%
#   PC2 explained variance: 5.11%
# C(treatment):C(timepoint) - Sum of Squares: 83.3314
#   PC1 explained variance: 81.10%
#   PC2 explained variance: 18.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 47.2150
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 84.4486
#   PC1 explained variance: 58.73%
#   PC2 explained variance: 41.27%
# C(treatment):C(timepoint) - Sum of Squares: 83.2600
#   PC1 explained variance: 85.80%
#   PC2 explained variance: 14.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.8138
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.6461
#   PC1 explained variance: 52.36%
#   PC2 explained variance: 47.64%
# C(treatment):C(timepoint) - Sum of Squares: 44.0532
#   PC1 explained variance: 54.93%
#   PC2 explained variance: 45.07%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.2705
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.3149
#   PC1 explained variance: 88.15%
#   PC2 explained variance: 11.85%
# C(treatment):C(timepoint) - Sum of Squares: 84.6056
#   PC1 explained variance: 85.24%
#   PC2 explained variance: 14.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.3379
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.2851
#   PC1 explained variance: 90.47%
#   PC2 explained variance: 9.53%
# C(treatment):C(timepoint) - Sum of Squares: 56.1924
#   PC1 explained variance: 77.48%
#   PC2 explained variance: 22.52%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.1780
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.7945
#   PC1 explained variance: 84.97%
#   PC2 explained variance: 15.03%
# C(treatment):C(timepoint) - Sum of Squares: 31.8513
#   PC1 explained variance: 82.77%
#   PC2 explained variance: 17.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 93.0555
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 40.8709
#   PC1 explained variance: 85.50%
#   PC2 explained variance: 14.50%
# C(treatment):C(timepoint) - Sum of Squares: 137.4063
#   PC1 explained variance: 96.77%
#   PC2 explained variance: 3.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 76.7784
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 155.6900
#   PC1 explained variance: 89.99%
#   PC2 explained variance: 10.01%
# C(treatment):C(timepoint) - Sum of Squares: 170.2243
#   PC1 explained variance: 83.35%
#   PC2 explained variance: 16.65%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 14.2465
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 75.3383
#   PC1 explained variance: 68.44%
#   PC2 explained variance: 31.56%
# C(treatment):C(timepoint) - Sum of Squares: 31.6642
#   PC1 explained variance: 82.12%
#   PC2 explained variance: 17.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.8235
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.0379
#   PC1 explained variance: 66.29%
#   PC2 explained variance: 33.71%
# C(treatment):C(timepoint) - Sum of Squares: 82.6352
#   PC1 explained variance: 81.25%
#   PC2 explained variance: 18.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 164.0479
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 105.7186
#   PC1 explained variance: 81.13%
#   PC2 explained variance: 18.87%
# C(treatment):C(timepoint) - Sum of Squares: 62.7267
#   PC1 explained variance: 72.99%
#   PC2 explained variance: 27.01%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.0225
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.5658
#   PC1 explained variance: 62.11%
#   PC2 explained variance: 37.89%
# C(treatment):C(timepoint) - Sum of Squares: 42.9233
#   PC1 explained variance: 63.47%
#   PC2 explained variance: 36.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 147.7738
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 129.7897
#   PC1 explained variance: 77.13%
#   PC2 explained variance: 22.87%
# C(treatment):C(timepoint) - Sum of Squares: 112.4990
#   PC1 explained variance: 64.70%
#   PC2 explained variance: 35.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 133.9010
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 137.9554
#   PC1 explained variance: 79.36%
#   PC2 explained variance: 20.64%
# C(treatment):C(timepoint) - Sum of Squares: 158.9739
#   PC1 explained variance: 69.12%
#   PC2 explained variance: 30.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.4027
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.9267
#   PC1 explained variance: 68.65%
#   PC2 explained variance: 31.35%
# C(treatment):C(timepoint) - Sum of Squares: 127.9797
#   PC1 explained variance: 78.32%
#   PC2 explained variance: 21.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.8019
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 70.7067
#   PC1 explained variance: 87.82%
#   PC2 explained variance: 12.18%
# C(treatment):C(timepoint) - Sum of Squares: 74.1196
#   PC1 explained variance: 73.77%
#   PC2 explained variance: 26.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.5916
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.4259
#   PC1 explained variance: 60.10%
#   PC2 explained variance: 39.90%
# C(treatment):C(timepoint) - Sum of Squares: 53.9579
#   PC1 explained variance: 64.83%
#   PC2 explained variance: 35.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.7607
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.9135
#   PC1 explained variance: 78.15%
#   PC2 explained variance: 21.85%
# C(treatment):C(timepoint) - Sum of Squares: 95.1771
#   PC1 explained variance: 87.14%
#   PC2 explained variance: 12.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 7.9712
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 36.4444
#   PC1 explained variance: 54.08%
#   PC2 explained variance: 45.92%
# C(treatment):C(timepoint) - Sum of Squares: 24.7537
#   PC1 explained variance: 62.40%
#   PC2 explained variance: 37.60%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 93.6156
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.0966
#   PC1 explained variance: 74.25%
#   PC2 explained variance: 25.75%
# C(treatment):C(timepoint) - Sum of Squares: 121.1195
#   PC1 explained variance: 95.26%
#   PC2 explained variance: 4.74%
#   Completed 60 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 64.0938
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 88.3780
#   PC1 explained variance: 64.62%
#   PC2 explained variance: 35.38%
# C(treatment):C(timepoint) - Sum of Squares: 64.2572
#   PC1 explained variance: 86.16%
#   PC2 explained variance: 13.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.0039
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.9835
#   PC1 explained variance: 88.66%
#   PC2 explained variance: 11.34%
# C(treatment):C(timepoint) - Sum of Squares: 71.4588
#   PC1 explained variance: 68.04%
#   PC2 explained variance: 31.96%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.4805
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.5920
#   PC1 explained variance: 59.83%
#   PC2 explained variance: 40.17%
# C(treatment):C(timepoint) - Sum of Squares: 47.1551
#   PC1 explained variance: 90.75%
#   PC2 explained variance: 9.25%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.9953
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.0041
#   PC1 explained variance: 62.43%
#   PC2 explained variance: 37.57%
# C(treatment):C(timepoint) - Sum of Squares: 134.0838
#   PC1 explained variance: 64.22%
#   PC2 explained variance: 35.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.5320
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.9306
#   PC1 explained variance: 66.83%
#   PC2 explained variance: 33.17%
# C(treatment):C(timepoint) - Sum of Squares: 114.4919
#   PC1 explained variance: 80.76%
#   PC2 explained variance: 19.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 138.1924
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 128.4494
#   PC1 explained variance: 62.10%
#   PC2 explained variance: 37.90%
# C(treatment):C(timepoint) - Sum of Squares: 167.4353
#   PC1 explained variance: 63.28%
#   PC2 explained variance: 36.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.5579
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.8344
#   PC1 explained variance: 75.58%
#   PC2 explained variance: 24.42%
# C(treatment):C(timepoint) - Sum of Squares: 48.8830
#   PC1 explained variance: 59.01%
#   PC2 explained variance: 40.99%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.1289
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.9574
#   PC1 explained variance: 73.25%
#   PC2 explained variance: 26.75%
# C(treatment):C(timepoint) - Sum of Squares: 65.2961
#   PC1 explained variance: 74.72%
#   PC2 explained variance: 25.28%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.4385
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.3685
#   PC1 explained variance: 70.85%
#   PC2 explained variance: 29.15%
# C(treatment):C(timepoint) - Sum of Squares: 62.9679
#   PC1 explained variance: 59.80%
#   PC2 explained variance: 40.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.8172
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.9868
#   PC1 explained variance: 65.05%
#   PC2 explained variance: 34.95%
# C(treatment):C(timepoint) - Sum of Squares: 77.5605
#   PC1 explained variance: 88.84%
#   PC2 explained variance: 11.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6198
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 44.9746
#   PC1 explained variance: 67.23%
#   PC2 explained variance: 32.77%
# C(treatment):C(timepoint) - Sum of Squares: 73.3071
#   PC1 explained variance: 90.12%
#   PC2 explained variance: 9.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 112.1787
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 92.2843
#   PC1 explained variance: 88.73%
#   PC2 explained variance: 11.27%
# C(treatment):C(timepoint) - Sum of Squares: 145.7468
#   PC1 explained variance: 84.83%
#   PC2 explained variance: 15.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 92.7923
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8309
#   PC1 explained variance: 68.40%
#   PC2 explained variance: 31.60%
# C(treatment):C(timepoint) - Sum of Squares: 54.1722
#   PC1 explained variance: 75.47%
#   PC2 explained variance: 24.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.8420
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.4897
#   PC1 explained variance: 60.04%
#   PC2 explained variance: 39.96%
# C(treatment):C(timepoint) - Sum of Squares: 64.2805
#   PC1 explained variance: 54.18%
#   PC2 explained variance: 45.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.9798
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.8588
#   PC1 explained variance: 71.36%
#   PC2 explained variance: 28.64%
# C(treatment):C(timepoint) - Sum of Squares: 136.3190
#   PC1 explained variance: 57.61%
#   PC2 explained variance: 42.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.7355
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.3260
#   PC1 explained variance: 88.75%
#   PC2 explained variance: 11.25%
# C(treatment):C(timepoint) - Sum of Squares: 87.5063
#   PC1 explained variance: 94.97%
#   PC2 explained variance: 5.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.7606
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.3878
#   PC1 explained variance: 67.27%
#   PC2 explained variance: 32.73%
# C(treatment):C(timepoint) - Sum of Squares: 46.7964
#   PC1 explained variance: 55.16%
#   PC2 explained variance: 44.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.4731
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.5275
#   PC1 explained variance: 60.81%
#   PC2 explained variance: 39.19%
# C(treatment):C(timepoint) - Sum of Squares: 40.2915
#   PC1 explained variance: 83.53%
#   PC2 explained variance: 16.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.5775
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.0589
#   PC1 explained variance: 81.41%
#   PC2 explained variance: 18.59%
# C(treatment):C(timepoint) - Sum of Squares: 89.0888
#   PC1 explained variance: 95.05%
#   PC2 explained variance: 4.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.4983
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.0859
#   PC1 explained variance: 67.05%
#   PC2 explained variance: 32.95%
# C(treatment):C(timepoint) - Sum of Squares: 126.2874
#   PC1 explained variance: 90.09%
#   PC2 explained variance: 9.91%
#   Completed 80 permutations
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.1746
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.1026
#   PC1 explained variance: 83.49%
#   PC2 explained variance: 16.51%
# C(treatment):C(timepoint) - Sum of Squares: 42.1619
#   PC1 explained variance: 78.87%
#   PC2 explained variance: 21.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.2323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.3496
#   PC1 explained variance: 92.92%
#   PC2 explained variance: 7.08%
# C(treatment):C(timepoint) - Sum of Squares: 73.4514
#   PC1 explained variance: 75.10%
#   PC2 explained variance: 24.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.8108
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.4396
#   PC1 explained variance: 57.89%
#   PC2 explained variance: 42.11%
# C(treatment):C(timepoint) - Sum of Squares: 82.9862
#   PC1 explained variance: 72.33%
#   PC2 explained variance: 27.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.7679
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 98.9390
#   PC1 explained variance: 79.47%
#   PC2 explained variance: 20.53%
# C(treatment):C(timepoint) - Sum of Squares: 102.2909
#   PC1 explained variance: 75.53%
#   PC2 explained variance: 24.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.5054
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 39.9591
#   PC1 explained variance: 67.87%
#   PC2 explained variance: 32.13%
# C(treatment):C(timepoint) - Sum of Squares: 77.7079
#   PC1 explained variance: 74.83%
#   PC2 explained variance: 25.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.8095
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.7352
#   PC1 explained variance: 58.17%
#   PC2 explained variance: 41.83%
# C(treatment):C(timepoint) - Sum of Squares: 58.6922
#   PC1 explained variance: 67.60%
#   PC2 explained variance: 32.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 207.6415
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.5652
#   PC1 explained variance: 74.97%
#   PC2 explained variance: 25.03%
# C(treatment):C(timepoint) - Sum of Squares: 164.7368
#   PC1 explained variance: 91.18%
#   PC2 explained variance: 8.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 138.5167
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.6042
#   PC1 explained variance: 78.59%
#   PC2 explained variance: 21.41%
# C(treatment):C(timepoint) - Sum of Squares: 105.0695
#   PC1 explained variance: 91.13%
#   PC2 explained variance: 8.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.2061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.0477
#   PC1 explained variance: 56.43%
#   PC2 explained variance: 43.57%
# C(treatment):C(timepoint) - Sum of Squares: 52.2624
#   PC1 explained variance: 78.95%
#   PC2 explained variance: 21.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.2227
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.8702
#   PC1 explained variance: 72.77%
#   PC2 explained variance: 27.23%
# C(treatment):C(timepoint) - Sum of Squares: 66.1411
#   PC1 explained variance: 87.84%
#   PC2 explained variance: 12.16%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6855
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 111.5940
#   PC1 explained variance: 89.99%
#   PC2 explained variance: 10.01%
# C(treatment):C(timepoint) - Sum of Squares: 81.2256
#   PC1 explained variance: 77.78%
#   PC2 explained variance: 22.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.5325
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 118.7682
#   PC1 explained variance: 87.20%
#   PC2 explained variance: 12.80%
# C(treatment):C(timepoint) - Sum of Squares: 42.0798
#   PC1 explained variance: 73.57%
#   PC2 explained variance: 26.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.2930
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.6663
#   PC1 explained variance: 75.66%
#   PC2 explained variance: 24.34%
# C(treatment):C(timepoint) - Sum of Squares: 93.5337
#   PC1 explained variance: 68.82%
#   PC2 explained variance: 31.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.2881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 88.6973
#   PC1 explained variance: 71.00%
#   PC2 explained variance: 29.00%
# C(treatment):C(timepoint) - Sum of Squares: 82.1089
#   PC1 explained variance: 82.92%
#   PC2 explained variance: 17.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 128.7708
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 121.5047
#   PC1 explained variance: 80.21%
#   PC2 explained variance: 19.79%
# C(treatment):C(timepoint) - Sum of Squares: 228.6359
#   PC1 explained variance: 92.29%
#   PC2 explained variance: 7.71%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.8738
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 38.5953
#   PC1 explained variance: 66.30%
#   PC2 explained variance: 33.70%
# C(treatment):C(timepoint) - Sum of Squares: 55.6615
#   PC1 explained variance: 62.30%
#   PC2 explained variance: 37.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.7559
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 109.8221
#   PC1 explained variance: 90.07%
#   PC2 explained variance: 9.93%
# C(treatment):C(timepoint) - Sum of Squares: 131.8791
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.1000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.4753
#   PC1 explained variance: 79.63%
#   PC2 explained variance: 20.37%
# C(treatment):C(timepoint) - Sum of Squares: 55.2224
#   PC1 explained variance: 74.39%
#   PC2 explained variance: 25.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.8653
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.3050
#   PC1 explained variance: 58.18%
#   PC2 explained variance: 41.82%
# C(treatment):C(timepoint) - Sum of Squares: 116.5312
#   PC1 explained variance: 75.17%
#   PC2 explained variance: 24.83%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0700 (not significant)
# Effect C(treatment) is significant (p=0.0100) and included in enhanced model
# Effect C(timepoint) is significant (p=0.0100) and included in enhanced model
# Effect C(treatment):C(timepoint) is not significant (p=0.0700) and added to residuals
# C(treatment) - Sum of Squares: 592.6881 (35.97% of total)
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804 (35.93% of total)
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# === LiMM-PCA Analysis (Linear Mixed Models with PCA) ===
# Processing feature 1/10...
# Processing feature 4/10...
# Processing feature 7/10...
# Processing feature 10/10...
#
# Variance Partition:
# Fixed Effects: 65.05%
# Random Effects: 18.15%
# Residuals: 9.57%
#
# PCA on Fixed Effects:
# PC1 explained variance: 44.23%
# PC2 explained variance: 34.29%
# === MSCA Analysis (Multilevel Simultaneous Component Analysis) ===
#
# Variance Partition:
# Between-subject: 51.77%
# Within-subject: 48.23%
#
# PCA on Between-subject Variation:
# PC1 explained variance: 53.02%
# PC2 explained variance: 13.09%
#
# PCA on Within-subject Variation:
# PC1 explained variance: 52.73%
# PC2 explained variance: 23.16%
# ==== COMPARATIVE ANALYSIS OF MULTIVARIATE METHODS ====
#
# 1. Variance Decomposition Comparison:
# Method                ASCA  LiMM-PCA   MSCA  PE-ASCA
# Component
# Between-subject        NaN       NaN  51.77      NaN
# Fixed Effects          NaN     65.05    NaN      NaN
# Interaction          16.49       NaN    NaN      NaN
# Random Effects         NaN     18.15    NaN      NaN
# Residual             34.95      9.57    NaN    51.44
# Timepoint            65.78       NaN    NaN      NaN
# Treatment            65.85       NaN    NaN      NaN
# Within-subject         NaN       NaN  48.23      NaN
# timepoint              NaN       NaN    NaN    65.78
# treatment              NaN       NaN    NaN    65.85
# treatment:timepoint    NaN       NaN    NaN     0.00
# Results exported to CSV files:
# - variance_decomposition_summary.csv
# - pca_explained_variance_summary.csv

# %%
def asca_plus(data, formula, design_cols, feature_cols, n_permutations=999):
    """
    Implement ASCA+ (ASCA with permutation testing)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing

    Returns:
    --------
    Dictionary containing ASCA results plus permutation test results
    """
    print("\n=== ASCA+ Analysis (ASCA with Permutation Testing) ===")

    # Run standard ASCA
    asca_results = asca(data, formula, design_cols, feature_cols)

    # Get effect matrices and calculate sum of squares for each effect
    effect_matrices = asca_results['effect_matrices']
    observed_ss = {effect: np.sum(matrix**2) for effect, matrix in effect_matrices.items()
                 if effect != 'Residual'}

    # Permutation testing
    permuted_ss = {effect: [] for effect in observed_ss.keys()}

    print(f"\nRunning permutation tests with {n_permutations} permutations...")

    for perm in range(n_permutations):
        if perm % 100 == 0 and perm > 0:
            print(f"  Completed {perm} permutations")

        # Create permuted data
        perm_data = data.copy()

        # Permute each factor separately
        for effect in observed_ss.keys():
            if effect == 'C(treatment)':
                # Permute treatment labels
                perm_data['treatment'] = np.random.permutation(perm_data['treatment'].values)
            elif effect == 'C(timepoint)':
                # Permute timepoint labels
                perm_data['timepoint'] = np.random.permutation(perm_data['timepoint'].values)
            elif effect == 'C(treatment):C(timepoint)':
                # Permute interaction by shuffling combinations
                combinations = perm_data[['treatment', 'timepoint']].values
                np.random.shuffle(combinations)
                perm_data['treatment'] = combinations[:, 0]
                perm_data['timepoint'] = combinations[:, 1]

        # Run ASCA on permuted data
        perm_asca = asca(perm_data, formula, design_cols, feature_cols)
        perm_effect_matrices = perm_asca['effect_matrices']

        # Calculate sum of squares for each permuted effect
        for effect in observed_ss.keys():
            perm_ss = np.sum(perm_effect_matrices[effect]**2)
            permuted_ss[effect].append(perm_ss)

    # Calculate p-values
    p_values = {}
    for effect in observed_ss.keys():
        # Count how many permuted SS are >= observed SS
        p_values[effect] = (np.sum(np.array(permuted_ss[effect]) >= observed_ss[effect]) + 1) / (n_permutations + 1)

    print("\nPermutation Test Results:")
    for effect, p_value in p_values.items():
        significance = "significant" if p_value < 0.05 else "not significant"
        print(f"{effect}: p-value = {p_value:.4f} ({significance})")

    # Add results to ASCA results
    asca_results['p_values'] = p_values
    asca_results['permuted_ss'] = permuted_ss

    return asca_results

# %%
def asca_plus(data, formula, design_cols, feature_cols, n_permutations=999):
    """
    Implement ASCA+ (ASCA with permutation testing)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing

    Returns:
    --------
    Dictionary containing ASCA results plus permutation test results
    """
    print("\n=== ASCA+ Analysis (ASCA with Permutation Testing) ===")

    # Run standard ASCA
    asca_results = asca(data, formula, design_cols, feature_cols)

    # Get effect matrices and calculate sum of squares for each effect
    effect_matrices = asca_results['effect_matrices']
    observed_ss = {effect: np.sum(matrix**2) for effect, matrix in effect_matrices.items()
                 if effect != 'Residual'}

    # Permutation testing
    permuted_ss = {effect: [] for effect in observed_ss.keys()}

    print(f"\nRunning permutation tests with {n_permutations} permutations...")

    for perm in range(n_permutations):
        if perm % 100 == 0 and perm > 0:
            print(f"  Completed {perm} permutations")

        # Create permuted data
        perm_data = data.copy()

        # Permute each factor separately
        for effect in observed_ss.keys():
            if effect == 'C(treatment)':
                # Permute treatment labels
                perm_data['treatment'] = np.random.permutation(perm_data['treatment'].values)
            elif effect == 'C(timepoint)':
                # Permute timepoint labels
                perm_data['timepoint'] = np.random.permutation(perm_data['timepoint'].values)
            elif effect == 'C(treatment):C(timepoint)':
                # Permute interaction by shuffling combinations
                combinations = perm_data[['treatment', 'timepoint']].values
                np.random.shuffle(combinations)
                perm_data['treatment'] = combinations[:, 0]
                perm_data['timepoint'] = combinations[:, 1]

        # Run ASCA on permuted data
        perm_asca = asca(perm_data, formula, design_cols, feature_cols)
        perm_effect_matrices = perm_asca['effect_matrices']

        # Calculate sum of squares for each permuted effect
        for effect in observed_ss.keys():
            perm_ss = np.sum(perm_effect_matrices[effect]**2)
            permuted_ss[effect].append(perm_ss)

    # Calculate p-values
    p_values = {}
    for effect in observed_ss.keys():
        # Count how many permuted SS are >= observed SS
        p_values[effect] = (np.sum(np.array(permuted_ss[effect]) >= observed_ss[effect]) + 1) / (n_permutations + 1)

    print("\nPermutation Test Results:")
    for effect, p_value in p_values.items():
        significance = "significant" if p_value < 0.05 else "not significant"
        print(f"{effect}: p-value = {p_value:.4f} ({significance})")

    # Add results to ASCA results
    asca_results['p_values'] = p_values
    asca_results['permuted_ss'] = permuted_ss

    return asca_results

# %%
def pe_asca(data, formula, design_cols, feature_cols, n_permutations=999, alpha=0.05):
    """
    Implement PE-ASCA (Permutation-Enhanced ASCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    formula: str
        ANOVA formula for decomposition
    design_cols: list
        List of column names for design factors
    feature_cols: list
        List of column names for features
    n_permutations: int
        Number of permutations for significance testing
    alpha: float
        Significance level

    Returns:
    --------
    Dictionary containing PE-ASCA results
    """
    print("\n=== PE-ASCA Analysis (Permutation-Enhanced ASCA) ===")

    # First, run ASCA+ to get permutation test results
    asca_plus_results = asca_plus(data, formula, design_cols, feature_cols, n_permutations)

    # Extract relevant information
    effect_matrices = asca_plus_results['effect_matrices']
    p_values = asca_plus_results['p_values']

    # Enhanced decomposition: only keep significant effects
    enhanced_matrices = {}
    for effect, p_value in p_values.items():
        if p_value <= alpha:
            enhanced_matrices[effect] = effect_matrices[effect]
            print(f"Effect {effect} is significant (p={p_value:.4f}) and included in enhanced model")
        else:
            # Add non-significant effects to residuals
            if 'Residual' not in enhanced_matrices:
                enhanced_matrices['Residual'] = effect_matrices[effect].copy()
            else:
                enhanced_matrices['Residual'] += effect_matrices[effect]
            print(f"Effect {effect} is not significant (p={p_value:.4f}) and added to residuals")

    # Add original residuals if not already included
    if 'Residual' not in enhanced_matrices:
        enhanced_matrices['Residual'] = effect_matrices['Residual']
    else:
        enhanced_matrices['Residual'] += effect_matrices['Residual']

    # Apply PCA to each significant effect matrix
    pca_results = {}
    explained_var = {}

    for effect, matrix in enhanced_matrices.items():
        if effect != 'Residual':  # Skip PCA on residuals
            pca = PCA()
            pca_results[effect] = pca.fit_transform(matrix)
            explained_var[effect] = pca.explained_variance_ratio_

            # Print effect summary
            effect_ss = np.sum(matrix**2)
            total_ss = np.sum([np.sum(m**2) for m in enhanced_matrices.values()])
            print(f"{effect} - Sum of Squares: {effect_ss:.4f} ({effect_ss/total_ss*100:.2f}% of total)")
            if len(explained_var[effect]) > 0:
                print(f"  PC1 explained variance: {explained_var[effect][0]*100:.2f}%")
                if len(explained_var[effect]) > 1:
                    print(f"  PC2 explained variance: {explained_var[effect][1]*100:.2f}%")

    # Create result structure
    pe_asca_results = {
        'effect_matrices': enhanced_matrices,
        'pca_results': pca_results,
        'explained_var': explained_var,
        'p_values': p_values,
        'total_variance': asca_plus_results['total_variance']
    }

    return pe_asca_results

# %%
def limm_pca(data, feature_cols, verbose=True):
    """
    Implement LiMM-PCA (Linear Mixed Models with PCA)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing LiMM-PCA results
    """
    if verbose:
        print("\n=== LiMM-PCA Analysis (Linear Mixed Models with PCA) ===")

    # Extract data matrix
    X = data[feature_cols].values

    # Standardize the data
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Create copy of data with proper string conversion for categorical variables
    data_copy = data.copy()

    # Convert categorical variables to strings
    data_copy['subject_id'] = data_copy['subject_id'].astype(str)
    data_copy['treatment'] = data_copy['treatment'].astype(str)
    data_copy['timepoint'] = data_copy['timepoint'].astype(str)

    # Initialize containers for results
    fixed_effects = {}
    random_effects = {}
    residuals = {}
    pvalues = {}

    # Apply mixed model to each feature
    for i, feature in enumerate(feature_cols):
        if verbose and i % 3 == 0:
            print(f"Processing feature {i+1}/{len(feature_cols)}...")

        # Create mixed model formula
        formula = f"{feature} ~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"

        # Fit mixed effects model
        try:
            # Fit the model with explicit specification of groups
            model = mixedlm(formula, data_copy, groups=data_copy['subject_id'])
            result = model.fit(reml=True)

            # Extract fixed effects (predicted values without random effects)
            subjects = data_copy['subject_id'].values
            re_dict = {str(subj): val[0] for subj, val in result.random_effects.items()}

            # Create array for random effects
            subject_effect = np.array([re_dict.get(str(subj), 0) for subj in subjects])

            # Fixed effects = fitted values - random effects
            fixed_effects[feature] = result.fittedvalues - subject_effect

            # Store random effects
            random_effects[feature] = subject_effect

            # Extract residuals
            residuals[feature] = result.resid

            # Store p-values for fixed effects
            pvalues[feature] = result.pvalues

        except Exception as e:
            if verbose:
                print(f"Error fitting model for {feature}: {e}")
            # Use simpler approach if model fails
            fixed_effects[feature] = np.zeros(len(data))
            random_effects[feature] = np.zeros(len(data))
            residuals[feature] = X_scaled[:, i]

    # Convert to matrices
    fixed_matrix = np.column_stack([fixed_effects[feature] for feature in feature_cols])
    random_matrix = np.column_stack([random_effects[feature] for feature in feature_cols])
    resid_matrix = np.column_stack([residuals[feature] for feature in feature_cols])

    # Calculate variance explained
    total_var = np.sum(X_scaled**2)
    fixed_var = np.sum(fixed_matrix**2)
    random_var = np.sum(random_matrix**2)
    resid_var = np.sum(resid_matrix**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Fixed Effects: {fixed_var/total_var*100:.2f}%")
        print(f"Random Effects: {random_var/total_var*100:.2f}%")
        print(f"Residuals: {resid_var/total_var*100:.2f}%")

    # Apply PCA to fixed effects matrix
    pca_fixed = PCA()
    pca_fixed.fit(fixed_matrix)
    fixed_scores = pca_fixed.transform(fixed_matrix)

    if verbose and len(pca_fixed.explained_variance_ratio_) > 0:
        print("\nPCA on Fixed Effects:")
        print(f"PC1 explained variance: {pca_fixed.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_fixed.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_fixed.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'fixed_matrix': fixed_matrix,
        'random_matrix': random_matrix,
        'resid_matrix': resid_matrix,
        'pca_fixed': pca_fixed,
        'fixed_scores': fixed_scores,
        'total_var': total_var,
        'fixed_var': fixed_var,
        'random_var': random_var,
        'resid_var': resid_var
    }

    return results

# %%
def msca(data, feature_cols, verbose=True):
    """
    Implement MSCA (Multilevel Simultaneous Component Analysis)

    Parameters:
    -----------
    data: DataFrame
        Data containing design factors and feature measurements
    feature_cols: list
        List of column names for features
    verbose: bool
        Whether to print detailed output

    Returns:
    --------
    Dictionary containing MSCA results
    """
    if verbose:
        print("\n=== MSCA Analysis (Multilevel Simultaneous Component Analysis) ===")

    # Extract data
    X = data[feature_cols].values
    subjects = data['subject_id'].unique()
    n_subjects = len(subjects)

    # Center the data
    X_centered = X - np.mean(X, axis=0)

    # Split data into between-subject and within-subject parts
    X_between = np.zeros_like(X)
    X_within = np.zeros_like(X)

    # Calculate between-subject variation (level 2)
    for subject in subjects:
        subject_indices = data['subject_id'] == subject
        subject_mean = np.mean(X[subject_indices], axis=0)
        X_between[subject_indices] = subject_mean

    # Calculate within-subject variation (level 1)
    X_within = X - X_between

    # Calculate variance explained by each level
    total_var = np.sum(X_centered**2)
    between_var = np.sum(X_between**2)
    within_var = np.sum(X_within**2)

    if verbose:
        print("\nVariance Partition:")
        print(f"Between-subject: {between_var/total_var*100:.2f}%")
        print(f"Within-subject: {within_var/total_var*100:.2f}%")

    # Apply PCA to between-subject variation
    pca_between = PCA()
    between_scores = pca_between.fit_transform(X_between)

    # Apply PCA to within-subject variation
    pca_within = PCA()
    within_scores = pca_within.fit_transform(X_within)

    if verbose:
        print("\nPCA on Between-subject Variation:")
        print(f"PC1 explained variance: {pca_between.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_between.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_between.explained_variance_ratio_[1]*100:.2f}%")

        print("\nPCA on Within-subject Variation:")
        print(f"PC1 explained variance: {pca_within.explained_variance_ratio_[0]*100:.2f}%")
        if len(pca_within.explained_variance_ratio_) > 1:
            print(f"PC2 explained variance: {pca_within.explained_variance_ratio_[1]*100:.2f}%")

    # Store results
    results = {
        'X_between': X_between,
        'X_within': X_within,
        'pca_between': pca_between,
        'pca_within': pca_within,
        'between_scores': between_scores,
        'within_scores': within_scores,
        'total_var': total_var,
        'between_var': between_var,
        'within_var': within_var
    }

    return results

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.formula.api import ols, mixedlm

# Prepare your data
# Either load from CSV:
# df = pd.read_csv('your_data.csv')
# Or use synthetic data generation function

# Extract feature columns and prepare data matrix
feature_cols = [col for col in df.columns if 'feature' in col]
X = df[feature_cols].values

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Create a data matrix for easier handling
X_matrix = pd.DataFrame(X_scaled, columns=feature_cols)
X_matrix['subject_id'] = df['subject_id']
X_matrix['treatment'] = df['treatment']
X_matrix['timepoint'] = df['timepoint']

# Set up formula and design columns
formula = "~ C(treatment) + C(timepoint) + C(treatment):C(timepoint)"
design_cols = ['treatment', 'timepoint', 'subject_id']

# Run the analyses
asca_results = asca(X_matrix, formula, design_cols, feature_cols)
asca_plus_results = asca_plus(X_matrix, formula, design_cols, feature_cols, n_permutations=99)  # Use 999+ for final analysis
pe_asca_results = pe_asca(X_matrix, formula, design_cols, feature_cols, n_permutations=99, alpha=0.05)
limm_pca_results = limm_pca(X_matrix, feature_cols)
msca_results = msca(X_matrix, feature_cols)

# Now you can visualize and interpret the results
# (See the comprehensive plotting code in the guide)
# Out:
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.2406
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.7752
#   PC1 explained variance: 82.00%
#   PC2 explained variance: 18.00%
# C(treatment):C(timepoint) - Sum of Squares: 82.1474
#   PC1 explained variance: 89.69%
#   PC2 explained variance: 10.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.1216
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 119.3476
#   PC1 explained variance: 76.02%
#   PC2 explained variance: 23.98%
# C(treatment):C(timepoint) - Sum of Squares: 80.7992
#   PC1 explained variance: 69.62%
#   PC2 explained variance: 30.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.0026
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.1658
#   PC1 explained variance: 53.71%
#   PC2 explained variance: 46.29%
# C(treatment):C(timepoint) - Sum of Squares: 54.2212
#   PC1 explained variance: 57.09%
#   PC2 explained variance: 42.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.8492
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 95.3448
#   PC1 explained variance: 59.35%
#   PC2 explained variance: 40.65%
# C(treatment):C(timepoint) - Sum of Squares: 72.8433
#   PC1 explained variance: 68.60%
#   PC2 explained variance: 31.40%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.3246
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.8694
#   PC1 explained variance: 85.86%
#   PC2 explained variance: 14.14%
# C(treatment):C(timepoint) - Sum of Squares: 69.5646
#   PC1 explained variance: 79.49%
#   PC2 explained variance: 20.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.4828
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.9309
#   PC1 explained variance: 78.37%
#   PC2 explained variance: 21.63%
# C(treatment):C(timepoint) - Sum of Squares: 49.5714
#   PC1 explained variance: 79.30%
#   PC2 explained variance: 20.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.8096
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.1998
#   PC1 explained variance: 73.38%
#   PC2 explained variance: 26.62%
# C(treatment):C(timepoint) - Sum of Squares: 57.8525
#   PC1 explained variance: 70.15%
#   PC2 explained variance: 29.85%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 9.9100
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.7486
#   PC1 explained variance: 90.61%
#   PC2 explained variance: 9.39%
# C(treatment):C(timepoint) - Sum of Squares: 60.7831
#   PC1 explained variance: 82.39%
#   PC2 explained variance: 17.61%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.1752
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.4800
#   PC1 explained variance: 78.84%
#   PC2 explained variance: 21.16%
# C(treatment):C(timepoint) - Sum of Squares: 135.9940
#   PC1 explained variance: 63.16%
#   PC2 explained variance: 36.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.2192
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.5029
#   PC1 explained variance: 81.80%
#   PC2 explained variance: 18.20%
# C(treatment):C(timepoint) - Sum of Squares: 63.0739
#   PC1 explained variance: 76.94%
#   PC2 explained variance: 23.06%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 166.4390
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 161.5291
#   PC1 explained variance: 71.04%
#   PC2 explained variance: 28.96%
# C(treatment):C(timepoint) - Sum of Squares: 181.2184
#   PC1 explained variance: 92.49%
#   PC2 explained variance: 7.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.6083
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.9458
#   PC1 explained variance: 70.21%
#   PC2 explained variance: 29.79%
# C(treatment):C(timepoint) - Sum of Squares: 41.2522
#   PC1 explained variance: 79.44%
#   PC2 explained variance: 20.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 175.6346
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.2532
#   PC1 explained variance: 82.40%
#   PC2 explained variance: 17.60%
# C(treatment):C(timepoint) - Sum of Squares: 272.8960
#   PC1 explained variance: 94.03%
#   PC2 explained variance: 5.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.4468
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.5610
#   PC1 explained variance: 65.22%
#   PC2 explained variance: 34.78%
# C(treatment):C(timepoint) - Sum of Squares: 92.5868
#   PC1 explained variance: 66.58%
#   PC2 explained variance: 33.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 25.5869
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.6274
#   PC1 explained variance: 81.71%
#   PC2 explained variance: 18.29%
# C(treatment):C(timepoint) - Sum of Squares: 82.2202
#   PC1 explained variance: 75.79%
#   PC2 explained variance: 24.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.8918
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.3935
#   PC1 explained variance: 74.77%
#   PC2 explained variance: 25.23%
# C(treatment):C(timepoint) - Sum of Squares: 58.4307
#   PC1 explained variance: 82.97%
#   PC2 explained variance: 17.03%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.1659
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 59.8450
#   PC1 explained variance: 79.91%
#   PC2 explained variance: 20.09%
# C(treatment):C(timepoint) - Sum of Squares: 67.5709
#   PC1 explained variance: 57.41%
#   PC2 explained variance: 42.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 27.5256
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 141.0589
#   PC1 explained variance: 84.53%
#   PC2 explained variance: 15.47%
# C(treatment):C(timepoint) - Sum of Squares: 58.2580
#   PC1 explained variance: 83.20%
#   PC2 explained variance: 16.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.7323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 112.2728
#   PC1 explained variance: 72.21%
#   PC2 explained variance: 27.79%
# C(treatment):C(timepoint) - Sum of Squares: 109.0906
#   PC1 explained variance: 69.08%
#   PC2 explained variance: 30.92%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.7012
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.0870
#   PC1 explained variance: 59.57%
#   PC2 explained variance: 40.43%
# C(treatment):C(timepoint) - Sum of Squares: 40.3273
#   PC1 explained variance: 63.80%
#   PC2 explained variance: 36.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 90.9430
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 75.0060
#   PC1 explained variance: 67.18%
#   PC2 explained variance: 32.82%
# C(treatment):C(timepoint) - Sum of Squares: 108.2753
#   PC1 explained variance: 75.35%
#   PC2 explained variance: 24.65%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.9530
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 19.7540
#   PC1 explained variance: 83.31%
#   PC2 explained variance: 16.69%
# C(treatment):C(timepoint) - Sum of Squares: 96.2376
#   PC1 explained variance: 80.76%
#   PC2 explained variance: 19.24%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.6651
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 116.8437
#   PC1 explained variance: 71.46%
#   PC2 explained variance: 28.54%
# C(treatment):C(timepoint) - Sum of Squares: 72.0598
#   PC1 explained variance: 86.95%
#   PC2 explained variance: 13.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.9276
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.3673
#   PC1 explained variance: 72.67%
#   PC2 explained variance: 27.33%
# C(treatment):C(timepoint) - Sum of Squares: 35.3981
#   PC1 explained variance: 85.81%
#   PC2 explained variance: 14.19%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 116.6810
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 123.2656
#   PC1 explained variance: 86.81%
#   PC2 explained variance: 13.19%
# C(treatment):C(timepoint) - Sum of Squares: 103.3679
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 109.7912
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.6118
#   PC1 explained variance: 57.44%
#   PC2 explained variance: 42.56%
# C(treatment):C(timepoint) - Sum of Squares: 172.6227
#   PC1 explained variance: 72.20%
#   PC2 explained variance: 27.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.5111
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 173.8670
#   PC1 explained variance: 78.25%
#   PC2 explained variance: 21.75%
# C(treatment):C(timepoint) - Sum of Squares: 69.1889
#   PC1 explained variance: 69.58%
#   PC2 explained variance: 30.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 63.2070
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.5124
#   PC1 explained variance: 84.93%
#   PC2 explained variance: 15.07%
# C(treatment):C(timepoint) - Sum of Squares: 55.6828
#   PC1 explained variance: 74.83%
#   PC2 explained variance: 25.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.0588
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 154.8941
#   PC1 explained variance: 86.77%
#   PC2 explained variance: 13.23%
# C(treatment):C(timepoint) - Sum of Squares: 105.1223
#   PC1 explained variance: 95.56%
#   PC2 explained variance: 4.44%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.3968
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 79.6579
#   PC1 explained variance: 71.57%
#   PC2 explained variance: 28.43%
# C(treatment):C(timepoint) - Sum of Squares: 58.1766
#   PC1 explained variance: 85.19%
#   PC2 explained variance: 14.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.7066
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 31.0574
#   PC1 explained variance: 80.56%
#   PC2 explained variance: 19.44%
# C(treatment):C(timepoint) - Sum of Squares: 50.2784
#   PC1 explained variance: 77.55%
#   PC2 explained variance: 22.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.9512
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.8427
#   PC1 explained variance: 75.84%
#   PC2 explained variance: 24.16%
# C(treatment):C(timepoint) - Sum of Squares: 52.2038
#   PC1 explained variance: 79.25%
#   PC2 explained variance: 20.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 184.2065
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.6361
#   PC1 explained variance: 84.35%
#   PC2 explained variance: 15.65%
# C(treatment):C(timepoint) - Sum of Squares: 168.4762
#   PC1 explained variance: 93.57%
#   PC2 explained variance: 6.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 105.4030
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.3991
#   PC1 explained variance: 70.46%
#   PC2 explained variance: 29.54%
# C(treatment):C(timepoint) - Sum of Squares: 108.9449
#   PC1 explained variance: 93.32%
#   PC2 explained variance: 6.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.9670
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 108.5947
#   PC1 explained variance: 88.07%
#   PC2 explained variance: 11.93%
# C(treatment):C(timepoint) - Sum of Squares: 131.3705
#   PC1 explained variance: 85.00%
#   PC2 explained variance: 15.00%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.4555
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.6671
#   PC1 explained variance: 92.78%
#   PC2 explained variance: 7.22%
# C(treatment):C(timepoint) - Sum of Squares: 89.6421
#   PC1 explained variance: 76.83%
#   PC2 explained variance: 23.17%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.7892
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 163.8768
#   PC1 explained variance: 79.92%
#   PC2 explained variance: 20.08%
# C(treatment):C(timepoint) - Sum of Squares: 107.8400
#   PC1 explained variance: 85.50%
#   PC2 explained variance: 14.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.4357
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 40.4407
#   PC1 explained variance: 73.77%
#   PC2 explained variance: 26.23%
# C(treatment):C(timepoint) - Sum of Squares: 56.4461
#   PC1 explained variance: 58.20%
#   PC2 explained variance: 41.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.4680
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.9426
#   PC1 explained variance: 68.33%
#   PC2 explained variance: 31.67%
# C(treatment):C(timepoint) - Sum of Squares: 90.9603
#   PC1 explained variance: 61.10%
#   PC2 explained variance: 38.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.2793
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.6794
#   PC1 explained variance: 67.35%
#   PC2 explained variance: 32.65%
# C(treatment):C(timepoint) - Sum of Squares: 40.8106
#   PC1 explained variance: 89.28%
#   PC2 explained variance: 10.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.9238
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.7943
#   PC1 explained variance: 67.20%
#   PC2 explained variance: 32.80%
# C(treatment):C(timepoint) - Sum of Squares: 33.5440
#   PC1 explained variance: 58.79%
#   PC2 explained variance: 41.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.0046
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 122.5340
#   PC1 explained variance: 59.83%
#   PC2 explained variance: 40.17%
# C(treatment):C(timepoint) - Sum of Squares: 118.7886
#   PC1 explained variance: 92.07%
#   PC2 explained variance: 7.93%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 5.7345
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.0115
#   PC1 explained variance: 86.71%
#   PC2 explained variance: 13.29%
# C(treatment):C(timepoint) - Sum of Squares: 60.0838
#   PC1 explained variance: 90.52%
#   PC2 explained variance: 9.48%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.3082
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8690
#   PC1 explained variance: 75.11%
#   PC2 explained variance: 24.89%
# C(treatment):C(timepoint) - Sum of Squares: 69.6241
#   PC1 explained variance: 82.31%
#   PC2 explained variance: 17.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.9323
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.0022
#   PC1 explained variance: 78.22%
#   PC2 explained variance: 21.78%
# C(treatment):C(timepoint) - Sum of Squares: 65.8509
#   PC1 explained variance: 56.14%
#   PC2 explained variance: 43.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.8514
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.7031
#   PC1 explained variance: 71.21%
#   PC2 explained variance: 28.79%
# C(treatment):C(timepoint) - Sum of Squares: 78.6381
#   PC1 explained variance: 69.90%
#   PC2 explained variance: 30.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 30.3182
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 67.4558
#   PC1 explained variance: 70.76%
#   PC2 explained variance: 29.24%
# C(treatment):C(timepoint) - Sum of Squares: 55.2327
#   PC1 explained variance: 77.45%
#   PC2 explained variance: 22.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 92.5148
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 63.2117
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
# C(treatment):C(timepoint) - Sum of Squares: 114.8594
#   PC1 explained variance: 89.70%
#   PC2 explained variance: 10.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.4000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.4675
#   PC1 explained variance: 79.56%
#   PC2 explained variance: 20.44%
# C(treatment):C(timepoint) - Sum of Squares: 144.6204
#   PC1 explained variance: 82.78%
#   PC2 explained variance: 17.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.8105
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.5721
#   PC1 explained variance: 73.11%
#   PC2 explained variance: 26.89%
# C(treatment):C(timepoint) - Sum of Squares: 64.5267
#   PC1 explained variance: 83.36%
#   PC2 explained variance: 16.64%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 60.6693
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 124.6785
#   PC1 explained variance: 89.00%
#   PC2 explained variance: 11.00%
# C(treatment):C(timepoint) - Sum of Squares: 150.1809
#   PC1 explained variance: 91.37%
#   PC2 explained variance: 8.63%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 107.7567
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 114.5357
#   PC1 explained variance: 63.08%
#   PC2 explained variance: 36.92%
# C(treatment):C(timepoint) - Sum of Squares: 203.0186
#   PC1 explained variance: 72.07%
#   PC2 explained variance: 27.93%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 69.9058
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 44.5217
#   PC1 explained variance: 66.05%
#   PC2 explained variance: 33.95%
# C(treatment):C(timepoint) - Sum of Squares: 39.7067
#   PC1 explained variance: 61.88%
#   PC2 explained variance: 38.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.8872
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 185.1426
#   PC1 explained variance: 88.19%
#   PC2 explained variance: 11.81%
# C(treatment):C(timepoint) - Sum of Squares: 254.9074
#   PC1 explained variance: 94.91%
#   PC2 explained variance: 5.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.7287
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.9797
#   PC1 explained variance: 76.71%
#   PC2 explained variance: 23.29%
# C(treatment):C(timepoint) - Sum of Squares: 33.9515
#   PC1 explained variance: 53.69%
#   PC2 explained variance: 46.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 192.6848
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 170.9497
#   PC1 explained variance: 82.08%
#   PC2 explained variance: 17.92%
# C(treatment):C(timepoint) - Sum of Squares: 175.0752
#   PC1 explained variance: 82.88%
#   PC2 explained variance: 17.12%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.7342
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.9406
#   PC1 explained variance: 67.91%
#   PC2 explained variance: 32.09%
# C(treatment):C(timepoint) - Sum of Squares: 87.2268
#   PC1 explained variance: 63.01%
#   PC2 explained variance: 36.99%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.0143
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.9813
#   PC1 explained variance: 59.58%
#   PC2 explained variance: 40.42%
# C(treatment):C(timepoint) - Sum of Squares: 56.4085
#   PC1 explained variance: 85.03%
#   PC2 explained variance: 14.97%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.5567
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.7754
#   PC1 explained variance: 78.31%
#   PC2 explained variance: 21.69%
# C(treatment):C(timepoint) - Sum of Squares: 83.1012
#   PC1 explained variance: 86.41%
#   PC2 explained variance: 13.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 71.6632
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 100.2729
#   PC1 explained variance: 81.60%
#   PC2 explained variance: 18.40%
# C(treatment):C(timepoint) - Sum of Squares: 93.2210
#   PC1 explained variance: 84.58%
#   PC2 explained variance: 15.42%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.7683
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 38.0568
#   PC1 explained variance: 65.98%
#   PC2 explained variance: 34.02%
# C(treatment):C(timepoint) - Sum of Squares: 70.5775
#   PC1 explained variance: 80.27%
#   PC2 explained variance: 19.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 84.4762
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.3809
#   PC1 explained variance: 72.41%
#   PC2 explained variance: 27.59%
# C(treatment):C(timepoint) - Sum of Squares: 96.4162
#   PC1 explained variance: 96.57%
#   PC2 explained variance: 3.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 54.3851
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 35.3250
#   PC1 explained variance: 61.89%
#   PC2 explained variance: 38.11%
# C(treatment):C(timepoint) - Sum of Squares: 36.9236
#   PC1 explained variance: 70.55%
#   PC2 explained variance: 29.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.3062
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.3488
#   PC1 explained variance: 87.39%
#   PC2 explained variance: 12.61%
# C(treatment):C(timepoint) - Sum of Squares: 80.4566
#   PC1 explained variance: 84.49%
#   PC2 explained variance: 15.51%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.2922
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.3893
#   PC1 explained variance: 74.82%
#   PC2 explained variance: 25.18%
# C(treatment):C(timepoint) - Sum of Squares: 85.3232
#   PC1 explained variance: 54.16%
#   PC2 explained variance: 45.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 50.6488
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.6103
#   PC1 explained variance: 69.61%
#   PC2 explained variance: 30.39%
# C(treatment):C(timepoint) - Sum of Squares: 79.4090
#   PC1 explained variance: 75.06%
#   PC2 explained variance: 24.94%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.2094
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 138.8943
#   PC1 explained variance: 57.20%
#   PC2 explained variance: 42.80%
# C(treatment):C(timepoint) - Sum of Squares: 145.5113
#   PC1 explained variance: 76.44%
#   PC2 explained variance: 23.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.7023
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.3081
#   PC1 explained variance: 71.12%
#   PC2 explained variance: 28.88%
# C(treatment):C(timepoint) - Sum of Squares: 164.7540
#   PC1 explained variance: 93.91%
#   PC2 explained variance: 6.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.9061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 64.0057
#   PC1 explained variance: 80.07%
#   PC2 explained variance: 19.93%
# C(treatment):C(timepoint) - Sum of Squares: 36.4484
#   PC1 explained variance: 87.89%
#   PC2 explained variance: 12.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 49.9245
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 60.6083
#   PC1 explained variance: 84.85%
#   PC2 explained variance: 15.15%
# C(treatment):C(timepoint) - Sum of Squares: 52.4485
#   PC1 explained variance: 73.02%
#   PC2 explained variance: 26.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 45.3538
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.8536
#   PC1 explained variance: 81.79%
#   PC2 explained variance: 18.21%
# C(treatment):C(timepoint) - Sum of Squares: 35.3170
#   PC1 explained variance: 68.66%
#   PC2 explained variance: 31.34%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 94.0596
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.0056
#   PC1 explained variance: 57.42%
#   PC2 explained variance: 42.58%
# C(treatment):C(timepoint) - Sum of Squares: 91.9101
#   PC1 explained variance: 86.16%
#   PC2 explained variance: 13.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 10.0145
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.5832
#   PC1 explained variance: 87.73%
#   PC2 explained variance: 12.27%
# C(treatment):C(timepoint) - Sum of Squares: 37.9410
#   PC1 explained variance: 81.85%
#   PC2 explained variance: 18.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 32.6416
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 71.2199
#   PC1 explained variance: 74.98%
#   PC2 explained variance: 25.02%
# C(treatment):C(timepoint) - Sum of Squares: 63.7353
#   PC1 explained variance: 78.50%
#   PC2 explained variance: 21.50%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.2402
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.0284
#   PC1 explained variance: 60.33%
#   PC2 explained variance: 39.67%
# C(treatment):C(timepoint) - Sum of Squares: 75.9066
#   PC1 explained variance: 69.66%
#   PC2 explained variance: 30.34%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 40.9160
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.9625
#   PC1 explained variance: 74.76%
#   PC2 explained variance: 25.24%
# C(treatment):C(timepoint) - Sum of Squares: 105.6830
#   PC1 explained variance: 78.27%
#   PC2 explained variance: 21.73%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.0030
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.7798
#   PC1 explained variance: 62.39%
#   PC2 explained variance: 37.61%
# C(treatment):C(timepoint) - Sum of Squares: 132.9635
#   PC1 explained variance: 81.70%
#   PC2 explained variance: 18.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.4467
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.2838
#   PC1 explained variance: 73.75%
#   PC2 explained variance: 26.25%
# C(treatment):C(timepoint) - Sum of Squares: 85.3961
#   PC1 explained variance: 83.69%
#   PC2 explained variance: 16.31%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 36.1530
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 84.4957
#   PC1 explained variance: 76.54%
#   PC2 explained variance: 23.46%
# C(treatment):C(timepoint) - Sum of Squares: 55.5767
#   PC1 explained variance: 71.31%
#   PC2 explained variance: 28.69%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 72.9467
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.2745
#   PC1 explained variance: 75.36%
#   PC2 explained variance: 24.64%
# C(treatment):C(timepoint) - Sum of Squares: 71.6495
#   PC1 explained variance: 78.10%
#   PC2 explained variance: 21.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.0871
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 168.3153
#   PC1 explained variance: 94.61%
#   PC2 explained variance: 5.39%
# C(treatment):C(timepoint) - Sum of Squares: 84.4454
#   PC1 explained variance: 86.22%
#   PC2 explained variance: 13.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.1703
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.8168
#   PC1 explained variance: 72.29%
#   PC2 explained variance: 27.71%
# C(treatment):C(timepoint) - Sum of Squares: 56.9122
#   PC1 explained variance: 75.34%
#   PC2 explained variance: 24.66%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 25.1927
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 76.1611
#   PC1 explained variance: 66.47%
#   PC2 explained variance: 33.53%
# C(treatment):C(timepoint) - Sum of Squares: 44.0158
#   PC1 explained variance: 61.02%
#   PC2 explained variance: 38.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.4053
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 250.3561
#   PC1 explained variance: 82.28%
#   PC2 explained variance: 17.72%
# C(treatment):C(timepoint) - Sum of Squares: 86.1859
#   PC1 explained variance: 68.26%
#   PC2 explained variance: 31.74%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 89.5002
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.0789
#   PC1 explained variance: 67.16%
#   PC2 explained variance: 32.84%
# C(treatment):C(timepoint) - Sum of Squares: 44.9918
#   PC1 explained variance: 84.17%
#   PC2 explained variance: 15.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.8895
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 45.7758
#   PC1 explained variance: 87.50%
#   PC2 explained variance: 12.50%
# C(treatment):C(timepoint) - Sum of Squares: 68.2090
#   PC1 explained variance: 64.15%
#   PC2 explained variance: 35.85%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 66.2017
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 36.1451
#   PC1 explained variance: 76.36%
#   PC2 explained variance: 23.64%
# C(treatment):C(timepoint) - Sum of Squares: 56.5073
#   PC1 explained variance: 70.64%
#   PC2 explained variance: 29.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 20.1320
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.2681
#   PC1 explained variance: 67.55%
#   PC2 explained variance: 32.45%
# C(treatment):C(timepoint) - Sum of Squares: 40.2181
#   PC1 explained variance: 80.40%
#   PC2 explained variance: 19.60%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.2590
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.1288
#   PC1 explained variance: 75.28%
#   PC2 explained variance: 24.72%
# C(treatment):C(timepoint) - Sum of Squares: 145.1008
#   PC1 explained variance: 91.55%
#   PC2 explained variance: 8.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 18.2269
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 145.9336
#   PC1 explained variance: 69.30%
#   PC2 explained variance: 30.70%
# C(treatment):C(timepoint) - Sum of Squares: 35.6192
#   PC1 explained variance: 75.14%
#   PC2 explained variance: 24.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.7463
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 55.7320
#   PC1 explained variance: 68.92%
#   PC2 explained variance: 31.08%
# C(treatment):C(timepoint) - Sum of Squares: 34.3647
#   PC1 explained variance: 75.68%
#   PC2 explained variance: 24.32%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 38.6688
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.5957
#   PC1 explained variance: 57.38%
#   PC2 explained variance: 42.62%
# C(treatment):C(timepoint) - Sum of Squares: 85.6425
#   PC1 explained variance: 81.13%
#   PC2 explained variance: 18.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.9668
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 93.2716
#   PC1 explained variance: 69.60%
#   PC2 explained variance: 30.40%
# C(treatment):C(timepoint) - Sum of Squares: 32.1763
#   PC1 explained variance: 67.25%
#   PC2 explained variance: 32.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 12.7014
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 100.6886
#   PC1 explained variance: 78.94%
#   PC2 explained variance: 21.06%
# C(treatment):C(timepoint) - Sum of Squares: 48.8603
#   PC1 explained variance: 89.22%
#   PC2 explained variance: 10.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 52.6955
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.5567
#   PC1 explained variance: 89.99%
#   PC2 explained variance: 10.01%
# C(treatment):C(timepoint) - Sum of Squares: 78.5186
#   PC1 explained variance: 83.11%
#   PC2 explained variance: 16.89%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.9663
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 96.6414
#   PC1 explained variance: 74.03%
#   PC2 explained variance: 25.97%
# C(treatment):C(timepoint) - Sum of Squares: 88.0031
#   PC1 explained variance: 66.14%
#   PC2 explained variance: 33.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 118.5173
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.1647
#   PC1 explained variance: 79.28%
#   PC2 explained variance: 20.72%
# C(treatment):C(timepoint) - Sum of Squares: 68.7249
#   PC1 explained variance: 78.89%
#   PC2 explained variance: 21.11%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 73.0634
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 61.3267
#   PC1 explained variance: 67.39%
#   PC2 explained variance: 32.61%
# C(treatment):C(timepoint) - Sum of Squares: 122.6578
#   PC1 explained variance: 60.45%
#   PC2 explained variance: 39.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 42.0578
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 73.0832
#   PC1 explained variance: 67.44%
#   PC2 explained variance: 32.56%
# C(treatment):C(timepoint) - Sum of Squares: 64.6168
#   PC1 explained variance: 64.49%
#   PC2 explained variance: 35.51%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.1000 (not significant)
#
# === PE-ASCA Analysis (Permutation-Enhanced ASCA) ===
#
# === ASCA+ Analysis (ASCA with Permutation Testing) ===
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 592.6881
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
# C(treatment):C(timepoint) - Sum of Squares: 148.4164
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# Running permutation tests with 99 permutations...
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 49.2947
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7215
#   PC1 explained variance: 61.77%
#   PC2 explained variance: 38.23%
# C(treatment):C(timepoint) - Sum of Squares: 79.9093
#   PC1 explained variance: 64.47%
#   PC2 explained variance: 35.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 104.5620
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 102.3960
#   PC1 explained variance: 67.39%
#   PC2 explained variance: 32.61%
# C(treatment):C(timepoint) - Sum of Squares: 98.2144
#   PC1 explained variance: 80.32%
#   PC2 explained variance: 19.68%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 15.3569
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.7327
#   PC1 explained variance: 61.67%
#   PC2 explained variance: 38.33%
# C(treatment):C(timepoint) - Sum of Squares: 40.8871
#   PC1 explained variance: 61.92%
#   PC2 explained variance: 38.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.6031
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.1464
#   PC1 explained variance: 81.29%
#   PC2 explained variance: 18.71%
# C(treatment):C(timepoint) - Sum of Squares: 46.6305
#   PC1 explained variance: 81.74%
#   PC2 explained variance: 18.26%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.1229
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.4551
#   PC1 explained variance: 83.74%
#   PC2 explained variance: 16.26%
# C(treatment):C(timepoint) - Sum of Squares: 96.9734
#   PC1 explained variance: 90.55%
#   PC2 explained variance: 9.45%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 123.1694
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.2184
#   PC1 explained variance: 79.00%
#   PC2 explained variance: 21.00%
# C(treatment):C(timepoint) - Sum of Squares: 137.9866
#   PC1 explained variance: 78.45%
#   PC2 explained variance: 21.55%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 115.7939
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.8034
#   PC1 explained variance: 63.50%
#   PC2 explained variance: 36.50%
# C(treatment):C(timepoint) - Sum of Squares: 72.7242
#   PC1 explained variance: 80.16%
#   PC2 explained variance: 19.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 79.6196
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 37.6583
#   PC1 explained variance: 52.73%
#   PC2 explained variance: 47.27%
# C(treatment):C(timepoint) - Sum of Squares: 53.4075
#   PC1 explained variance: 82.05%
#   PC2 explained variance: 17.95%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 74.4662
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 57.7651
#   PC1 explained variance: 74.54%
#   PC2 explained variance: 25.46%
# C(treatment):C(timepoint) - Sum of Squares: 69.3219
#   PC1 explained variance: 85.67%
#   PC2 explained variance: 14.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 9.5544
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.7727
#   PC1 explained variance: 78.02%
#   PC2 explained variance: 21.98%
# C(treatment):C(timepoint) - Sum of Squares: 69.1643
#   PC1 explained variance: 62.13%
#   PC2 explained variance: 37.87%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.3531
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.0991
#   PC1 explained variance: 70.57%
#   PC2 explained variance: 29.43%
# C(treatment):C(timepoint) - Sum of Squares: 60.7556
#   PC1 explained variance: 81.47%
#   PC2 explained variance: 18.53%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 100.5456
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7985
#   PC1 explained variance: 50.79%
#   PC2 explained variance: 49.21%
# C(treatment):C(timepoint) - Sum of Squares: 124.6717
#   PC1 explained variance: 70.70%
#   PC2 explained variance: 29.30%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 19.5738
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 80.8509
#   PC1 explained variance: 61.59%
#   PC2 explained variance: 38.41%
# C(treatment):C(timepoint) - Sum of Squares: 51.8927
#   PC1 explained variance: 76.19%
#   PC2 explained variance: 23.81%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 37.5933
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 46.8780
#   PC1 explained variance: 87.70%
#   PC2 explained variance: 12.30%
# C(treatment):C(timepoint) - Sum of Squares: 40.8761
#   PC1 explained variance: 62.90%
#   PC2 explained variance: 37.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.1089
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 56.2473
#   PC1 explained variance: 79.44%
#   PC2 explained variance: 20.56%
# C(treatment):C(timepoint) - Sum of Squares: 52.7229
#   PC1 explained variance: 86.12%
#   PC2 explained variance: 13.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 23.9980
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 50.3284
#   PC1 explained variance: 67.99%
#   PC2 explained variance: 32.01%
# C(treatment):C(timepoint) - Sum of Squares: 28.2435
#   PC1 explained variance: 68.95%
#   PC2 explained variance: 31.05%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.3037
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.4803
#   PC1 explained variance: 78.57%
#   PC2 explained variance: 21.43%
# C(treatment):C(timepoint) - Sum of Squares: 54.9183
#   PC1 explained variance: 78.23%
#   PC2 explained variance: 21.77%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.4900
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.8932
#   PC1 explained variance: 65.84%
#   PC2 explained variance: 34.16%
# C(treatment):C(timepoint) - Sum of Squares: 61.0347
#   PC1 explained variance: 67.78%
#   PC2 explained variance: 32.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 56.1040
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.4448
#   PC1 explained variance: 74.62%
#   PC2 explained variance: 25.38%
# C(treatment):C(timepoint) - Sum of Squares: 64.5216
#   PC1 explained variance: 79.67%
#   PC2 explained variance: 20.33%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 33.3521
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 33.5562
#   PC1 explained variance: 87.55%
#   PC2 explained variance: 12.45%
# C(treatment):C(timepoint) - Sum of Squares: 84.1905
#   PC1 explained variance: 67.73%
#   PC2 explained variance: 32.27%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 201.3488
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 127.3861
#   PC1 explained variance: 83.69%
#   PC2 explained variance: 16.31%
# C(treatment):C(timepoint) - Sum of Squares: 117.8758
#   PC1 explained variance: 92.33%
#   PC2 explained variance: 7.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 119.7560
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 103.4994
#   PC1 explained variance: 64.97%
#   PC2 explained variance: 35.03%
# C(treatment):C(timepoint) - Sum of Squares: 101.7801
#   PC1 explained variance: 90.28%
#   PC2 explained variance: 9.72%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.4274
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 292.2594
#   PC1 explained variance: 80.77%
#   PC2 explained variance: 19.23%
# C(treatment):C(timepoint) - Sum of Squares: 274.1979
#   PC1 explained variance: 93.41%
#   PC2 explained variance: 6.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 26.2691
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.4632
#   PC1 explained variance: 60.79%
#   PC2 explained variance: 39.21%
# C(treatment):C(timepoint) - Sum of Squares: 40.5269
#   PC1 explained variance: 52.17%
#   PC2 explained variance: 47.83%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 41.4748
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 144.5931
#   PC1 explained variance: 75.28%
#   PC2 explained variance: 24.72%
# C(treatment):C(timepoint) - Sum of Squares: 78.1761
#   PC1 explained variance: 82.65%
#   PC2 explained variance: 17.35%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 104.3061
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 165.7680
#   PC1 explained variance: 83.58%
#   PC2 explained variance: 16.42%
# C(treatment):C(timepoint) - Sum of Squares: 166.3818
#   PC1 explained variance: 92.21%
#   PC2 explained variance: 7.79%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.0712
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 47.6801
#   PC1 explained variance: 85.09%
#   PC2 explained variance: 14.91%
# C(treatment):C(timepoint) - Sum of Squares: 25.5896
#   PC1 explained variance: 63.92%
#   PC2 explained variance: 36.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.8358
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 74.0702
#   PC1 explained variance: 71.00%
#   PC2 explained variance: 29.00%
# C(treatment):C(timepoint) - Sum of Squares: 70.7602
#   PC1 explained variance: 70.46%
#   PC2 explained variance: 29.54%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 57.2134
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 139.5668
#   PC1 explained variance: 71.18%
#   PC2 explained variance: 28.82%
# C(treatment):C(timepoint) - Sum of Squares: 87.9664
#   PC1 explained variance: 65.44%
#   PC2 explained variance: 34.56%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 46.0694
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 90.5833
#   PC1 explained variance: 85.87%
#   PC2 explained variance: 14.13%
# C(treatment):C(timepoint) - Sum of Squares: 63.9424
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 39.3805
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.5281
#   PC1 explained variance: 71.86%
#   PC2 explained variance: 28.14%
# C(treatment):C(timepoint) - Sum of Squares: 78.4305
#   PC1 explained variance: 69.78%
#   PC2 explained variance: 30.22%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.0706
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.7534
#   PC1 explained variance: 80.23%
#   PC2 explained variance: 19.77%
# C(treatment):C(timepoint) - Sum of Squares: 33.6868
#   PC1 explained variance: 78.33%
#   PC2 explained variance: 21.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.6780
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.4774
#   PC1 explained variance: 89.10%
#   PC2 explained variance: 10.90%
# C(treatment):C(timepoint) - Sum of Squares: 83.9086
#   PC1 explained variance: 70.20%
#   PC2 explained variance: 29.80%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 95.6073
#   PC1 explained variance: 100.00%
# ...
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.9698
#   PC1 explained variance: 67.41%
#   PC2 explained variance: 32.59%
# C(treatment):C(timepoint) - Sum of Squares: 111.1036
#   PC1 explained variance: 63.33%
#   PC2 explained variance: 36.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 56.3447
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.8924
#   PC1 explained variance: 76.31%
#   PC2 explained variance: 23.69%
# C(treatment):C(timepoint) - Sum of Squares: 53.3135
#   PC1 explained variance: 81.38%
#   PC2 explained variance: 18.62%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 86.0047
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 69.2602
#   PC1 explained variance: 68.95%
#   PC2 explained variance: 31.05%
# C(treatment):C(timepoint) - Sum of Squares: 63.1520
#   PC1 explained variance: 74.10%
#   PC2 explained variance: 25.90%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.9237
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 95.5056
#   PC1 explained variance: 60.68%
#   PC2 explained variance: 39.32%
# C(treatment):C(timepoint) - Sum of Squares: 136.6338
#   PC1 explained variance: 90.09%
#   PC2 explained variance: 9.91%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 88.1704
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 89.1625
#   PC1 explained variance: 58.49%
#   PC2 explained variance: 41.51%
# C(treatment):C(timepoint) - Sum of Squares: 101.6801
#   PC1 explained variance: 76.77%
#   PC2 explained variance: 23.23%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 47.6582
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.3988
#   PC1 explained variance: 76.76%
#   PC2 explained variance: 23.24%
# C(treatment):C(timepoint) - Sum of Squares: 47.2619
#   PC1 explained variance: 77.14%
#   PC2 explained variance: 22.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.7100
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 65.0689
#   PC1 explained variance: 62.95%
#   PC2 explained variance: 37.05%
# C(treatment):C(timepoint) - Sum of Squares: 120.3598
#   PC1 explained variance: 85.24%
#   PC2 explained variance: 14.76%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.8829
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 120.4077
#   PC1 explained variance: 77.76%
#   PC2 explained variance: 22.24%
# C(treatment):C(timepoint) - Sum of Squares: 77.6796
#   PC1 explained variance: 82.41%
#   PC2 explained variance: 17.59%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 108.4400
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 137.8710
#   PC1 explained variance: 83.19%
#   PC2 explained variance: 16.81%
# C(treatment):C(timepoint) - Sum of Squares: 110.3439
#   PC1 explained variance: 91.43%
#   PC2 explained variance: 8.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 76.1432
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 91.2186
#   PC1 explained variance: 93.52%
#   PC2 explained variance: 6.48%
# C(treatment):C(timepoint) - Sum of Squares: 86.8230
#   PC1 explained variance: 81.99%
#   PC2 explained variance: 18.01%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 102.0603
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 58.8807
#   PC1 explained variance: 78.11%
#   PC2 explained variance: 21.89%
# C(treatment):C(timepoint) - Sum of Squares: 87.8910
#   PC1 explained variance: 79.61%
#   PC2 explained variance: 20.39%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.5836
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.0955
#   PC1 explained variance: 64.09%
#   PC2 explained variance: 35.91%
# C(treatment):C(timepoint) - Sum of Squares: 89.7561
#   PC1 explained variance: 73.79%
#   PC2 explained variance: 26.21%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 53.8809
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.8847
#   PC1 explained variance: 68.70%
#   PC2 explained variance: 31.30%
# C(treatment):C(timepoint) - Sum of Squares: 111.9250
#   PC1 explained variance: 81.53%
#   PC2 explained variance: 18.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 61.3107
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 51.2221
#   PC1 explained variance: 73.84%
#   PC2 explained variance: 26.16%
# C(treatment):C(timepoint) - Sum of Squares: 33.5333
#   PC1 explained variance: 61.64%
#   PC2 explained variance: 38.36%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 68.2305
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 49.6220
#   PC1 explained variance: 80.90%
#   PC2 explained variance: 19.10%
# C(treatment):C(timepoint) - Sum of Squares: 62.6292
#   PC1 explained variance: 82.43%
#   PC2 explained variance: 17.57%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 22.6755
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.6832
#   PC1 explained variance: 79.61%
#   PC2 explained variance: 20.39%
# C(treatment):C(timepoint) - Sum of Squares: 36.2975
#   PC1 explained variance: 76.14%
#   PC2 explained variance: 23.86%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 82.0695
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 169.7588
#   PC1 explained variance: 65.47%
#   PC2 explained variance: 34.53%
# C(treatment):C(timepoint) - Sum of Squares: 100.5631
#   PC1 explained variance: 70.18%
#   PC2 explained variance: 29.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 70.2536
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 154.5043
#   PC1 explained variance: 65.99%
#   PC2 explained variance: 34.01%
# C(treatment):C(timepoint) - Sum of Squares: 100.4817
#   PC1 explained variance: 77.38%
#   PC2 explained variance: 22.62%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 29.9171
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 94.9731
#   PC1 explained variance: 79.94%
#   PC2 explained variance: 20.06%
# C(treatment):C(timepoint) - Sum of Squares: 55.1832
#   PC1 explained variance: 90.63%
#   PC2 explained variance: 9.37%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 48.7000
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.0747
#   PC1 explained variance: 73.10%
#   PC2 explained variance: 26.90%
# C(treatment):C(timepoint) - Sum of Squares: 104.1923
#   PC1 explained variance: 74.57%
#   PC2 explained variance: 25.43%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 86.1368
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 54.3396
#   PC1 explained variance: 56.55%
#   PC2 explained variance: 43.45%
# C(treatment):C(timepoint) - Sum of Squares: 80.8967
#   PC1 explained variance: 81.75%
#   PC2 explained variance: 18.25%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.2401
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 42.8405
#   PC1 explained variance: 89.21%
#   PC2 explained variance: 10.79%
# C(treatment):C(timepoint) - Sum of Squares: 79.3683
#   PC1 explained variance: 83.86%
#   PC2 explained variance: 16.14%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 65.8464
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 81.6921
#   PC1 explained variance: 73.60%
#   PC2 explained variance: 26.40%
# C(treatment):C(timepoint) - Sum of Squares: 57.0193
#   PC1 explained variance: 82.92%
#   PC2 explained variance: 17.08%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 28.7517
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 66.0911
#   PC1 explained variance: 69.21%
#   PC2 explained variance: 30.79%
# C(treatment):C(timepoint) - Sum of Squares: 75.8686
#   PC1 explained variance: 92.48%
#   PC2 explained variance: 7.52%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 124.4198
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 48.9115
#   PC1 explained variance: 54.25%
#   PC2 explained variance: 45.75%
# C(treatment):C(timepoint) - Sum of Squares: 167.4655
#   PC1 explained variance: 88.90%
#   PC2 explained variance: 11.10%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 35.0554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 72.0043
#   PC1 explained variance: 71.45%
#   PC2 explained variance: 28.55%
# C(treatment):C(timepoint) - Sum of Squares: 89.1698
#   PC1 explained variance: 80.02%
#   PC2 explained variance: 19.98%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 78.6886
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 117.8459
#   PC1 explained variance: 85.54%
#   PC2 explained variance: 14.46%
# C(treatment):C(timepoint) - Sum of Squares: 108.7505
#   PC1 explained variance: 65.85%
#   PC2 explained variance: 34.15%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 55.0839
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.8811
#   PC1 explained variance: 61.64%
#   PC2 explained variance: 38.36%
# C(treatment):C(timepoint) - Sum of Squares: 90.1772
#   PC1 explained variance: 85.87%
#   PC2 explained variance: 14.13%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 43.7535
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 68.4711
#   PC1 explained variance: 75.57%
#   PC2 explained variance: 24.43%
# C(treatment):C(timepoint) - Sum of Squares: 77.6781
#   PC1 explained variance: 73.12%
#   PC2 explained variance: 26.88%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 21.0652
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 26.3034
#   PC1 explained variance: 85.09%
#   PC2 explained variance: 14.91%
# C(treatment):C(timepoint) - Sum of Squares: 53.9173
#   PC1 explained variance: 74.25%
#   PC2 explained variance: 25.75%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 80.9520
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.6682
#   PC1 explained variance: 56.52%
#   PC2 explained variance: 43.48%
# C(treatment):C(timepoint) - Sum of Squares: 95.8840
#   PC1 explained variance: 63.82%
#   PC2 explained variance: 36.18%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 106.0836
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 78.3751
#   PC1 explained variance: 84.53%
#   PC2 explained variance: 15.47%
# C(treatment):C(timepoint) - Sum of Squares: 132.1044
#   PC1 explained variance: 81.33%
#   PC2 explained variance: 18.67%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 24.8853
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 33.2320
#   PC1 explained variance: 53.47%
#   PC2 explained variance: 46.53%
# C(treatment):C(timepoint) - Sum of Squares: 45.0746
#   PC1 explained variance: 83.22%
#   PC2 explained variance: 16.78%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 34.9886
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 85.7221
#   PC1 explained variance: 74.95%
#   PC2 explained variance: 25.05%
# C(treatment):C(timepoint) - Sum of Squares: 129.4101
#   PC1 explained variance: 90.30%
#   PC2 explained variance: 9.70%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 16.1806
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 41.9546
#   PC1 explained variance: 83.20%
#   PC2 explained variance: 16.80%
# C(treatment):C(timepoint) - Sum of Squares: 35.5608
#   PC1 explained variance: 67.16%
#   PC2 explained variance: 32.84%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 67.8187
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 101.3044
#   PC1 explained variance: 90.88%
#   PC2 explained variance: 9.12%
# C(treatment):C(timepoint) - Sum of Squares: 112.9431
#   PC1 explained variance: 88.80%
#   PC2 explained variance: 11.20%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 85.5554
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 62.9289
#   PC1 explained variance: 90.95%
#   PC2 explained variance: 9.05%
# C(treatment):C(timepoint) - Sum of Squares: 86.6625
#   PC1 explained variance: 74.91%
#   PC2 explained variance: 25.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 58.3713
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 97.3385
#   PC1 explained variance: 72.00%
#   PC2 explained variance: 28.00%
# C(treatment):C(timepoint) - Sum of Squares: 93.4994
#   PC1 explained variance: 73.91%
#   PC2 explained variance: 26.09%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 44.0186
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 148.7258
#   PC1 explained variance: 81.33%
#   PC2 explained variance: 18.67%
# C(treatment):C(timepoint) - Sum of Squares: 42.7511
#   PC1 explained variance: 76.53%
#   PC2 explained variance: 23.47%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 62.9986
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 77.5059
#   PC1 explained variance: 79.60%
#   PC2 explained variance: 20.40%
# C(treatment):C(timepoint) - Sum of Squares: 87.9624
#   PC1 explained variance: 82.18%
#   PC2 explained variance: 17.82%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 51.0970
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 143.7985
#   PC1 explained variance: 65.55%
#   PC2 explained variance: 34.45%
# C(treatment):C(timepoint) - Sum of Squares: 85.5233
#   PC1 explained variance: 80.62%
#   PC2 explained variance: 19.38%
#
# === ASCA Analysis ===
# C(treatment) - Sum of Squares: 17.6160
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 30.0711
#   PC1 explained variance: 74.73%
#   PC2 explained variance: 25.27%
# C(treatment):C(timepoint) - Sum of Squares: 45.9914
#   PC1 explained variance: 84.90%
#   PC2 explained variance: 15.10%
#
# Permutation Test Results:
# C(treatment): p-value = 0.0100 (significant)
# C(timepoint): p-value = 0.0100 (significant)
# C(treatment):C(timepoint): p-value = 0.0600 (not significant)
# Effect C(treatment) is significant (p=0.0100) and included in enhanced model
# Effect C(timepoint) is significant (p=0.0100) and included in enhanced model
# Effect C(treatment):C(timepoint) is not significant (p=0.0600) and added to residuals
# C(treatment) - Sum of Squares: 592.6881 (35.97% of total)
#   PC1 explained variance: 100.00%
#   PC2 explained variance: 0.00%
# C(timepoint) - Sum of Squares: 591.9804 (35.93% of total)
#   PC1 explained variance: 66.85%
#   PC2 explained variance: 33.15%
#
# === LiMM-PCA Analysis (Linear Mixed Models with PCA) ===
# Processing feature 1/10...
# Processing feature 4/10...
# Processing feature 7/10...
# Processing feature 10/10...
#
# Variance Partition:
# Fixed Effects: 65.05%
# Random Effects: 18.15%
# Residuals: 9.57%
#
# PCA on Fixed Effects:
# PC1 explained variance: 44.23%
# PC2 explained variance: 34.29%
#
# === MSCA Analysis (Multilevel Simultaneous Component Analysis) ===
#
# Variance Partition:
# Between-subject: 51.77%
# Within-subject: 48.23%
#
# PCA on Between-subject Variation:
# PC1 explained variance: 53.02%
# PC2 explained variance: 13.09%
#
# PCA on Within-subject Variation:
# PC1 explained variance: 52.73%
# PC2 explained variance: 23.16%
